# %% [markdown]
# ### Recuperación de recursos de la web

# %% [markdown]
# Se van a mostrar varias formas de recuperar recursos que se encuentran en la web:
#
# * Recuperación via http
#
# * Recuperación con el módulo urllib.
#
# * Recuperación con el módulo Request
#
# __Recuperación via http__
#
# Un socket proporciona una conexión de doble sentido entre dos programas, de manera que es posible tanto leer como escribir en el mismo socket. Si se escribe algo en un socket, es enviado hacia la aplicación que está al otro lado del socket. Si se lee desde un socket, se obtienen los datos que la otra aplicación ha enviado.
#
# En Python existe un soporte integrado para los sockets.
#
# El protocolo para el intercambio de recursos web es HTTP. En este  protocolo para pedir un documento a un servidor web se escribe una línea en la cual el segundo parámetro es la página web que estamos solicitando, y a continuación enviamos una línea en blanco:
#
#             GET servidor web HTTP/1.0
#
# El servidor web responderá con una cabecera que contiene cierta información acerca del documento y una línea en blanco, seguido por el contenido del documento.
#
# En el siguiente ejemplo se va a recuperar una imagen. Para ello se realiza una conexión con el puerto 80 del servidor y se envía el comando GET seguido por una línea en blanco. Una vez enviada la línea en blanco, se utiliza un bucle que recibe los datos desde el socket en bloques de 512 caracteres y se  imprime en pantalla hasta que no quedan más datos por leer (recv() devuelve una cadena vacía).

# %%
import socket

misock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
misock.connect(('4.bp.blogspot.com', 80))
cmd = 'GET http://4.bp.blogspot.com/-aqPvTTwBDJQ/W4FInd5fTtI/AAAAAAAACkY/6536BHcuVlEh4YTRqIVi6DUFGb1FZWEWQCK4BGAYYCw/s1600/DSC_0166-1.jpg HTTP/1.1\r\n\r\n'.encode()
misock.send(cmd)

while True:
    datos = misock.recv(512)
    if (len(datos) < 1):
        break
    print(datos)
misock.close()
# Out:
# b'HTTP/1.1 200 OK\r\nAccess-Control-Expose-Headers: Content-Length\r\nETag: "va47"\r\nExpires: Wed, 16 Oct 2019 01:47:09 GMT\r\nContent-Disposition: inline;filename="DSC_0166-1.jpg"\r\nContent-Type: image/jpeg\r\nVary: Origin\r\nAccess-Control-Allow-Origin: *\r\nTiming-Allow-Origin: *\r\nX-Content-Type-Options: nosniff\r\nDate: Tue, 15 Oct 2019 01:47:09 GMT\r\nServer: fife\r\nContent-Length: 341437\r\nX-XSS-Protection: 0\r\nCache-Control: public, max-age=86400, no-transform\r\nAge: 472\r\n\r\n\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xe1\x00lExif\x00\x00II*\x00\x08\x00\x00\x00\x03\x001\x01\x02\x00\x07\x00\x00\x002\x00'
# b'\x00\x00\x12\x02\x03\x00\x02\x00\x00\x00\x02\x00\x02\x00i\x87\x04\x00\x01\x00\x00\x00:\x00\x00\x00\x00\x00\x00\x00Google\x00\x00\x03\x00\x00\x90\x07\x00\x04\x00\x00\x000220\x02\xa0\x04\x00\x01\x00\x00\x00\x00\x05\x00\x00\x03\xa0\x04\x00\x01\x00\x00\x00z\x02\x00\x00\x00\x00\x00\x00\xff\xe2\x0cXICC_PROFILE\x00\x01\x01\x00\x00\x0cHLino\x02\x10\x00\x00mntrRGB XYZ \x07\xce\x00\x02\x00\t\x00\x06\x001\x00\x00acspMSFT\x00\x00\x00\x00IEC sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-HP  \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x11cprt\x00\x00\x01P\x00\x00\x003desc\x00\x00\x01\x84\x00\x00\x00lwtpt\x00\x00\x01\xf0\x00\x00\x00\x14bkpt\x00\x00\x02\x04\x00\x00\x00\x14rXYZ\x00\x00\x02\x18\x00\x00\x00\x14gXYZ\x00\x00\x02,\x00\x00\x00\x14bXYZ\x00\x00\x02@\x00\x00\x00\x14dmnd\x00\x00\x02T\x00\x00\x00pdmdd\x00\x00\x02\xc4\x00\x00\x00\x88vued\x00\x00\x03L\x00\x00\x00\x86view\x00\x00\x03\xd4\x00\x00\x00$lumi\x00\x00\x03\xf8\x00\x00\x00\x14meas\x00\x00\x04\x0c\x00\x00\x00$tech\x00\x00\x040\x00\x00\x00\x0crTRC\x00\x00\x04<\x00\x00\x08\x0cgTRC\x00\x00\x04<\x00\x00\x08\x0cbTRC\x00\x00\x04<\x00\x00\x08\x0ctext\x00\x00\x00\x00Copyright (c) 1998 Hewlett-Packard Company\x00\x00desc\x00\x00\x00\x00\x00\x00\x00\x12sRGB IEC61966-'
# b'2.1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x12sRGB IEC61966-2.1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00XYZ \x00\x00\x00\x00\x00\x00\xf3Q\x00\x01\x00\x00\x00\x01\x16\xccXYZ \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00XYZ \x00\x00\x00\x00\x00\x00o\xa2\x00\x008\xf5\x00\x00\x03\x90XYZ \x00\x00\x00\x00\x00\x00b\x99\x00\x00\xb7\x85\x00\x00\x18\xdaXYZ \x00\x00\x00\x00\x00\x00$\xa0\x00\x00\x0f\x84\x00\x00\xb6\xcfdesc\x00\x00\x00\x00\x00\x00\x00\x16IEC http://www.iec.ch\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x16IEC http://www.iec.ch\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00desc\x00\x00\x00\x00\x00\x00\x00.IEC 61966-2.1 Default RGB colour space - sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00.IEC 61966-2.1 Default RGB colour space - sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00desc\x00\x00\x00\x00\x00\x00\x00,Reference Viewing Condition in IEC61966-2.1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00,Reference Viewi'
# b'ng Condition in IEC61966-2.1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00view\x00\x00\x00\x00\x00\x13\xa4\xfe\x00\x14_.\x00\x10\xcf\x14\x00\x03\xed\xcc\x00\x04\x13\x0b\x00\x03\\\x9e\x00\x00\x00\x01XYZ \x00\x00\x00\x00\x00L\tV\x00P\x00\x00\x00W\x1f\xe7meas\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x8f\x00\x00\x00\x02sig \x00\x00\x00\x00CRT curv\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x05\x00\n\x00\x0f\x00\x14\x00\x19\x00\x1e\x00#\x00(\x00-\x002\x007\x00;\x00@\x00E\x00J\x00O\x00T\x00Y\x00^\x00c\x00h\x00m\x00r\x00w\x00|\x00\x81\x00\x86\x00\x8b\x00\x90\x00\x95\x00\x9a\x00\x9f\x00\xa4\x00\xa9\x00\xae\x00\xb2\x00\xb7\x00\xbc\x00\xc1\x00\xc6\x00\xcb\x00\xd0\x00\xd5\x00\xdb\x00\xe0\x00\xe5\x00\xeb\x00\xf0\x00\xf6\x00\xfb\x01\x01\x01\x07\x01\r\x01\x13\x01\x19\x01\x1f\x01%\x01+\x012\x018\x01>\x01E\x01L\x01R\x01Y\x01`\x01g\x01n\x01u\x01|\x01\x83\x01\x8b\x01\x92\x01\x9a\x01\xa1\x01\xa9\x01\xb1\x01\xb9\x01\xc1\x01\xc9\x01\xd1\x01\xd9\x01\xe1\x01\xe9\x01\xf2\x01\xfa\x02\x03\x02\x0c\x02\x14\x02\x1d\x02&\x02/\x028\x02A\x02K\x02T\x02]\x02g\x02q\x02z\x02\x84\x02\x8e\x02\x98\x02\xa2\x02\xac\x02\xb6\x02\xc1\x02\xcb\x02\xd5\x02\xe0\x02\xeb\x02\xf5\x03\x00\x03\x0b\x03\x16\x03!\x03-\x038\x03C\x03O\x03Z\x03f\x03r\x03~\x03\x8a\x03\x96\x03\xa2\x03\xae\x03\xba\x03\xc7\x03\xd3\x03\xe0\x03\xec\x03\xf9\x04\x06\x04\x13\x04 \x04-\x04;\x04H\x04U\x04c\x04q\x04~\x04\x8c\x04\x9a\x04\xa8\x04\xb6\x04\xc4\x04\xd3\x04\xe1\x04\xf0\x04\xfe\x05\r\x05\x1c\x05+\x05:\x05I\x05X\x05g\x05w\x05\x86\x05\x96\x05\xa6\x05\xb5\x05\xc5\x05\xd5\x05\xe5\x05\xf6\x06\x06'
# b'\x06\x16\x06\'\x067\x06H\x06Y\x06j\x06{\x06\x8c\x06\x9d\x06\xaf\x06\xc0\x06\xd1\x06\xe3\x06\xf5\x07\x07\x07\x19\x07+\x07=\x07O\x07a\x07t\x07\x86\x07\x99\x07\xac\x07\xbf\x07\xd2\x07\xe5\x07\xf8\x08\x0b\x08\x1f\x082\x08F\x08Z\x08n\x08\x82\x08\x96\x08\xaa\x08\xbe\x08\xd2\x08\xe7\x08\xfb\t\x10\t%\t:\tO\td\ty\t\x8f\t\xa4\t\xba\t\xcf\t\xe5\t\xfb\n\x11\n\'\n=\nT\nj\n\x81\n\x98\n\xae\n\xc5\n\xdc\n\xf3\x0b\x0b\x0b"\x0b9\x0bQ\x0bi\x0b\x80\x0b\x98\x0b\xb0\x0b\xc8\x0b\xe1\x0b\xf9\x0c\x12\x0c*\x0cC\x0c\\\x0cu\x0c\x8e\x0c\xa7\x0c\xc0\x0c\xd9\x0c\xf3\r\r\r&\r@\rZ\rt\r\x8e\r\xa9\r\xc3\r\xde\r\xf8\x0e\x13\x0e.\x0eI\x0ed\x0e\x7f\x0e\x9b\x0e\xb6\x0e\xd2\x0e\xee\x0f\t\x0f%\x0fA\x0f^\x0fz\x0f\x96\x0f\xb3\x0f\xcf\x0f\xec\x10\t\x10&\x10C\x10a\x10~\x10\x9b\x10\xb9\x10\xd7\x10\xf5\x11\x13\x111\x11O\x11m\x11\x8c\x11\xaa\x11\xc9\x11\xe8\x12\x07\x12&\x12E\x12d\x12\x84\x12\xa3\x12\xc3\x12\xe3\x13\x03\x13#\x13C\x13c\x13\x83\x13\xa4\x13\xc5\x13\xe5\x14\x06\x14\'\x14I\x14j\x14\x8b\x14\xad\x14\xce\x14\xf0\x15\x12\x154\x15V\x15x\x15\x9b\x15\xbd\x15\xe0\x16\x03\x16&\x16I\x16l\x16\x8f\x16\xb2\x16\xd6\x16\xfa\x17\x1d\x17A\x17e\x17\x89\x17\xae\x17\xd2\x17\xf7\x18\x1b\x18@\x18e\x18\x8a\x18\xaf\x18\xd5\x18\xfa\x19 \x19E\x19k\x19\x91\x19\xb7\x19\xdd\x1a\x04\x1a*\x1aQ\x1aw\x1a\x9e\x1a\xc5\x1a\xec\x1b\x14\x1b;\x1bc\x1b\x8a\x1b\xb2\x1b\xda\x1c\x02\x1c*\x1cR\x1c{\x1c\xa3\x1c\xcc\x1c\xf5\x1d\x1e\x1dG\x1dp\x1d\x99\x1d\xc3\x1d\xec\x1e\x16\x1e@\x1ej\x1e\x94\x1e\xbe\x1e\xe9\x1f\x13\x1f>\x1fi\x1f\x94\x1f\xbf\x1f\xea \x15 A l \x98 \xc4 \xf0!\x1c!H!u!\xa1!\xce!\xfb"\'"U"\x82"\xaf"\xdd#\n#8#f#\x94#\xc2#\xf0$\x1f$M$|$\xab$\xda%\t'
# b'%8%h%\x97%\xc7%\xf7&\'&W&\x87&\xb7&\xe8\'\x18\'I\'z\'\xab\'\xdc(\r(?(q(\xa2(\xd4)\x06)8)k)\x9d)\xd0*\x02*5*h*\x9b*\xcf+\x02+6+i+\x9d+\xd1,\x05,9,n,\xa2,\xd7-\x0c-A-v-\xab-\xe1.\x16.L.\x82.\xb7.\xee/$/Z/\x91/\xc7/\xfe050l0\xa40\xdb1\x121J1\x821\xba1\xf22*2c2\x9b2\xd43\r3F3\x7f3\xb83\xf14+4e4\x9e4\xd85\x135M5\x875\xc25\xfd676r6\xae6\xe97$7`7\x9c7\xd78\x148P8\x8c8\xc89\x059B9\x7f9\xbc9\xf9:6:t:\xb2:\xef;-;k;\xaa;\xe8<\'<e<\xa4<\xe3="=a=\xa1=\xe0> >`>\xa0>\xe0?!?a?\xa2?\xe2@#@d@\xa6@\xe7A)AjA\xacA\xeeB0BrB\xb5B\xf7C:C}C\xc0D\x03DGD\x8aD\xceE\x12EUE\x9aE\xdeF"FgF\xabF\xf0G5G{G\xc0H\x05HKH\x91H\xd7I\x1dIcI\xa9I\xf0J7J}J\xc4K\x0cKSK\x9aK\xe2L*LrL\xbaM\x02MJM\x93M\xdcN%NnN\xb7O\x00OIO\x93O\xddP\'PqP\xbbQ\x06QPQ\x9bQ\xe6R1R|R\xc7S\x13S_S\xaaS\xf6TBT\x8fT\xdbU(UuU\xc2V\x0fV\\V\xa9V\xf7WDW\x92W\xe0X/X}X\xcbY\x1aYiY\xb8Z\x07ZVZ\xa6Z\xf5[E[\x95[\xe5\\5\\\x86\\\xd6]\']x]\xc9^\x1a^l^\xbd_\x0f_a_\xb3`\x05`W`\xaa`\xfcaOa\xa2a\xf5bIb\x9cb\xf0cCc\x97c\xebd@d\x94d\xe9e=e\x92e\xe7f=f\x92f\xe8'
# b'g=g\x93g\xe9h?h\x96h\xeciCi\x9ai\xf1jHj\x9fj\xf7kOk\xa7k\xfflWl\xafm\x08m`m\xb9n\x12nkn\xc4o\x1eoxo\xd1p+p\x86p\xe0q:q\x95q\xf0rKr\xa6s\x01s]s\xb8t\x14tpt\xccu(u\x85u\xe1v>v\x9bv\xf8wVw\xb3x\x11xnx\xccy*y\x89y\xe7zFz\xa5{\x04{c{\xc2|!|\x81|\xe1}A}\xa1~\x01~b~\xc2\x7f#\x7f\x84\x7f\xe5\x80G\x80\xa8\x81\n\x81k\x81\xcd\x820\x82\x92\x82\xf4\x83W\x83\xba\x84\x1d\x84\x80\x84\xe3\x85G\x85\xab\x86\x0e\x86r\x86\xd7\x87;\x87\x9f\x88\x04\x88i\x88\xce\x893\x89\x99\x89\xfe\x8ad\x8a\xca\x8b0\x8b\x96\x8b\xfc\x8cc\x8c\xca\x8d1\x8d\x98\x8d\xff\x8ef\x8e\xce\x8f6\x8f\x9e\x90\x06\x90n\x90\xd6\x91?\x91\xa8\x92\x11\x92z\x92\xe3\x93M\x93\xb6\x94 \x94\x8a\x94\xf4\x95_\x95\xc9\x964\x96\x9f\x97\n\x97u\x97\xe0\x98L\x98\xb8\x99$\x99\x90\x99\xfc\x9ah\x9a\xd5\x9bB\x9b\xaf\x9c\x1c\x9c\x89\x9c\xf7\x9dd\x9d\xd2\x9e@\x9e\xae\x9f\x1d\x9f\x8b\x9f\xfa\xa0i\xa0\xd8\xa1G\xa1\xb6\xa2&\xa2\x96\xa3\x06\xa3v\xa3\xe6\xa4V\xa4\xc7\xa58\xa5\xa9\xa6\x1a\xa6\x8b\xa6\xfd\xa7n\xa7\xe0\xa8R\xa8\xc4\xa97\xa9\xa9\xaa\x1c\xaa\x8f\xab\x02\xabu\xab\xe9\xac\\\xac\xd0\xadD\xad\xb8\xae-\xae\xa1\xaf\x16\xaf\x8b\xb0\x00\xb0u\xb0\xea\xb1`\xb1\xd6\xb2K\xb2\xc2\xb38\xb3\xae\xb4%\xb4\x9c\xb5\x13\xb5\x8a\xb6\x01\xb6y\xb6\xf0\xb7h\xb7\xe0\xb8Y\xb8\xd1\xb9J\xb9\xc2\xba;\xba\xb5\xbb.\xbb\xa7\xbc!\xbc\x9b\xbd\x15\xbd\x8f\xbe\n\xbe\x84\xbe\xff\xbfz\xbf\xf5\xc0p\xc0\xec\xc1g\xc1\xe3\xc2_\xc2\xdb\xc3X\xc3\xd4\xc4Q\xc4\xce\xc5K\xc5\xc8\xc6F\xc6\xc3\xc7A\xc7\xbf\xc8=\xc8\xbc\xc9:\xc9\xb9\xca8\xca\xb7\xcb6\xcb\xb6\xcc5\xcc\xb5\xcd5\xcd\xb5\xce6\xce\xb6\xcf7\xcf\xb8\xd09\xd0\xba\xd1<\xd1\xbe\xd2?'
# b'\xd2\xc1\xd3D\xd3\xc6\xd4I\xd4\xcb\xd5N\xd5\xd1\xd6U\xd6\xd8\xd7\\\xd7\xe0\xd8d\xd8\xe8\xd9l\xd9\xf1\xdav\xda\xfb\xdb\x80\xdc\x05\xdc\x8a\xdd\x10\xdd\x96\xde\x1c\xde\xa2\xdf)\xdf\xaf\xe06\xe0\xbd\xe1D\xe1\xcc\xe2S\xe2\xdb\xe3c\xe3\xeb\xe4s\xe4\xfc\xe5\x84\xe6\r\xe6\x96\xe7\x1f\xe7\xa9\xe82\xe8\xbc\xe9F\xe9\xd0\xea[\xea\xe5\xebp\xeb\xfb\xec\x86\xed\x11\xed\x9c\xee(\xee\xb4\xef@\xef\xcc\xf0X\xf0\xe5\xf1r\xf1\xff\xf2\x8c\xf3\x19\xf3\xa7\xf44\xf4\xc2\xf5P\xf5\xde\xf6m\xf6\xfb\xf7\x8a\xf8\x19\xf8\xa8\xf98\xf9\xc7\xfaW\xfa\xe7\xfbw\xfc\x07\xfc\x98\xfd)\xfd\xba\xfeK\xfe\xdc\xffm\xff\xff\xff\xdb\x00C\x00\x02\x01\x01\x02\x01\x01\x02\x02\x02\x02\x02\x02\x02\x02\x03\x05\x03\x03\x03\x03\x03\x06\x04\x04\x03\x05\x07\x06\x07\x07\x07\x06\x07\x07\x08\t\x0b\t\x08\x08\n\x08\x07\x07\n\r\n\n\x0b\x0c\x0c\x0c\x0c\x07\t\x0e\x0f\r\x0c\x0e\x0b\x0c\x0c\x0c\xff\xdb\x00Cz\x05\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc4\xc5\xc6\xc7\xc8'
# b'\xc9\xca\xd2\xd3\xd4\xd5\xd6\xd7\xd8\xd9\xda\xe1\xe2\xe3\xe4\xe5\xe6\xe7\xe8\xe9\xea\xf1\xf2\xf3\xf4\xf5\xf6\xf7\xf8\xf9\xfa\xff\xc4\x00\x1f\x01\x00\x03\x01\x01\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf8\xa6O\x8b_\xf0\x8c\xda\xdcEo=\xed\xbc\xf3@\xd767\x11\xfe\xfa\xc7P@7\x15\xdc\xb9\x00\xfdH<u\xe4f\xff\x00\xc1\xbf\x88\x7f\xf0\x99hM\xa9\xce\xa2\xde\xebP\x95fd\x04\xed\x18P\xa3\x07\xf0\xce\x0f<\xd7\xc0^\x15\xf1\xf7\x8a>\x1d\xc7\xf6=/V\x9c\xe9\xd7d\xa3A\xbb\xcc\x85\xb7pHS\x90\xacG\x1b\x97\x07\xde\xbe\x89\xf0\x07\xc7]\'O\xd4l\xb4{\x1f\x11.\x83\xaai\xee\xb6W\x96\xda\x8af\xc6\xfd3\x82U\xb3\x85e\xcey*N\xd1\x83\xeb\xf5\xf8\x1c\xc2T\xa99?$|\xfe+/\x8dIYu\xea}f\xd7\xcf"\xabnl\x17\xdd\xc8\xea{\xf5\xfc\xaai.D\x97\x1ec\x7f\x11\xc8Q\xd0w\xae\x0e\xc7\xe2}\x9f\x86\xb5k=/X\x92\xe2\x1f\xed$V\xd3\xeeY7[\xdc\x9e~@\xeb\x92\xad\xc7\x03\x04\x1e9\xc9\x00\xf6:~\xadk}\x0bI\x89#Up\xbb\xdf\x95\x07\xd3?\xcb=q^\xce\x1f2\xa5S}\x19'
# b'\xe1\xd7\xcb\xaa\xc3X\xea\x8d\x19\xfcC\xe4kV\xac\xa8\xa4\xb3\x99UX\xf4U\x03\x8e>\xa2\xadj\xda\xcf\xf6\xdd\xd1\x93\xee\xfc\xe4\x8ez\x0e\xb8\xfc+\x97;o|e\'\xef\x11\x96\xd6\xd7\nU\xb2\xa4\xbb\x1f\xc3\xa2~\xb5\xa1b\xad*M\xb8\x94X\xc8"\xbd/u\xea\x8e\'u\xee\xb3\x7fC\xb9\x92\xefV\xdc\xd9\x93\xe6\xdes\xed\x9f\xc3\x8e\xdfJ\xdb\xf1\x07\x8a\xda\xf6\xdb\xec0\xabI\xbb\x80s\x8d\x84\xf3\xfe{\xd7!\xa3kri\x93\xbc\x8b\xb7\xee\x94\xe4qR\xe8\xde [m~2\xc5\x99\xa2\xc4\x9e\xb9\x1c\x8f\xe9\xfaT\xb8_R\xa3+ht\xb0Gp \x1bS2\xdb\xfc\xa3p\xe9\xf8\xfe\x9f_\xce\xa3\xb1\xb4\xb9\xb8\xbf2\xc9\tm\xc4\xa0$\xfe\x1e\xd5\xad\xa9^\x8b8\x1a\xf6\t\x07\xcc\x9er\xab\xe3#8\'\xfc~\xb5\xcdA\xe2\xb9\x94M\'\x98Y\xe4vf\xe3\xa0\xdaG\xf9\xc5g\x1ef\x8de%\x16\x8d+\xa8\x11/\xbc\x9f\xb3\xb0\x8dSs\xc8\xa0\xe47=\x7f\xcf\xa5M\xa1\xb3$H\xb03\x7f\xac\xcb\xe4\xf5\x1dq\xe9W4\xeb\xc8m|-mq$\x8a\xf1\xb6\x03\xf3\x96-\xfc\xf8\xfaT7\xf2\xda\xd9Iu\x04M\xe5y@ya{\x9f\x7f\xeb\xfc\xaa9\xb5\xb1VKS\xac\xd2<Eg\xae\xda=\xbc1\xb4W\n\xdc\x87\xfb\xac:\x9e\xdf\xd6\xb0<G\xac\t5\xc8 \x93lq\xa0\xdc\xe4\x7f\x0fa\xfc\xf9\x15\x89\xa4jO\xa4M\x1b\x17h\xf76\xfd\xc0c\xb1\xfd\rW\x13\xb6\xbd\xac\xdc>\xf0:\x0c\xaf\xf9\xef\xfdj=\x8d\x9d\xcb\xf6\xad\xab\x1dN\x9fy\xa7\xbaF\xd3I\xb5Q\xc9,\xad\xc8\xfe}{V\x8d\xd6\x83\xf6\xeb\x04m\xb3\xc8\x18\x90\x87\xf8\x0e8\xfd\x7f\n\xe2l\x15\xac\xef\x04,\xa1|\xd1\xd0\x1eF\x0f\x1f\x81\xfe\x95\xe8\x92\xdf\x9b\x1f\x0cGu"\xff\x00\xa3B6\xc5*\xbfB0q\x8eG=\x8eA\x1fJ\xce\xa4m\xaa7\xa7;\xadN[\xc7^\x17}3\xc3\x0c\xd7\x81\x0bl/\x02\xb7\xdeLg\xbe\x7fA'
# b"\xcf8\xaf#\x9ai\x19\x95\x98`+s\x8a\xf5_\x89\x1e:\xfbO\x85#Y\x18\xc95\xd0\xc8\x04\x01\xb0g'\xa7=\xb1\xcf\x07\x1d\xab\x81\xd2\xb54\xb40\x1b\x85V\x8d\xdb2\x06\\\xeeS\x93\x9f\xc3\xf5\xad\xb0\xfc\xdc\xad\xb3\x96\xbd\x9c\xac\x88\xaegW\x8f\xfd\x12GX\xe4R\xb8c\xf3+p\x7f^\xd8\xa8\xef5;\xcb\xb8V\xd8\xab\x1d\xa0#s\xd4\xf4\xfdk\x7fM\xf0\xce\x97\xe2\xbdRH`3@\xef\x11\x95\x08\xe8\x18s\xfe}\xf1XWz\x0c\x9a}\xac\xd3Mt\xc1\xa3\x93n\x08\xf9\x9e\xab\x99lg(4\xbc\x8c\x1b\x98\x96+\xa6\x8f\x96\x0b\xc1'\xa8\xcf\xf8t\xa8\x92<>\xe0\xa7j\xaf$\x0f\xe7Z76\xdb\xa4o\x99y9\x18\xe4\xf6\xaa\xd7k\xe5\x8f\x97\x83\xd0\xe7\xbf_\xf3\xf8U\x19\x19\xe9\xb8+,\x9e\xb8\x04\x7f\x87\xe9OG\x01\xf6\xf6\xf4\xf5\xc5Y\x16bi\x82\xfd\xdd\xdc\x12GO\xc6\xba\x0bo\x85s\x8bH\xee\xa4\x91\xbe\xce\xdfy\xd5~d\x1e\xb8\xa9\x94\x94w5\x859Kc\x95{\xb6y>PWou5b\xda\xe2F\xc3*\xb3\xb0\x1d==\xea\xf6\xab\xe1\xc5\xf0\xf6\xaa\xf0\xdd\x07\xf2\xe3\x1b\x81Q\xf7\x87Q\xf9\xd5\xed\n\xd2\xde+\x85\x92\xdc\xba\xc9(s\x18\r\x96?Q\xd3\xfcqY\xcaQ\xb6\x86\x91\x83\xbd\x99\xf4\xff\x00\xfc\x13/\xfe\n\r\xaf~\xc6\x1e)\xd5\xa4m5\xb5\xad'\xc4\x89\x05\x93%\xdd\xd1\x8a\x1b'Y\x81\x12\x93\x82p\x15\xa5\x18\xe0e\xf3\x9e0\x7fp\xfe\x0c|c\xd0~<\xfc<\xb1\xf17\x86\xef\xa1\xbf\xd2\xef\xb7*\xc9\x13\x86\n\xe8\xc5]O\xd0\x83\xd7\xb6\x0e9\xaf\xe6\xc5Q\xf4\xe8f\x17\x0b&\xd8\xe5\xda\xac\xa7\x19n\xa7\xfc\x7f\n\xf7\x7f\x85\x1f\xb7\xef\x8b?g\x7f\xd9\x8b\xc4\x7f\x0f|;\xe2;\xcd-\xbcG\xa9E{\x04\xeb\x00\xfd\xc4\x0f\x14\x89r\xab&wF\xce\xcb\x06\n\xa9\xc0\x0cr\xb9\xc9\xf9\xfc\xcb+\xf6\xef\x9e\x9e\xe7\xb9\x81\xc7\xfb\x18\xf2T\xd8\xfe\x80\xe8\xaf\xc7?\x0f\xff\x00"
# b'\xc1x~,|/\xf1\x8czo\x88t\xdf\n\xf8\x9a\xd6\xce\xd2\xd6\xcai"\x97r\xdcH\x8a\xc1\xaeRh\xc8R\xd2\xee\x05\xb8*\n\x006\xf2\x0f\xd4\x9f\xb3?\xfc\x17C\xc0\xbf\xb4/\xc6=\x17\xc27\x1e\x1d\xd4<.\xda\xe5\xcf\xd9`\xbd\xbc\xbcG\x85\\\xac\x85C`\x0c\x16a\x12\x0e\xdb\xa4<\x80\x01>\r\\\xaf\x13Ms8\xddwG\xabO2\xc3\xcd\xf2\xa7g\xe6}\xd1Ec\xf8W\xc7z/\x8e"\x96M\x1bU\xd3\xf5D\xb7m\xb25\xac\xeb2\xa1\xdc\xcb\xc9\\\x8f\xbc\xac?\xe0&\xb6\ry\xe7}\xef\xb0QE\x14\x00QE\x14\x00QE\x14\x00R\x11\xe9KE\x00\x00\xe6\x8a\x08\xcd&q\xd6\x80\x16\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a)\xae\xd8\xa0\x00\xbe)\x0bf\x939\xa2\xa9D\x8b\x85\x14\x13\x8aFlU\x08S\xd2\x9a\xcd\x9any\xa0\xf4\xa0\x98\x88XSY\xb3JNE4\xf4\xaaH\x9b\x8c<\x7f\x8d%9\x97\x14\xdcU\x00QE\x15h\x02\x9a\xd4\xeak.zS\x01\xb4c&\x8a(\x00S\x83Lc\x93Ns\x81L\xa0\x06\x91M\xa73sM\xaa\x89\x0c)\xac)\xd4\xd6\xebT!\xb4\xd7\xe9N\xa1\x86h\x023M+\x9as\x0ei\x1cdUD\x06R\x15\xa5=h\xaa3\x1b\x8c\xfd)\xa4S\xc8\xa6\xb6*\xa2A\x11\xa4e\xa7\xb7\xf9\xf6\xa6\x1f\xd2\xad\x162\x90\x8d\xd4\xa6\x91\xbaU\x80\xd6\xe0\xd2R\xb0\xdbIA2\x1a\xc34\xde\x95\'ja\x14\x12%5\xc6i\xd4\x1a\xa8\x82\x18\xddi\x0f4\xe6<\xd3h\x01\x84b\x92\x9c\xc7?\xe7\xad6\xa4\xcck-4\xd4\x84\xe0Tg\xadTIcYy\xa6\xd4\x84\xd4g\x8a\xa2C\xad4\x8cS\xa9\xackTf\xc6\xd20\xc8\xa54U\x81\x19\x184\x85i\xee)\xb4\x01\x1b&E1\x97\x15+\x1c\xd3OJ\xb8\x99\x912n\xa6'
# b'\xb2\xe0\xd3\xe9\xac3L\x06\x9eE7n)\xc7\x8a(\x01\x9bi\x18dS\xcfJB\xbc\xd6\x86d$|\xb4\xd6\\\n\x91\x87\x1d\xe9\xbd(\x02:k.*G\x1d\xe9\xa4dU\xa2d\x88\xe9\xa5jF\\Sj\x91#\x18`\xd2\x1aq\x14\xda\xb4\x031\xcd%<\x8ak\x0c\x1a\x00\x8d\x81\xc5!\x15 \xa8\xc8\xc5hfFV\xa3"\xa6+M+\x9a\xa8\xb36B\xc34\xda{u\xa6\xb7&\xb6@%5\x97\x14\xea\x08\xcd\x06dl\xb5\x0b\xae\x05O"\xe3\xda\xa3d\xa0\x96D\xc3\x8aa\x19\xf5\xa9\x1d}\xa9\xa4V\x91\x91$Ds\xedC\x8c\x8f\xce\x9cG\x14\xd2+C2\x16\xe9Q\xb7J\xb1*b\xa1q\xcdi\x16\x1b\x90\xb0\xcdF\xc3\x15;\x0e*&\x19\xad\x08z\x1f\xc8\x1d\xb7\xc3\xf8\xf4\x1f\x1e\xc7\xa7[\xc9$\x8a/U@\xcfQ\xb8\x0czVO\x8fl\xbc\xbf\x13^&\xb5\xa7O\xa7\xdcI+0\x93i\xe4d\xe3\xff\x00\xd7^\xa3\xf0\xafL\xff\x00\x84\xb7\xf6\x84\xd2c\x03z\xcfy\xe6\x1ct\xc7\'\xfa\xd7C\xfb^x~=_\xe2\x0e\xa1%\xc7\xdb\xa1M6x\xec\xe4D\xb1\x13\xc2a\x90\xab.\xc9\xe3 F\xc5\x94\r\x93\x00F\xf6\xc3\x11\x81_\x11Y8a\xe0\xa3\xd4\xfb:>\xf5V\xe4y_\xc3\xbf\x8d~5\xf8C\x04cB\xd6?\xb4\xb4\x98\x9f\xcc[+\x91\xe7\xc0\xa7\x9eB\x9eT\xfb\xa9S\xcf\xe1^\xbf\xe0\x8f\xdbG\xc3\xde!\xf1\r\xad\xd6\xa9.\xab\xe0\xfdA\x90E\xa8\xc7\x17\xfaE\x86\xa2\xa1p\x0b\x0c\x16\x8d\xba`\xe0\x803\xf3\x02s^y\xa5~\xceW\x1e+\x87T:\x1d\xc2Z\xeb\x9a1\xff\x00N\xb4\x83t\xb6\x91\x1e\xc8&\xc6\xd6a\xd0\x80H\x04\x1eN\x0e8\rGB\xbb{\xa9\xeduK\x1f&\xea\xdeA\x1b:\x0eO^\xdf\x8fP{\xf4\xaej2r\x97*\xba6\xa9\x18\xda\xec\xfbg\xe0\xef\x8d-4\x8d\x1duK\xc9\xaf#\xb1\xd6.\xdcGu\x14~l(K\x0f,8\x19+\xb80\xc1\xe0{\xe4\xf3\xebP'
# b'jJD\x9f+\x01\t\xcc\x8d\x8f\x94g\x81\x9f\xaf\xbd~z\xea~.\xf17\xc3\xef\x1b\xcd{\xe1}bkSn\x91[\xc9\x0co\xba7\xf2\xd5F\x1d\x0eU\xb0FpA\xc1\xe7\xaf5\xe9\xbf\x0f\xbfn\x0b]o\xc4V\r\xe2\xff\x00\xed\x0f\x0e\xea\x10\xaf\x93q{\xa7|\xd6\xb7\xb1\xf3\xf2\xcd\t\xc9^\xb9\xdc\x99>\xc3\x82=\xaf\xed9\xd2\xaa\xd2\xdbc\xc9\x96]\x1a\xb0R{\xb3\xec;Q\x1d\xd4\x8a\xa8\xdbC6X\xe7\xb7z\xab\xa69\x9b\xc4z\x84\x8aWm\xbb$(s\xd7\x03w\xfe\xcf^n\xff\x00\x13\xc5\x8d\x8c\xf7Z^\xcdGK\x9a\x06\xb8\xb1\xd5\xacgY\xad\xdbj\x82\xd1L3\x95q\x9e\x98\xcfOz\xea>\x0ckW\x1e0\xf0\xc2\xdeL\xb1\xad\xd5\xd3\t\xe6\xda\xdf*\xb3\x01\xc6:\xaeq\xc6x>\xbe\xbe\xf6\x0f2\xa7R\r\xbd\x0f\x17\x11\x97\xce\x9b\xd3S\xba\xbe\xd7\xa5\xbe\xb4\xc4\x921\xe3\xcb\\zq\xc5f\xa4\xe22\xca\x1b\xaf\xe9R^\xdbInR6\x8d\xc1\xed\xc7_\xf3\xedT\x96=\xcew\x1d\xbf0\x00\x9e\xff\x00\xe7\xd2\xbd\n|\xb2Z\x1e|\xa2\xd3\xb34d\xd7..\xad\x16\xdcH\xcd\x1a\xae\x02\x8e\xc6\xaeO\xa9\xb5\xc5\x8e]\x98\xcc\x85I$\xf2z\x8f\xd3\x8fz\xc1\xd2\xf5T\x95\x05\xc2\xfc\xca\xe1\x8a\xf1\xd5I$~\x95j\xca\xf5\x9dd\xff\x00i\xb0;{\xd2\x94<\x83SJ{\xe9\xae\xb6\xfc\xcc\xcc\x15c\x06\xb5\xac\xa5]\x1bQ\x91\x1b\xed\x0b\xfb\xb0\xa5\xd7\xe5\xf9\x8e:\xff\x00\x9e\xd5\x81o,k$~c2\xa6\xeeH\xab\x9e \xf1\x01\xd4/Y\xa3\xcf\x96\xa9\xc8\'\xef7\x1c\xfa\xd6R\x8fb\xa2\xed\xa9\xd5\xd846\xba\x9a*\xff\x00\xa47\xcc\x89"\xf7;A\xe7\xbf\x1d\x7f?Z\xeat\xcbv\x1e\x13\x99.%\x8d\xad$\x8fa\x86O\x94\x06\'\xa8>\xa3\xae\x7f\xc2\xbc\xafC\xf1\x04\xb6\xf7*\xe78\x85\xc4\x98\xff\x00>\xbf\xd6\xbb\x0b?\x88\xf6\xc9\xe1\xdb[{\xb8\xdaf\x8c\x92s\xfc\x03p\xc0\xfc\x8f\x1f'
# b"B;\xd7-X\xca\xfa\x1dtj\xc7i\x19>5\xb3\x8fH\xd6\xfe\xca\xad\xfb\xa8\xc0!\xa4\xea\x01\xe7\x1e\xfcq\x9e\xf5\x91(\xb5\xbc\xb5\x8dm\xc2\xbb0\xc6\xc2\xb9\xc1\xf4\x15\xdb|I\xd2\xff\x00\xe1'\xb0\xfbtPI\x19\x11\xeeI\x01\xdc\xac\x9dq\xf8u\x1d\xf1\\,~\x15\x96\xc2\t\x19\xa6\xfb\xd1\xee\x8d\x94}\xefo\\\x8fJ\xd6\x8c\x93\x8e\xbb\x91R2M\x9a\x9e\x17\xd4\xcd\x95\x85\xd4\x0c\xado0]\x8e\x81v\xb2v\x18\xef\xefX\xba\xdc\xb8\x8e8fe\x93o,\xc3\x8d\xfd\xf9\xa7Y\xdbj\x1e \xd5\xcb\x06\xf2\xe4a\x89\\\x0ceF\x06Os\xe9\xf8V\xdbx[K\xfe\xca\xba\xddu\x19\x93\xe5\x8a\x13!\xda\xc2N\t\x07\xe8;\xf4\xc9\x03\xde\x94\xb9b\xeeM\xe5%c\x86\xb8\x7f._\x94\r\xb9\xc8\xedRKo\x04\xb0\xac\xbb\x84\x93c.\xb8\xe8y\xfc\xff\x00*\xb5\xafhri\xc8\xd1\x9d\x8eT\xe3r\x1d\xd8\xef\xf4\xf7\xfck\x1e4x\xddU_\xefu\xf7\xadU\x9a\xba1\xd9\xd8\xb5f\xebw{\x1a\x1c*\xee\x0b\xd3\xa7A\x9f\xc2\xbdcJ\xd5!\x87L\x86\xdb\xccI$\xdb\x96\xd8\xdf(a\x8f\xe7\xda\xbc~ \xc6WUc\xc9\xc1\xad+=Z\xe2\x1b\x08\xf6\xb6<\xbf\x94\xf09\xe7?\xe7\xd2\xb0\xadM\xc8\xdf\x0f[\x94\xed\xbcM\xb7\\\xb2Y.-\xd43\x1d\x9b\x88\xce\xd5\x1c\x91\x9e\xbd}{\x11Y\x9a\x0f\x87\xadl\xf5?&8\xe6Y\xb6\x10\x1c\x01\xc0l\x90\xd8<\xf1\xdc\x0e\xc3\xebW4\xddmnt\xe8v\xed\xc5\xc2\xe2S\xd0+}:r8\xed\xfaU\xdb;x\xc4W\x17\xd1\xb7\x98\xd1\xae\xfc\xee\xfb\xbbF?\xfa\xd5\xcb\xca\xe2\xacv\xdd7r\x8d\xcf\x87\xee.t\xaf%\xae|\xe6\x8ea\xbb\x03ha\xfes\\\xef\x8e\xe1\x82\xd9\xee!o\x9b\xe7\xfd\xc0\xcfO\x94\x1f\xcb\xfa\xd7q\xa6Z\xcc\x08\xb8\xdd\xfb\x96\xe7\xe5\xec9\xc7\xf5\x1fLW\x03\xf1\x93T\xfb/\x88!\x850\x1b\xcb\xdeF:d\x9f\xe7\x8a)_\x9e\xc2\xac"
# b'\x97\xb3\xb9\xcf\r]\xadL\x90\xc4\xef\x1cr\x15g@~V# \x1fN2pOL\x9a[;\xff\x00\xdfed\xc2\xe7\x93\xcf\xff\x00\xaa\xb3\xda}\xf2\xee]\xbb\x9b\x8f\xadF\x17dN?\x8d\x8eF?*\xee\xe5G\x05\xf5;\xaf\x07\xfcr\xf1W\xc3mUf\xf0\xfe\xbd\xac\xe8\xed\x13\x03\x1bY\xde<D`\x92>\xe9\x1f\xden\x0f\x1f1\xf59\xfas\xe0\xb7\xfc\x17\x1b\xe3\xaf\xc3\x9f\x145\xd6\xad\xafC\xe2\xabY\x96$\x96\xd7T\xb7S\x1e\xd4\xc0\xca\x14\xdaU\x99F\x0b\x02rI$\x13\xcd|Wo9\xb7\n\xc5\x9b\xccS\x9e?/\xd3\xfa\xd4\xd1_*E(!\xb2\xd8\xda\x07j\xe3\xad\x81\xa3SI\xc53jX\xaa\xb4\xfe\t4~\xe2|\x07\xff\x00\x82\xfb\xfc\'\xf8\x95uoi\xe2\x8b\x1dW\xc1\xb7WW&$\x96L]Z\xc6\x9f.\xd7\x91\xd7\x0c\xb9%\xb3\x85 m\xcey\xaf\xae\xbe\x1b\xfe\xd1^\x01\xf8\xc3v\xb6\xfe\x15\xf1\x9f\x86|Ar\xf0\x9b\x81\x05\x86\xa3\x14\xd3\x08\xc1\x00\xb1Eb\xc0\x02@9\x1d\xeb\xf9\x83[\xa2Y\x15r\xa7\xa6s\xd0V\xf7\x85~"k\x9e\x08\xbdk\xad\x1bX\xd44\xbb\xa6\x88\xc6e\xb6\xb8hY\xd0\x90\x197)\xce\x0f\xa18 c\x9a\xf11\x1c?\x07\xad)[\xd4\xf5\xe8\xe7\x95\x16\x95\x15\xff\x00\x03\xfa\x94\x07"\x8a\xfeu~\x07\xff\x00\xc1K\xbe4~\xce\xfa\xbf\x9d\xa6\xf8\xe7V\xba\x86@\x19\xedo\xae~\xddn\xc0\xe5\xbe\xe4\x85\x82\x92N~\\\x1c\x923\xd4W\xe9\x97\xec)\xff\x00\x05\xc1\xf0\xbf\xed\x0f\xe2m\x17\xc1\xfe1\xd3\xee4?\x15kW\x8bceu\n\x06\xb2\xb9vQ\xb09\xceQ\x9aO\x90`\x15%\x97\xee\xe7\x03\xc7\xc4\xe55\xe8\xaem\xd7\x91\xea\xe1\xf3J5_.\xcf\xcc\xfb\xe2\x8a(\xaf0\xf4\x82\x8a(\xa0\x02\x8a(\xa0\x06\xe3oN\x9e\x94\xe5m\xc2\x8ai\\\x9fz\x00u\x14\xd5npx?\xce\x9d@\x05\x14Q@\x05\x14Q@\x05\x14Q@\x05\x14Q@\x05\x14Q'
# b'@\x05\x14Q@\x05\x14Q@\x05\x14Q@\x05\x14Q@\x05\x14Q@\x05\x14Q@\x055\x86\x05:\x8cP\x04tS\x99i\xb5\xa1\x98\x1eE4\x9cS\xa8a\x9f\xff\x00U\x00GM&\x9d\x8c\xd27\x06\x84M\x86SO\xff\x00\xaa\x9dHx\xad\t\x18h\xa0\xd1@\x05\x14QZ\x00SO\x02\x9dMc@\r\xa2\x8a3@\rc\xfe})\xb4\x1e\xb47J\x00i\x19&\x9bNbi\xb5h\xcc)\xa4\xf3N\xa6\xb7\x14\xc0m\x04\xd1H\xc7\x02\x80\x1ai\xacqJhaU\x11\x0c\xcf4\x94\xa6\x92\xa8\x81\x0f\x0bLa\x9c\xd3\xdb\xee\xd3\x0f"\xaa&hk\x1c\x9a\x8d\xeaFj\x8d\xb9>\x98\xab\x8e\xe6\x83i\x18\xe0\xd2\xd3Z\xac\x06\xd1E\x14\x19\xb1\x18\xd2\x13\x91C\x1ai\xa0\x02\x90\xd2\x9aF<U\x00\xc3GJ)\xa4\x12jHv\xe84\x9eh\xa2\x8a\x04\x07\xa5GNc\x8f\xe7M\xad\x11\x0cF4\xc3\xd6\x9e\xc7\x14\xc3U\x12\x1b\xd0\t\xa6\x96\xf6\xa7S[\x83\xd0V\x91$m\x04\xd1H\xdfv\xa8\x04/\x9am\x06\x90\x9c\n\tb1\xc7\xad4\x9c\n\x1b\x83McVH\x8d\xd6\x9a\xc34\xb4\xd2i\x80\xda(\xa2\x80`y\xa4c\x81KHETL\xc6\x1acu\xa7\xb9\xcd1\xba\xd5\x00\xc6\xe4\xd3OZ{\x0c\xd3H\xc1\xaa\x88\x98\xd6\x19\x14\xc3R\x1acu\xaa Jc\x7f\xf5\xe9\xf4\xd6\x19\xaa\x88\r\xa6\xb0\xe7\xfc\xf3N\xa0\xf4\xaa\x02:k\x8c\xd3\xc8\xa4\xaa\x88=H\xcdF\xc2\xa6u\xe6\x98\xc3"\xa8\xcaH\x89\x97&\x98W\xfc\xfa\xd4\xac)\xa4g\xf0\xad#"\x08\x88\xc7Z1\x9av3M\xc75\xa1-\x08zTl\xbb\xaaC\xcd#.M\x04\x908\xc9\xa8\xc8\xab\x0e\xbf\xfe\xaa\x8d\x96\x82\x1e\x84.3M<\x8a\x90\xf5\xa60\xc3V\xd1\x95\xc8h`\x19\xa8\xdcs\xd2\xa6\xa6:\xf1\xfd*\xd1\x1b\x15\x9a\xa3q\xcdXe\xc5D\xe3"\xb5\x88\x9a?\x8f\xbf\x85?\x1a\xe6\xf8\x7f\xe29\xb5\x8b\xd6hu+x\xc0\xb7\x91"\xdd\xb9\xb2\x01%'
# b'~\xef\x03$\xf4\xcf\xd6\xbd/\xc5_\x18t_\x8f\xd0\xcc\xd7\x11\xe9zf\xa1\xa8[5\xb5\xf5\xf5\xb5\xab?\xda\x07\x05\x1eDVI7+\x05\xc6K\xa9\x1f\xc2x\xae#\xc4_\r\x92h\xc9\xf2\xc3+p\x0e8?\xfe\xaa\xe1\xf5\x9f\x87\xd7\x1aL\xbeu\xa3I\x1b)\xc8\xc1 \xaf\xe3_\x0f[\xdar\xa8\xc9]/\xbc\xfbHr7u\xa3>\xbf\xfd\x944\xeb\x85\xf8s6\xa5u\xaf}\xb9E\xb0\xb2M>\x05\xfb=\xbd\x9e\xc3\xb5\xb3\x08\x00\x168\x0c$8f\x0cx\x15\xe4\xbe"\xd1\xbf\xe1&\xf8\xc2\xb6\xd1\xa6~\xd5~\x91`w\xf9\x80\xfe\x95\xe4\xbe\x1a\xf8\xb7\xaex*\xed|\xd6\x9d\xb1\xc7\x9b\x1b\x98\xe5\x03\xfd\xe1\xc3}\x18\x1a\xf5o\x80\xdf\x11\xb4\xddS\xe2\x96\x9f\xab\\4\x97\x16\xbat\x9fk\xb8\x04\x05\x98\x9e\x07N\x07S\xc6\x0e+L\xbd\xc5\xd6^_\xa1\x9e%IE\xb2?\xda\x93\xe0\xbd\xaf\x80\xbe(\xc9\x16\x8a\xba\x8d\xb8\xb88k\x86B\xd6\xf2L\x18\x191 \xcamU,\xc4\x12\n\xec`@\xe0\x9f7\xd74{\xcb=*\x1b\x9dSO7Zu\xc0\xcc7\xf0&c\x90r3\x9a\xf7\xaf\xdab\xd2\xd7\xc4\xba\xde\xad\xe2O\rM\x1e\xb1\x1d\xf3\xc7\xa9-\xbc\x16\xd7\x03\xcax\x80\x12Gq\x14lU\xf7!|\xbb\xa2\x82\xa4\x8d\xe7\xa1\xeb>\x05\xe8\x96\xfe%\xf8m\xafMy\xa5\xeaMg|\xf1\xca\x97:\x9b\xed7\x05\x97w\xee\xed\xb1\xb6\x18@a\xb7i \x829\xe3\x03\x86\\\xcaM\xa3\xaa2\\\x88\xf9G\xc1\xff\x00\xda\x1aN\xb3\n\xe8Z\xb5\xd4V\xfa\x8b\x88\'H\xa5+\xe6) \x15u\xe8G\xb1\x06\xbd\xe3\xe1\xf7\xed\x87\xa0\xf8{\xc7V\xf1\xf8\x87N\xd4\xb4\x994\xc2\xd6I\x7f\xa6\xca|\xab\xb8A!D\xf1u$pw)9\x03\x1bpk\x8b\xf0\xc7\xc3\xc4\xbf\xf8\xa7g\xa7\xe9\xb0\xc6\xac\xf7\xcea\x18\xe8y#\xf9\n\xe2\xfck\xa0\xea\x9e\r\xf1\r\xde\x97\xaeY\xa5\xe4\x96\xf2\xb4n\xc8>l\x80\xacq\xeb\xf2\xba\x9c\x8e'
# b"\xa0\x83\x9a\xee\x94\xbd\x9d\x08\xdfNf\xdf\xe4s\xe9R\xa3\xb7D~\x82|:\xf8\xb7'\x8dV\xf0\xda\xbe\x9d\xaehh<\xfb=N\xd2\xe4I\x90O\xfa\xa9#?4r(\xecB\xe4d\xe3\x81\x93]\xf8\x95\xa3\xc5\xe1\x8b]B\xda\xf2\x1b\x88\xef$1\xc6bm\xfbd9\x01XpT\x83\xc1\x04df\xbf;\xbc)\xaaj>\r\xd6\x13T\xf0\xa6\xb5y\xa6\xdfBr\x04r\x18\xdf\x8epGF\x1e\xc4\x10}+\xd5~\x1b\xfe\xd2\xd7\xbe'\xd7\xd6?\x14i\xf6\x16\x91\xd9\xcd\xfd\xa5\xa8_Y[\x08e\xb9\xd8\x9bw:.\x15\x9b\x91\xf7p3\xdb'5\xd9\x97\xe3jF\xa2I\xe9\xf8hq\xe300\x94n}\x89\xa6\xa2\xc1a\n\xa6J\x88\xd5F:\x1c\x00*\xfc\x12y0(oZ\xe4>\x12|N\xb6\xf1W\x81\xee\xf5\x08\xf5-'^\xb3\xd3\x980\x9fMVi\x9a\x1c\x03\xbeXp\x1a7\\\xe0\x829\xdaOL\x13\xd5[\xebzn\xbbc\x15\xce\x9bp/-nc\xf3a\x9a Y]}}x\xee\x0f \x82;W\xbfG8\xa57ihxu\xf2\xca\x90\xd6:\x96\xc4\xa8m\xe3\xdc\xc7t\x92\x14\x18\xed\xf2\x96\xfe\x9f\xadCh\xbe|\xbbw\x15\x0b\x92MR\xb4\x9dou(\xbc\xb9#\x9a;x\xdd\xdf\xcbp\xc1I*9\xfdz\xf2+SO\x87\xca\xb5\x91\xc7\xf1d(\xafO\x998\xde,\xf3e\x16\x9d\x98\xe3'\x94\x8c\xdb\xd5\xb3\xc6G\xe5\xcdX\xb6\xbe\xdc\xad\xb9\x95\xb6\x8c\x11\xf9\xff\x00\x9f\xca\xb2\xe3f\x13'\xfb\\\xe3\xfc\xfd*x\x99|\xbf\x97\x83!'\xa7Q\xc8\xff\x00\xeb\xd2\x94t\xd4\x11\xea\x9aW\x88&\xb3\xf0\xb2\xc7\x0c\x96\xf7I=\xa8tUna=>o\xa1\xe0\x82\x00\xe3\xadr\xe7Rh\xed\xbc\xbb\xa1\x84\x8cpOq\xd3\xfc\xf7\xa6\xfc4\x95lg\x95\x9d\xb8u\x11\x0ez\xe7\x9e\x9c\xff\x00LV\x86\xb2\xd6\xfa\xad\xb3}\x9eO\x9b\x90P\x8c\xe0\xfbu\xfc\xab\x89\xda2;9\x9b\x82fM\xaf\x8a\xe3\xb1\xd2n\xa1\x8e"
# b'\xdd\x16K\x86%e=H\xe3\xf9v\xacK\xcb\xd9\xb5;\xd9\'\x9eO\x99\xfeb\xdbv\x82zq\xda\xa4\xba\xb3f+\n\xa7\xdc\x04}*\xac\x85\xa2\x80*\xedc\xc0 \x1a\xda1[\xa3\x96S\x93\xd1\x8d\xfb\\\xd7\x10I\n\xb1!NNOz\xaf\xf6_,|\xc3kg+\xf4\xff\x00>\xb5+\x9f\xb2\xc9\xb1\x943\x16\xcb0=zTW7>am\xbcv\x04w\xad\x11%\xcd+\xc3\x97Z\xa4SIn\xa5\xcc}\x00\xeaz\x7f\x9e\x07z\xcf\xba\x8eK[\x85\x85\x95\x95\xba\x10j\xf6\x95\xa8\xc9\xa5L\xb2E$\x91\xc8\xcaA\xda\x7f\nv\xb4\xeb\xabK$\xd9\xdb#\x12A\x1cc\xbdg\xad\xf5\x0b\xabi\xb9\xab\xe0\xadn8\xd9a\xb8\xda \x857d\x1d\xacF\x7f_\xa7\xb5T\xf1\x07\x88\x96\x18\xae\x12\xcd\xe4X\xa5b1\x9e\xab\xd3\xfa\xfe\x95\x90\xc9\xe5w;\xb1\x8a\x8a`n"\xc0\xea?J\xcf\xd9\xa6\xee\xcd=\xb3\xe5\xe5=\x03\xc2\xfe8\x8e\xcf\xc3\xf6\xf2H\xcc\xcd\x1a2\xb2)\xe4\xb0\xe0~}\x7f:\xe3|q\xa6\xc9\xe2+\xe6\xbc\x7f\x95\xb0\x0e\xd3\xd5z\x9a\x87L\xd5\x8e\x90\xb2\x15\x8c4\x85p\xa4\xff\x00\t\xf5\xff\x00\xf5\xd3\xb5=w\xfbB\xd9\xc2\xfc\x8d!\xcb\x11\xdf\x81Q\x1aJ2\xba5\x95nhY\x9c\xff\x00\xd8>\\\xe1\xb7\x01\x8cz\x9e\x94\xd3h@\xf9\xb7nP?\xcf\xf9\xf4\xad\x08\xaf\r\xa1\\a\xb0s\xef\xda\x9bs*\xdc<\x8eG\xcc\xcd\x9a\xdc\xc1H\xcbx[\x1b\x99{\xe3\xebA\x1b\xb6\xaa\xb0\xe9\x9eFs[\x16&\xd1\xf4\xf9\x9aO\xf5\x99!\x07\xe1U$\x829#.\xa0nc\xb4\xafN\x9f\xe7\xf3\xa5}lhP\xf31/\xa7\xd2\x9c\xd7M\x10e\xdcY\x00\xcf>\xbd(\xfb\x04\x84\x19\x11w\x01\x9c\xf1\xd2\x9a\xda|\xa4\x8926\xe7\x04\xe6\x95\x90\x16-\xef8a"\xe4:\xf0=\x0f\xf9\xff\x00<\xd6\xdf\x84\xf5X\xed>\xd0\xc9p\xd6\xb7\x90\xaaKm(\x90\xc7\xb1\xc3\x03\x9c\xe0\x9c\x8cq\x82\x08<\xe7\xa8'
# b'<\xf1\xb3\x98\xb7\xca\xbf+\x1c\x8d\xdf\xe7\xf5\xa6\xba<J\xc3\xa3m\xe9\xe9Y\xca\t\xe8i\x1d\x1d\xcf\xd7_\xf8&_\xfc\x16\xe3I\xd3>\x1e\x9f\x08\xfcd\xd4\xee"\x9bD\xb6\xdd\xa7k\xa2\x030\x9a\x08\xd0\x8f*p\xb9v\x90m\x01\\)\xdd\xbb\xe6 \x8d\xcd\xf7?\xc1\x7f\xdb\xd3\xe17\xc7\x8b{_\xec\x1f\x1ah\xbfo\xba\xb5\xb6\xba:}\xd5\xca\xdb\xddB\'\xc0\x8d\n\xb1\xc1\x93q\nU\x0b\x10J\xff\x00xg\xf9\xa3\xb7\xbah\x95W\xdb\x9f\xf3\xf8\xd6\x87\x87\xfcU\x7f\xe1\x8dZ\x0b\xcb\x0b\xcb\x8b;\xbbY\x04\xb1K\x13\x94x\xd9H*A\x18 \x8cd\x11\xc8 \x1a\xf0q\x19\x04&\xdc\xa0\xed\xf9\x1e\xc6\x1f8\xa9\x04\xa35\x7f\xcc\xfe\xab\xa8\xaf\xc9\xaf\xd8G\xfe\x0b\xf8\xfe\x1f\xd0\xb4\xef\x0e|d\xb6\xbc\xd4B\xbb\x8f\xf8Im\xdb|\xe16\x92\xa2XB\xfc\xff\x007\x1b\xd5\x81\x00\x8f\x94\xe3\'\xf4O\xe0\x9f\xed\x95\xf0\xcf\xf6\x8b\xd5\xaf,|\x1b\xe2\xcd?\\\xb8\xd3\xed\xd2\xea\xe1a\xc8\xf2\xe3a\xc6r\x061\xdc\x1e\x95\xf38\x8c\x1dj.\xd3\x8f\xcf\xa1\xef\xd0\xc6R\xaa\xaf\x17\xf2=J\x8a\x8e\xde\xe6;\xb8VH\xa4I#a\x90\xc8\xdb\x94\xfe5%r\x9d!E\x14P\x00FE7\x95\xf7\x1f\xca\x9dE\x00\x00\xe4QMe\xfe\xef\xff\x00\xae\x946h\x01h\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00\t\xc50\xf0)\xf4\xd7\xe9A2\x1bA\xa2\x83\xcdhH\xd6\xfb\xdc})\xa7\xa59\xb9^)\x84PK?;\xbf\xe0\xe1\xcf\xda+Y\xf8i\xf0\x1f\xc2\x9e\x07\xd1\xee\xee,c\xf1\xd5\xdd\xc3\xearB\xe5\x1ak[u\x8f0\x12?\x81\xdee,;\x88\xf0x$\x1f%\xff\x00\x83r>1\xf8\x92\xeb\xe2G\x8d\xbc\x0b>\xabuq\xe1{}\x18j\xb6\xd6\x12\xc8^;;\x81p\x88\xcd\x10\'\t\xbcJ\xdb\x82\xe3q\nO"'
# b"\xaf\xff\x00\xc1\xcb7k\xfd\xb3\xf0\x86\xdf\r\xbcC\xaa\xc9\x9e\xd8-h?\xa5q\x1f\xf0n'\xfc\x9d\x1f\x8e\xbf\xecU?\xfaWo_\xd1YV\x06\x82\xf0\xda\xa5NEy)\xc9\xbbuU\x1cS\xf5I$\x8f\x073\x9bX\xbaq]9\x7f\x16\x9b\xfb\xd3\xb7\xa6\x87\xece\x14\x1e(\xaf\xe7\xa4{\x87\xe7\x8f\xfc\x1c5\xfb@x\x93\xe1\x97\xc1\x1f\x06\xf8GC\xd4.t\xdb\x0f\x1c\xdc\xde\xae\xac\xf6\xf2yoso\x02D>\xceH\xe7\xcbs>X\x022\x10\x03\x90H\xaf\x05\xff\x00\x83t\xbe*k\xd6\x7f\xb4\x7f\x8a\xbc\x16\xba\x8d\xc3xf\xfb\xc3\xf3j\xef`\xceZ\x14\xbb\x8e{h\x84\xc8\xb9\xc2\xb9I\n\xb1\x03,\x15\x01\xce\xd5\xc7e\xff\x00\x07*\xdc\xc6uO\x840\xee\xfd\xe0\x8bU|c\xb6m\x05y\xdf\xfc\x1b\xa1\xa6\xfd\xa3\xf6\xc2\xf1e\xd6\xcd\xdff\xf0\x94\xcb\xbb?wu\xdd\xafo}\xbf\xa5\x7fFd\xb8:\x10\xf0\xe2\xac\xdc\x15\xe5\x1a\x92n\xdb\xb56\xa2\xfdRJ\xde\x87\x87\x9aM\xac]8\xf6q\xfcZ\x7f\x93\xfb\x8f\xd9\xa3L'5\xf2\xb7\xfc\x14k\xfe\n\xa7\xe1\xef\xf8'\xf5\xfe\x8d\xa3\xb7\x87o<]\xe2\x8dj\x1f\xb6\xa5\x84wb\xca\x0b{P\xcc\x9el\x93\x14\x90\xeegV\n\xaa\x87;\x18\x92\xb8]\xdd\x17\xeck\xff\x00\x05 \xf0O\xedi\xfb=j~>\xbak\x7f\x03\xc3\xe1\xbb\x8f\xb2\xeb\xb0j\xb7\xd1\x884\xd7!J7\x9e\xdb\x15\xa3p\xc0+2\xa1,\x18m\xe0g\xf1G\xc39\xa2\xcb\xe3\x9a\xfb\x17\xecd\xec\xa5\xa6\xad\xbb-/\xcdf\xf4N\xd6oK\x9e\xbc\xab\xc25U\x16\xfd\xe7\xb2\xfc\x7f-}\x0f\xa1\x8fJk\x1a\xf8\x83\xc7\xbf\xf0p/\xc0\x7f\x08x\x92k\r>\xdf\xc7^(\xb6\x8dT\xae\xa1\xa5\xe91%\xb4\xa4\x8c\x90\xa2\xe6he\xc8\xe8s\x18\x19\x1c\x129\xaf\xa2\x7fe\x7f\xdbS\xe1\xcf\xed\x9b\xe1i\xb5O\x01\xeb\xcb\xa8Ib#\xfb~\x9f<Mo}\xa73\xa8`\xb2D\xdd\xb9+\xbd\x0bF"
# b'\xcc\xac\x15\xdbi\xc3\xc7p\xaeo\x83\xc3\xfdk\x15\x86\x9c!\xdd\xc5\xab_\xbfo\x9d\xb5\xd0K\x13I\xcb\x91I\\\xf5Bri\t\xe6\x94\xd7\x9b\xfe\xd0\xdf\xb5\xd7\xc3o\xd9KH\xb7\xbc\xf8\x81\xe2\xed3\xc3\xabxqo\x04\x81\xe7\xba\xb8\x19\xc1d\x82%yYA\xc0,\xa8Ur2FEx\xf8|5lEEG\x0f\x079=\x92M\xb7\xe8\x96\xac\xd2R\xb6\xafdz1\xa6\xd7\xc1\xb7\x1f\xf0q\x0f\xc1(.$\x8d|7\xf1>dG H\x9am\x96\xd7\x03\xb8\xcd\xd88=y\x00\xfbW\xd5\x1f\xb3\x7f\xed\x7f\xf0\xe7\xf6\xb6\xd0n\xb5\x0f\x00x\xa2\xcb][\x16\x0bwo\xb1\xed\xee\xed\t\x1cy\x90\xc8\xab"\xa9\xe4\x07\xdb\xb5\x8a\xb0\x04\xe0\xe3\xdb\xcc8W7\xc0Q\xf6\xf8\xcc<\xe1\x0e\xedh\xbdZ\xdb\xe7\xb9\xcd\x1cM\'.U%s\xd2\xa9\xadN\xaf+\xfd\xa2\x7fm\x9f\x85\x7f\xb2\x99\xb7\x8f\xc7\xde4\xd2\xb4\x1b\xab\xcd\xa6+ \xb2]^26\xfcI\xf6xU\xe5\x11\x92\x8c<\xc2\xbb21\x9c\xe0W\x93\x85\xc2\xd7\xc4\xd4Tp\xf0s\x93\xd9E6\xdf\xc9jn\xdd\x95\xd9\xea\x07\xad#\x1c\n\xf8__\xff\x00\x83\x84>\x07\xe8\xfa\xe5\xe5\xad\xbe\x8f\xf1\x1bV\xb7\xb6\x99\xa2\x8e\xf6\xd7K\xb5X.\xd4\x12\x04\x88%\xb9I\x02\xb7P\x1d\x15\xb0yPx\xad\xff\x00\x82\xff\x00\xf0\\\xff\x00\x82_\x19\xfe!\xd8xso\x8b\xfc+6\xa6\xeb\x05\xb5\xde\xb7a\x0cv\x8f3:\xa2F^\x19\xa5(X\xb7\xdep\xa8\x009a\xc6~\x8e|\r\x9f\xc2\x9b\xab,$\xec\x95\xf6\xd6\xde\x9b\xfc\xads\x9aX\xca\x11\xdeH\xfb\x1a\x90\xf2=\xe9s\x9aBy\xaf\x98F\xf2c\x0f\x06\x8aRsHN\x7f\xcfZ\x0c\xe4\x1d\x0f\xd6\xa3+N\'\x15\xf3G\xedK\xff\x00\x05b\xf87\xfb)k\xf3h\xba\xb6\xb1}\xe2/\x11Z\xca"\xba\xd2\xb4\x0bu\xbb\x9e\xcf;\xc1\xf3]\xdd!VR\x98h\xcc\x9e`\xdc\xa7f\x0ek\xd0\xcbr\xcc^:\xaf\xb0\xc1'
# b'\xd3\x94\xe5\xda*\xff\x007\xd9y\xbd\tm%\xcd-\x11\xf4\x93\x9ac\x0c\xb5|\x91\xf0c\xfe\x0bq\xf0#\xe3\x06\xb5\xfd\x9fu\xabk~\t\xb8\x92X\xe1\xb7o\x11\xd9,\x10\xdc\x17\xc8\xcf\x9d\x0b\xcb\x1cJ\xb8\x1b\x9af\x8c\r\xc3\x93\xce>\xad\xd0\xf5\xeb\x1f\x14\xe8\xb6\x9a\x96\x97yk\xa8\xe9\xb7\xf0\xa5\xc5\xad\xdd\xac\xcb4718\xdc\xae\x8e\xa4\xab+\x02\x08 \x90A\xae\x9c\xc7%\xc7\xe5\xf3\xe4\xc6\xd1\x95;\xedt\xd2~\x8fg\xf2aN\xb59\xe9\x07r\xc55\x875\xe0?\xb6O\xfc\x14\xa7\xe1\xbf\xec?\xab\xe9z_\x8a\xbf\xb75-gU\x8b\xed\t\xa7\xe8\xf6\xd1\xcd<0e\x94K!\x92H\xd1T\xb2\x95\x03qbA\xe3\x00\x9a\xf4/\xd9\xcb\xf6\x92\xf0\x9f\xedY\xf0\xb6\xcf\xc5\xde\r\xbf{\xed.\xe9\x8cR$\xa9\xe5\xdcYL\xa0\x17\x82T\xfe\x17\\\x8c\xe0\x95 \x82\xa5\x94\x86.\xa6O\x8e\xa7\x84\x8e>t\xa4\xa9I\xd9J\xda7\xeb\xf2\tT\x8a\x9f\xb3o^\xdf\xd7\x96\xbe\x9a\x9d\xd5\x15\x93\xe3\xcf\x1di?\x0c|\x17\xaax\x8b^\xbe\x8fM\xd1t[Y//nd\x04\xac1"\x96f\xc2\x82I\xc0\xe0($\x9c\x00\t W\xcd\x7f\xb3\xa7\xfc\x16\'\xe1\x07\xed)\xf1f\xd7\xc1\xbag\xfc$\xda\x1e\xa9\xa99\x8bO\x93Y\xb2\x8a\x1b}B^\xd1F\xf1\xcb&\xd7`\tQ @\xdc(;\x8a\xa90y6;\x17F\xa5|5)N\x14\xf5\x93J\xe9u\xfc\xb5\xf4\xd4\x8a\x95#MsM\xd9\x1fT74\xdaRx\xae3\xe3g\xed\x07\xe0\xaf\xd9\xcb\xc2\x87Z\xf1\xc7\x894\xbf\x0e\xe9\xfc\x88\xda\xeaO\xde\xdc\x91\x8c\xacQ(2J\xc3 \xed\x8dX\xe3\x9cb\xb8\xf0\xf4jV\x9a\xa7J.R{$\xae\xdf\xa2E\x9d\x918\x14\xc2+\xe2o\x13\x7f\xc1}>\thZ\xed\xd5\x9d\xae\x9b\xf1\x03Z\xb7\xb7r\x91\xdfY\xe9\x96\xebor?\xbc\x82k\x88\xe4\x03\xfd\xf4S\xed^\xc5\xfb7\xff\x00\xc1I\xbe\x0f~\xd4\x97\x96\xba\x7f'
# b"\x87<U\r\xaf\x88.\xe3W\x1a6\xab\x11\xb2\xbd\xdc\xd9\xfd\xda\xee\xfd\xdc\xce0I\x10\xbc\x98\x1c\xf4\xafs\x17\xc2y\xd6\x1a\x8f\xd6+\xe1\xa7\x18\xee\xdf+\xd3\xd7\xb7\xce\xc7;\xc4\xd3\xbd\xb9\x91\xee\xd4\xc3O'\x02\xbf>\xfca\xff\x00\x05\xff\x00\xf0n\x81\xf1\x9em\x16\xcf\xc1:\xb6\xa5\xe1;[\xbf\xb3K\xae\xad\xfa\xc7;\xa8;^X\xedLgr\xe4eCJ\xac\xcb\x82B\x9f\x96\xb9\xb2~\x1f\xccsYN\x19}'7\x15wf\x95\x97M\xdaW}\x16\xee\xce\xc8u*F\x11\xe7\x96\xc7\xe8\x05\x07\xa5y/\xc7\xff\x00\xdb\x8b\xe1\x7f\xec\xcd\xe1K=[\xc5\x9e*\xb3\xb6\xfe\xd5\xb6\x17Zu\x9d\xb0k\x9b\xddB6Fdh\xe2@[cm H\xfbc\x0c@,3^\x0b\xe0\xef\xf8/'\xc1\x1f\x14\xf8\x8a\x0b\x1b\xeb_\x1cxr\xd6`\xdb\xf5\rGK\x89\xed\xe1\xc2\x927\x0by\xa5\x97\x9206\xc6y#8\x19#l\x0f\x0b\xe6\xd8\xbaN\xbe\x1b\x0f9EuQ};w~J\xfd\x88\xa9Z\t&\xde\xe7\xda\x19\xa2\xa9\xf8w\xc4\x9a\x7f\x8b\xf4\x1bMWI\xbe\xb4\xd4\xb4\xcdB%\x9e\xd6\xea\xd6U\x96\x1b\x88\xd8e]\x1dI\x0c\xa4t \xd7\xc8?\x11\xff\x00\xe0\xb9\xdf\x05\xfe\x1e\xf8\xdfR\xd1a\xb5\xf1\xa7\x88\x97M\x98\xc0u\r&\xc6\xd9\xec\xee\x18}\xef-\xa4\xb8\x8d\x99Cdn\xda\x01\xc6T\xb2\x90\xc7,\xb7#\xc7\xe6\x15%K\x07JS\x94wIm\xd3^\xdf\xf0\xfd\x81\xd4\x8a\x8f=\xf4\xeey\x17\xed\x81\xff\x00\x05\xc0\xf1W\xc1\xdf\xda7\\\xf0\x97\x83\xfc)\xe1\xdb\x8d\x1f\xc2\xd7\xcf\xa6\xde\xcd\xab\x89\xe4\xb8\xbe\x9a'+)\x8f\xcb\x91\x16%\xc8e\\\x87'\x01\x8f]\x83\xef?\x80\x1f\x19\xb4\xef\xda\x1b\xe0\xbf\x86\xfck\xa5E-\xbd\x97\x88\xac\x92\xe9a\x90\x86{v\xe5^2G\x04\xab\x86\\\x8e\xb8\xaf\xc0\xdf\xda\x93\xe2n\x97\xf1\x9f\xf6\x8b\xf1\xa7\x8btXo-\xb4\xbf\x12j\xf3\xea6\xf1]\xc4\x91\xce\x8b+\x16\xc3"
# b"\xaa3(l\x93\x9c1\xcfZ\xfbs\xf6\t\xff\x00\x82\xbe\xfc8\xfd\x97\x7feo\x0c\xf8\x1f\xc4z/\x8e\xaf\xb5m\x15\xae\xbc\xd9\xac--e\xb7a%\xcc\xb2\xa0V\x92\xe1\x1b\x85p\x0eT`\x83\xd4s_\xb1\xf1G\x87\xb0Y&\x1aYf\x1d\xfbu\xca\xa6\x96\xad\xde-\xc9\xbb\xbe\x92K\xd2\xf6Z\x1e|\xf1\x1f\xed.\xcf\xdc\xd5\x7f\x93\xfb\xbe\xfb\x9f\xa8\xc6\x9a\xc3\x8f\xa7J\xf2?\xd9\x1f\xf6\xdf\xf0\x1f\xed\xa7\xe1\x8b\xcdC\xc1\xf7W\xd1\xddi\x8c\x16\xff\x00L\xd4 \x10\xde\xd9nf\x08\xcc\x15\x99\x19\\!!\x91\xd8v8l\xa8\xf5\x0f\x11\xf8\x93M\xf0~\x81u\xaaj\xd7\xd6ZV\x9bc\x19\x96\xe6\xee\xf2u\x82\x0bt\x1dY\xdd\x88U\x03\xd4\x90+\xf1|V\x07\x11\x85\xae\xf0\xd8\x888\xcd;4\xd6\xbe_\x7fN\xfd\x0e\xc8MM^:\x96\xa8&\xbe@\xf8\x99\xff\x00\x05\xbf\xf8\x1d\xf0\xfb][\x1b\x1b\x8f\x14x\xb9v\x9f2\xe7F\xd3W\xc8\x89\x83\x15\xd9\xba\xe6HK\x1e2\x19\x03)\x04a\xab\xa5\xfd\x9d\xff\x00\xe0\xad\x9f\x06\x7fh\xcf\x10\xdb\xe8\xf6\xba\xbe\xa1\xe1}j\xf2\xe3\xec\xf6\x96^ \xb6[V\xbbl\x026J\x8f$ \xb1;UZEvn\x02\x9c\x8c\xfb\x158O9\x85\x0f\xacK\r5\x1b^\xfc\xafn\xedoo\x96\xda\xecL\xabB.\xcd\x9fKR\x11\x9a{\x8ek'\xc6~8\xd1~\x1cxn\xe3X\xf1\x06\xad\xa6\xe8zM\x9e<\xfb\xdb\xfb\x94\xb7\xb7\x8bq\n\xbb\x9d\xc8Q\x96 \x0ey$\x0e\xa6\xbc\x08\xc6R\x92\x8cU\xdb+[\x9a\x07\x91\xe9\xfd)\x84b\xbeJ\xf8\x89\xff\x00\x05\xb6\xf8\x13\xe0\x95\xb5\xfe\xcd\xd4|I\xe2\xe3p\\H4\x8d!\xe3\xfb.\xdcc\x7f\xda\xcc\x00\xee\xc9\xc6\xcd\xdft\xe7\x1cg\x96?\xf0_\x1f\x83\xc7\xfee\xbf\x89_\xf8/\xb2\xff\x00\xe4\xba\xfa\x9a\\\x17\x9eT\x8f<p\xb3\xb7\x9a\xb3\xfb\x9d\x99\x8b\xa9\x05\xbb>\xdd=)\xad\xd0W+\xf0S\xe3\x7f\x85\xff\x00h\x7f\x87\x96~)"
# b"\xf0\x86\xa9\x1e\xad\xa2\xde\x96D\x94#F\xc8\xeap\xc8\xe8\xc02\xb0=\x88\x1c`\x8c\x82\t\xea\xcfZ\xf9\xca\xd4jQ\xa8\xe9U\x8b\x8c\xa2\xec\xd3Vi\xf6h\xa8\xc9IsGa\x94S\xb1M#\x15\x98n\x15\xf3O\xfc\x14\xaf\xf6\xf4\xba\xfd\x87~\x1fh\xb2h\xfa5\xae\xb1\xe2/\x13\xcd4V_lf\xfb\x1d\xb2B\x10\xc8\xf2*\x10\xce\x7fx\x80(e\xfb\xc4\xee\xf9p\xdd7\xed{\xff\x00\x05\x04\xf8\x7f\xfb\x16K\xa5\xda\xf8\xa9\xf5k\xfd[VS,:n\x93\x02Mt\xb0\x8c\x8f9\xfc\xc7DT\xdc6\x8c\xb6X\xe7\x00\x85b\xbf\x9c\xff\x00\xf0To\xf8(\x17\x81\xff\x00m\xbf\x0fx>\xdf\xc2\xba_\x8a4\xfb\xaf\x0e\xdc\xdc\xc93j\xd6\x96\xf1+\xa4\xab\x18\xc2\x18\xe6\x90\xe71\xf2\x08\x03\xa7<W\xdf\xf0_\t\xe21\xd8\xda\x15\xf14%,3n\xefd\xec\x9d\xbc\xed\xcc\x92\x7f4K\x94b\xdf6\xf6\x7f\x96\x87\xda?\xf0L\xaf\xf8(\xee\xa1\xfbl\r\x7fG\xf16\x95\xa6\xe9~'\xd0\xd1o\x15\xb4\xd5\x91mn\xed\x99\xb6d$\x8e\xec\xac\x8d\xb4\x1f\x98\x83\xbc\x11\x8eE}b\xff\x00z\xbf\x10?\xe0\x9a_\xb5\xbf\x87\xff\x00c_\x8e\xfa\x97\x89\xbcMi\xae_i\xb7\xda$\xdar\xc5\xa5\xc5\x1c\x92\xf9\xad4\x12+\x15\x92H\xd7h\x11\xb79\xceH\xe3\xae?E~\x07\x7f\xc1c~\x10\xfcs\xf8\x8dc\xe1\x88S\xc5\x1e\x1c\xbe\xd5\x1da\xb3\x9fY\xb3\x86;{\x89\x99\x95R\x1d\xf1M!Vb\xdc\x17\n\xbc\x11\xb8\x12\x01\xf58\xdb\x82q41\xf3\xab\x96a\xe5\xecl\x9e\x8a\xe9;kn\xbd/\xf38\xe8V\xb2~\xd1\xf5\xfc4\xfdn}QMa\xba\xbc\xff\x00\xf6\x80\xfd\xab\xbe\x1e\xfe\xcb\x96Z}\xc7\x8e\xbcMm\xa1.\xaa\xed\x1d\xa4f\t\xaef\x9c\xa8\xcb\x11\x1c(\xef\xb4p\x0b\x11\xb4\x16Q\x9c\x90\x0e\x96\x81\xf1\xff\x00\xc1>'\xf8O\x07\x8e\xad<S\xa1\xff\x00\xc2\x1fq\x12\xca5i\xee\x96\xde\xd60\xcc\x14\t\x1a"
# b'B\xbe[\x06!J>\xd6\r\xf2\x90\x0f\x15\xf9\xe2\xc0\xe2U(\xe2=\x9c\xb9$\xec\xa5gf\xfb\'k7\xe4\xb5;/\xaf/S\xac\xebMe\xaf\x91\xfe \xff\x00\xc1m>\tx3X\x8e\xd7O\x93\xc5\x9e*\x89\xa3\xde\xd7ZV\x96\x12\x18\x9bq\x1b\x0f\xda\xa4\x85\xcb\x0c\x03\x95R\xb8a\xf3\x13\x90=\x83\xf6R\xfd\xb5\xfc\t\xfbc\xf8z\xea\xf3\xc27\x97\x91\xdei\xe4}\xb7K\xd4"\x10\xde\xd9\x82\xcc\x11\x99U\x99\x19[nC#0\x19\x00\xe1\xb2\x07\xa5\x8a\xe1\xbc\xd3\r\x87\xfa\xd6#\x0f8\xc3\xbbM[\xd7\xaa\xf9\xfe\xa62\x9cS\xe5oS\xd5\xa8\xa72\xe0W\xcd\xff\x00\x1f?\xe0\xaa\xff\x00\x06\xfe\x00\xea\xb7\x1am\xc6\xb9w\xe2mb\xceq\x05\xc5\x8e\x81n.\x9a\x03\x82I2\xb3$\x1f)\x1bYD\x85\xd5\x8e\n\xf0\xd8\xe3\xc0e\xd8\xacmOe\x84\xa6\xe7.\xc97\xf7\xf6^oB\xba\\\xfa,\xad%|s\xe1\xef\xf8.W\xc1\xbds[\xb5\xb4\xba\xd3\xbcw\xa3\xdb\xdc8G\xbd\xbb\xd3`h-\x87\xf7\x9cC<\x92\x11\xfe\xe21\xf6\xaf\xa6\xfe\x0f\xfct\xf0\x7f\xed\x01\xe1U\xd6\xbc\x1b\xe2\r?_\xd3\x89\n\xefn\xe7\xcc\x81\x8f;e\x8d\x80x\xdb\x1c\xeduS\x82\x0e0k\xbb0\xe1\xfc\xcb\x03\x1fi\x8b\xa1(G\xbbZ}\xfb_\xc8\x85R-\xd93\xa9+M#\x06\xb9\x9f\x8d\xbf\x18to\x80\x1f\n\xf5\xaf\x18x\x81\xae\x17I\xd0\xa0\xf3\xe7\x10G\xbeY\t`\x88\x88\xa4\x80Y\x9d\x95FH\x19a\x92\x06M|\xbb\xfb\'\xff\x00\xc1a\xb4/\xdaS\xe3]\x9f\x82\xef\xfc!u\xe1Yu\x86h\xb4\xdb\xbf\xed5\xbc\x8ey@f\t"\xf9q\xf9e\x82\xe0\x10_\xe6 q\xd6\x96\x07!\xc7\xe30\xf51xjnP\xa7\xf1=4\xd2\xefwwe\xabJ\xed\x0e\xa4\x94#\xcd-\x8f\xb2\x18dS'
# b'\n\xe4\xd7\x81~\xd2\x1f\xf0S/\x84\xff\x00\xb3.\xaf6\x93\xaak\x17:\xe6\xbdl\xe1\'\xd2\xf48V\xea{nX\x1f1\xd9\x92$e+\x82\x8d \x90d\x1d\xb89\xaco\x80\x7f\xf0V/\x84?\xb4\x07\x8c!\xd0`\xbc\xd6<3\xaa^J\x90YE\xae\xda\xa4\t|\xec\x18\xedI#\x92H\xd4\xf0\x00\x122\x16fP\xbb\x89\xc5oO\x873I\xe1\xbe\xb7\x1c<\xdc-{\xf2\xbd\xbb\xf7k\xcfbjIG\xe2\xd0\xfaM\xc55\x935#&\x05Q\xf1\x0f\x88t\xff\x00\t\xe8\x97\x1a\x96\xab}g\xa5\xe9\xb6q\x99n.\xae\xa6Xa\x81\x07Vwb\x15@\xf5\'\x15\xe3\xc6\xed\xd9\x13\xca\xdb\xd0\x98\x8c\x1ai\x1bO\xf4\xaf\x94~!\xff\x00\xc1h>\x0b\xf8+[[;\x19<Q\xe2\xa8\xf6n{\xad\'MU\x826\xdcABn$\x85\x89\xe0\x1c\xaa\x95!\x86\x18\x9c\x80\xff\x00\x87?\xf0Yo\x82\xfe<\xd5\xda\xd2\xf6\xe3\xc4\x9e\x14\x18_.}cN\x1eL\xccN6\x86\xb7y\xb6\xe3\xa9.\x15@\xef_I\x1e\x14\xce}\x97\xb5\xfa\xb4\xed\xfe\x17\x7f\xbb\x7f\xc0\xceRQ\xdc\xfa\xab\xbf\xf8\xd0W\x15W@\xf1\x06\x9f\xe2\xcd\x16\xdbR\xd2\xaf\xac\xf5M:\xf5\x04\xb6\xf7V\xb3\xac\xd0N\x87\xa3#\xa9*\xc0\xfa\x82EY\x91\x84J\xcc\xc4\x05Q\x92O\x00\n\xf0\xa5\x17\x17g\xb8Z\xfb\x08E1\xc6\x7f\xad|\xf7\xf1[\xfe\n\xa3\xf0O\xe1a\xd4!>+\xff\x00\x84\x8bR\xd3\xf6\x7f\xa1\xe8v\xcfy\xf6\x82\xdb\x7f\xd5\xcf\x85\xb6l\x06\xc9\xfd\xe8\xc6\xd2>\xf0\xdb^r\xdf\xf0\\\xaf\x84\xc4\x7f\xc8\xbd\xf1\x13\xff\x00\x00,\xff\x00\xf9*\xbd\xfc?\n\xe6\xf5\xe1\xed)\xe1\xe7o4\xd7\xdd{]y\xecL\xb4\xdc\xfb\x19\xd2\xa3"\xbc\xaf\xf6[\xfd\xb5\xbc\x0b\xfb_\xe9w\x92xR\xea\xfa\x1dCM\x01\xee\xf4\xcdB\x01\r\xdd\xba\x16eW!Y\x91\x94\xed\xea\x8e\xd8\xc8\r\xb4\x90+\xd6\x1drk\xc9\xc5`\xeb\xe1*\xba\x18\x888\xc9n\x9a\xb3'
# b'3\xba{\x10\xb0\xcdFV\xa6a\x91Q\x91Y\xc6W"\xc4l\x9cT.\xb8\x15g\x1c\xf4\xa6:\xee\xad"\xc4\x7f*\x1a\x8e\x9b5\x85\xd7\x934m\xb9N\n\xc8\xbd1\xd8\xf4<zdt\xac\x8dW\xc2\xcb\xaanX\xe3P\x1b\x8d\xe5\xb0\xa3\xf1\xe9\xfc\x87\xb9\xafk\x8f\xc7\xb7\x8f\xa7}\x93X\xd2\xf4\xff\x00\x16G\x12yA\xa4\x87\xec\xba\xa4@p0x/\x8e\xc1Y\xbe\x82\xb2\xef\xfe\x1b\xe8^1v\xff\x00\x84oXXo7a\xf4\xcdD}\x9e\xe9_\x81\xb4\x13\x85?V+\xf4\xaf\x9b\xf7^\x87\xd3Fmn|\xfd\xadx&/\xb5I\x1e\xcc:\x03\xc3!]\xc3\xa6Fpq\xe8@\xc5qz\xd7\xc3\xf9m\x16Cl\xd2A\xe6\x0c0S\x85a\xc1\xe4\x7f\x9eE}\x0f\xe2o\x01\xea^\x1c\x99\xac\xf5M>\xe2\xdd\xd7\x90\xb3G\xb7\xf1\x1b\xb8\xfa\x11\xd4t5\xccO\xe1h\xc4\x12*\xf2\xed\xca,\x99\xda?\x1e[\xf3\xdd\x93\xe9\\\xf3\xc3\xa7\xd0\xde\x15Z<gH\xf1\xef\x88\xbc\x0bp\xa5\xa5\x9aX\xe3\xe1[q\x0e\x9fF\x18o\xd4\x8a\xf6\x0f\x85\xbf\xb6T\x9ao\x83\xad\xfc;7\x97%\x8d\xbayP$\xe7l\xb0\xaf<+\xf2\x19GL0\x07\xa0\xacMs\xc1\xb1\xca\x98\x92?+q\xc0\'\x95c\xe8\x0f#>\xd9\xcf\xb0\xae3\xc4\x9f\t\xd7%\xa2VC\xfe\xc8\xaeYQ\x9cv\xd5\x1b\xa9A\xee}\x05\xfb(\xe9\xf0\xf8\x8f\xe3\xbd\xa4\x81\xb65\xacRN\xc7\xba9\x1cc<g\xd3\xa8\xaeS\xc7\xde\x1d\x93N\xf1\xfa.\xa1\xa5\xcd\xa6\xdd\xdfM=\x91x\xad[M\x92Y\xd3\xe7\x8f\xcevso\x1a\xc8\xb8.\xf0\xb6J\xa0\xf9\x17<\xf9\x17\x86\xbca\xe2/\x85\xd6\x93Ef\xab2\xc8\xea\xdb\xa4\xdc\xc5\x15rv\x8er2Nx\xc1\xe2\xba)>=\xd8\xf8\xf0\x8f\xed\xfd>\xc6mC\xcc\x86Aq\x7f\x0f\x9a\xc4\xc6\xc0\x80_\x82\xcaFT\x87\x04m8\xcf\x03\x15\x88\xad\x1a\x8a\x11\xd9\xa5\xd4\x9aPp\x93}\x19\xe9\x9f\x13\xff\x00g}\x17\xc4'
# b'\xff\x00\t\xec\xfcU\xa7\xdc\xe9\xe9\xa94L\xd3\xc9\xa5\xac\x91\xda;\xab\x10v\t>b\x061\xbb\xa1<\xf4"\xbc\xbe\xc7I\x9bL\xd0\xb5\xe9\x05\xb4\xda\x84q\xdb\xc5\x0c\x80\x0f\x98+8$\x929\xe3g\x7fZ\xf7\xff\x00\x1d\xfcz\xf0\xcf\x8e>\x16\xa6\x9b\xa4\xc7&\x9e\xd1\xc4\x91Ej\xdf2\x85\x04\x0c#\x8c\x86P8\x19#\x8e\xc2\xb9\xff\x00\x87\xda:\xd8|\x1a\xf1\x8e\xa1\'\xcbos=\xbe\x9f+\xac\xb0\xc7&\xc7\x18m\x9ew\xc8\xccs\x8d\xa4\xa9 \x9c0 V\x98XrFs]\x17\xe7\xa1\x15\xa6\xe4\xd4|\xcf\x00\xf0\xbd\xf5\xc7\x86\xf5\x98\xf5/\n\xeb7\xba.\xa9\x01\xf9vJa\x91}\xb21\xc1\xee\x0eA\x1dEz\xe7\x87\xbfm\xcdb\x0bk{\x1f\x1a[\xde\xa4\xf6n\x1e\xdbX\xd1\xca\xdb\xdc\xc2\x7f\xda\x8f\x1e\\\x8a\xdd\x18\x00\xb9\x1e\xbd\xf9\xff\x00\x05|\x17\xb7\xf1\xf7\x88\xff\x00\xb1\xe4\x86\xf2[\xd9.%\xb6c\x05\xbe\xdb\xabI\x15\x80\xf3\xa7]\xfbb\x87n\xdc\x02K\x16-\x8c\x81X\xbf\x10\xbe\x12k\x7f\r\xbcE>\x93\xa8I\r\xe5\xb0B\xd1\xc8\xc3\xe6=\xbe\xb9\xfc\xeb\x96\x9c\xa4\xe4\xa3mM\xe5\x18\xdbS\xea\x9f\x80\xdf\x10mu(\xef<Ako{\xaa\xd8\xeb\x17\x84:[\xb7\xfaL\x08\xd8H\xe4x\xb8&2\xc0\x82@\xc0 \xf3^\xe7\x04V:\x93\xcbokp\x90\xddY\x15\x13@\xec\tB\xdc\x8fR=\x89\x18>\xb5\xf9\xaf\xae\xdc\xbe\x91\xe2\r,\xe9:\xb5\xc6\x8f\xabiVp\xa4m\x1c\xa6&RF\xf3\x86\x18\xee\xf8#\xbf\xa5zw\x80\x7fm]K\xc3~&\xb0\xb8\xf1\xe6\x86\xba\xb4\xf6q\xfd\x99u\x8b?\xdc\xdd\x18\x8e>\xfaq\x1c\x98\x03\x82B\xb0\xf5<W\xad,uJ5-\x17\xa2\xd3\xee<\xd9`i\xd5\x85\xda\xd5\xfd\xe7\xd9\x9a\xa4o\xa2\xd9I#\x04\xff\x00E\x8d\x9d\x88\xc1\xe4d\x8f\xf0\xa8\xf4=6{\x8d\x1e\xddv\xee\x91"PO\xa9\xc0\xcdx\\\x1f\x1dc\xf8\x90\xd6\x16\x9a?\x88,uh'
# b'\xe6\xbe\x11B\xf6\xe8\xd0\xde\xbd\xb9R\xc5\'\x88\xe3\xe6\x1fw \x10s\xd4\xf5?Bx\x07\xc6\x9a\x7f\x8b\xf4\x18\xe2\xd3.\xe0\xber6\x03\x1cf;\x88d\x18\xccr\'Ua\xf8\x83\xcfj\xf6\xa8\xe6\xb1t\x93\x9e\x8d\xb3\xc7\xab\x96\xce\x12|\xba\x9aZK.\x85\xa6\x89\x19\xa3\xfbB\x9c\x04\xdd\x9eNz\xfb\n\x8e\xf3V\x96I7\xa0\xf9\x94g\x8e3\xdb\xfa\xd4\xf2\xf8m\xac\xac\xe4\x92M\xac\xca\xb9\xc1q\xf2\x9f\xa7_n\x9d\xea\xae\x9f\xa5\xdc_^]\xca\xb1\xed\xb5\xb6\x89\x15\x98t\x0cr\xc7\xf9\xa5t\xc2Q\x9a\xe6N\xe7\x14\xa3$\xf9^\x85I\'m\xdbYp\xe5rO_z\xa2\xb6\xfel\xcd\xe56\xd6nzt\x15\xd1[xj=cF\xb8\x92\xde\xe9VkS\xf3\x07\x1f+\x0e\x00\xe7\xdc\xf1\x8c\x1f\xebYv\xfal\x91;,\xdbU\xb6\xf4\xc8\xdc;\xe3\xf1\xf65\xacd\x9e\xc6\\\xac\xa2msu\x1a\xb1\xff\x00{\xeb\xebU\xe1\x08/\xa4\xdc\xaa\xd8$\xa9\xed\xe9]$\x16P\x08c+\xf3JA.\xa4\xe3?O\xf0\xaa7\xfaU\xb8\xb8M\xab\xb7p\xc9 \x7f\x91T\xa6\xb6\x17/S2\xee\xd9\x9aM\xe3\r\xb5q\xeej+t\x9a\x1f\x99\x8e\x11\x8e\xde\x7f\n\xda\xb6\xd2\xa4\xd4T2\x82\xf8\xe3\n>\xbf\xcf\xdf\xaf\xbd7R\xf0\xc5\xd1\xb2\xca\xc7\x85\xb5\xc9pO\xcd\xce\x7f\xc7\x1e\xdcQu\xd4\x1ct\xb9\x85q\xbd%\x8d\x95\xb7g\'\xe9I\x0e\xc9\xc3a\x99X\x8c\xf3\xeb\xcd9\xcc\x96\x92\xaa\xc8\xa5Y\xb9P{\x8a!\x8c\x89do/\xccV9\x18\x18\xc5Q\x905\xbc\xd6\xb1~\xf1\x15\x96A\x90A\xfc\xea\xae~\xcf9^\xddA\xcf8\xa9\xaf\xdd\x8c,\xcf\xbb\xe5\xe4})\xb3\xda\xbc\x90G\xd0w9\xea3K\xa0\x11\xddF\xa6-\xfb\xb73\x0e\x9e\x9f\xe4\xd4d\x93\x13|\xb8l~U5\xacj\xaa\xa1\x97qb}\xe8i\x15K\x00:\x1e\xb8\xff\x00?J@S\x86\t"\x95\x96E\xdcA\xff\x00\xeb\xd4\xb7+\xf2\x1e\xdcz\x7f\x9e'
# ...
# b'\xe3_\x8e\xff\x00\x15\xbe+F\xcd\xadx\xdb\xc5\x17\xb0\xcb\xcc\x90%\xc1\xb7\xb79\xcf\xf0.\x17\xf4\x1djK\x0bh\xed~\x19K$q\xc7\x1c\x9eq\xf9\x95B\xb7\nq\xcf\xb5z\x8f\xec\x81\xe1\xed?\xc5?\t\xe7\xb8\xd5,l\xf5+\x88\xf5\xddE\x16[\xa8VgUM>V@\x0b\x02p\xac\x01\x03\xb1\x19\xa7\xcfRJ\xfc\xc4sF.\xca\'\x8e\xf8s\xf6}\xbd\xf1.\x87\xf6\xfbv\x87SwB|\x88d\x17W\x05\xc1\'`Ebw\xe3$.\x03\x1c7\x07\x04\x8fK\xd2\x7f`\xaf\x1bG\xe1\xa3\xab^\xf8GZ\xd3\xf4\xe5}\xae\xf7Q\xf9{\x06\xdc\x86!r\x02\xe4\x80Ia\x83\x91\xc1\x04W\xaf\xf8?B\xb1\xb6\xfd\x95\xbcE\xadGgk\x1e\xb3k\xa2\xea\xd2\xc1~\xb0\xa8\xba\x85\xd2e\x08\xcb&7+(\xe0\x10r;U\xcf\xd9\x0b\xe3\xb7\x8e.mt\x98\xe4\xf1\x97\x8a\xa4I#M\xca\xda\xb5\xc1\r\xf3\xb0\xe4o\xa6\xe9GI\n5$\xfa\x9ew\xf0C\xf6]}In\xa0\xf1\x1e\x87\xa9Z\xd8C"\x87\xd4-l\xb0\x90\x97\xc2\xe3|\xb3\xaa\xb3.\xe0\xdbU\t8\xee\x01\x07\xda4\xdf\xd9+\xe0\x96\x93\xa2C\xa8j>0\xf1\xdf\x87\xecL\xcae}G\xc2\xf2j\x96R\xc8\xb9\nD\xb0\xe5S\xd7\x01\x81\xc9\xce9\x15\xfai\xfb8\xc4\xba\xce\x8dc%\xe2\xad\xd4\x92B\x0b\xb4\xc3\xcc,r:\x93\xd6\xbd\x1f^\xf8E\xe1=OO\x9d\xae|/\xe1\xdb\x86(\x14\x99t\xd8\\\x90\x1b\x81\xca\xf6\xa9\xf6\x8e?\t\x9d\xaf\xb9\xf9\xbf\xf0\xab\xc0\xff\x00\x0f|s\xe2H#\xf0\x7f\xc5o\x0c\xdeMck0]\x12\xd6\x1b\xab8\xe7m\xca\x04\xd2D\xf23+G\xc8b\xaaCn\x19\xc9\xc1\xaeS^\xfd\x98|}\xaakw\x96\x9a\x1f\xc5O\x85\x1e.\x8f\xcc?j\xd3\xae\xe0\xb1\xb8\xb9\x88\x82A\x0c\x8d\x16\x19\x97\xa7\xcc\xcay=\x08\xc1\xf7\xaf\xda\xf3\xc2z^\x89\xf0\xd6\xce\xc6\xcbM\xd3\xec\xec\xe3\xb9.\xb6\xf0[\xa4q+1]\xc4('
# b'\x18\xc9\xc0\xc9\xef\x81_/\xfc\x0f\xf0\xf6\x9fw\xf1\xcf\xc4\xf6\xb2\xd8\xd9\xc9m\xf6Y_\xcaxU\xa3\xdc\xd0H\t\xdb\x8cd\xf7=\xebW\x15(su"5\xa4\x9d\x91\xec_\x01\x7fg\x1f\x89\x1aw\x89,\xf4_\x1cxO\xc1\xe3\xe1\xe5\xca4\x9a\xacZ=\xa2\xab\xddm\xdaQ#\x8e\tB\xeefU9*\xa5B\x93\xce\x01\xaeG\xf6\x86\xfd\x8d\xb5\x8b_\x195\xdf\x84~\x08Y\xea\x9am\xfc\xf3\xcb\x13Y\xea\xda\x85\x85\xf5\xb2\xc7\x96O8n1\xee|eBn$\x80\x08\x04\xe2\xb1\x7f\xe0\xa56P\xf8\x1b\xf6J\xf8\x03y\xa2C\x1e\x8fx\xda5\xaeg\xb1Ao!\xdc\x96\xe4\xfc\xc9\x83\xc9f\'\xd7q\xf5\xaf\x9a~\x12\xfe\xd0\xff\x00\x10-\xfcB\xd0\xc7\xe3\x9f\x18G\x10\xd9\x84]f\xe4(\xfc7\xd4{4i\xed\x1d\xee{\x96\x91\xafx\xb3\xe1~\x8fumu\xf0\x9f\xe3\xf6\x87&2\xd7v^ \xbe\x91!\xc3\x1f\x9a2\xc8\xab\xef\xc9 \x8e9\xc5X\xf0o\xedI\xa9h\xfe \x86\x08\xfcW\xfbNi\xad3\xe4\xc7w\x10\xd4\x00E\xe0\xed\xdc\x06ps\x93\xcfn\xa3\x8a\xfa\x13\xf6V\xf8\x9f\xe2]b\x08V\xf3\xc4Z\xe5\xd08\xc8\x9a\xfeY3\xc8\xf5j\xfb\n\xd6y.\xb4\xabo1\xdaM\xd1\x8c\xee;\xb3\xc5\x1e\xcd\xf7+\xda\xf7H\xfc\xf7\xf1/\xed}\xe2Ky\xadc\xd1\xfe8x\xe3Ci\xa3\xca[x\x97\xc10\xde,\xc7 n\r\xe5\xe5}\n\x8c\xff\x00<\xeb\xbf\xed3\xf1\x07\xc1\xf6\xbfn\xf1?\xc6_\x85\xa7GT\xf3a]O\xc1\xfeE\xe4\x87\xa0\xdb\t\xf2\xfa\xf5\xc8`q\xeb\x9c\x8eo\xfe\n\xdb\xaf\xdfxSF\xba\xb8\xd2\xefn\xf4\xdb\x8f\x9a?6\xd6f\x85\xf6\xe4\xf1\x95 \xe3\xda\xbf/\x1e\xfe}k\xc4\xd1\xb5\xe4\xd3]\xb4\x9f3\x99\x9c\xc9\xb8\xfa\x9c\xf5\xaa\xf6|\xab\x99\xbb\x95\x0bT\xd2\xd6?@<G\xff\x00\x05a\xf0\xbc\xb1I\x0f\x8a\xfc\x11\xf0\xbf\xe2V\xa0\xacY>\xc5\xe1#\x0ca\xb8\x19\xf3\xa6\x91'
# b'\x9b\xb0\x04\x88\xfb\x0ex\x15\xf3\xbf\xc4\x8f\xdb_S\xf1\x85\xeb\xb7\x86~\x1e\xfc=\xf0</\'\x98\x86\xcbE\x85\xe7F\xe9\xc3\xb2\x9fRp\x00\xecz\xe0\x8f%\x8a\x14\x8e\xc6\xdfj*\xfc\x83\xa0\xf7\xafH\xf0E\x94\'\xc2\x1b\xbc\x98\xf3\xf6\xae\xbb\x07\xf7Mg\x1a\x8eO\xdd\xd0r\x8c`\xafk\x9c/\x89<E\xe2\xff\x00\x8b> \xb7\xb7\xf1\'\x8a.\xdb\xcf}\xa8\xda\x8d\xf7\x93\npO\x1b\x98*\xfb\x00@\xad\xad\x1f\xe0\x16\xa9u|\xf1\xd9\xe9w\xda\xa5\x9d\xb8\x05\xee\xec\xd1D%x,D\x8cp\xcc3\x8c)$\x90@\xce\r}\x03\xf0\xf3\xc1Z6\xad\xf1\x8fJ\x82\xebH\xd2\xee\xa1\xff\x00F>\\\xb6\xa8\xeb\xf3\x19s\xc1\x18\xe7\xbf\xadww\x1a\xe5\xef\x86u\xcdB\xdfM\xbc\xba\xd3\xed\xe1x\x1a8\xad\xa5hQ\x0f\x93\xbb )\x00s\xcf\x1d\xeag$\x9d\xa5\xab\xf5\x05&\xdd\x91O\xe0W\xc0\x8f\x86\xfa\xb7\xec\xdf6\x93\xacxgX\xb3\xf1\x15\xb6\xad\xba\xfbX\x95\xa3e\x8a6b!\x11"\xc9\xe7\xe4\xa9\x01\xb6+\xa9\'%xW^\xe3\xc0\x9f\xb2\'\xc3\x8f\x86W\xd2j\xd6\xde*\x83P\xd0\xed\xdcN\xf6Z\x8cwW\x0c\xef*\x86E\xd9,\xb1\xabm\xe0\x83\xb3<\x90NG\x1e\xb1\xfb4jW\x1e4\xd6\xa1\x83X\xb8\x9bV\x86k\xd8\xbc\xc8\xef\\\xdc+\xf1/P\xf9\x07\xa0\xfc\x85g\xfe\xd8\x90G\xa5|\x7f\xb7\xb3\xb5E\xb6\xb3\x87HYc\x82!\xb28\xdc\x8c\x16\n8\x07\x03\x19\x1c\xd6\x91\xa9ud\xacaR<\xac\xe6o\xf5t\xf1G\x8c\xbf\xb3|3\'\x83.4\xddA\x1a\xf6\xf2\x18t\xbb\xa8t\xe4\x8e\x18\xc8H\xa4\x9bx\x12K\xce\xd0\x01\nX\xa8$\x0c\x03\xdb\xe9^8\xd4?f\xbb\x8d7K\xf0\xdd\xb5\xc3.\xbd<w/\xa9\xa5\xf4\xdeE\xa1\xf9B+\xc2\x1f\xf7\x8cX\x04\xda\xea\x02\x81\xdc05\xe0\xdf\r\xf5;\x98<;\xa3\xf9w\x13\xa6.\x9dF\xd9\x08\xc0w\x908\xff\x00\x81`g\xd6\xbe\x92\xf1\x90\xfb'
# b"\x07\x8c'\xb1\x83\xf76S\x11+\xdb\xc7\xf2\xc4\xef\xfb\x93\xb8\xa8\xe0\x9f\x99\xb9\xc6y>\xb5\xbd\x1d\x8c\xa5v\xf5(h\xfe\x0f\xf1\x97\xc4\x1f\x1ej\x9a\xb6\xb1\xaa\xc7\xe6\xc9m$V\xd6\xd6\x08\x07\xdb3\xb5\xb6N\x15\x94\xb4\xa4\xed\x90\xb30 )\x01H`+:\xcaK\xdf\x05x\x9bR\xd0u\x13\xa0\xad\xf2\x0f\xb3\xfd\xb3\xcb\xf2c\xb8C\x92\xc5\x8a\xe3\x0c\xbd\xc9E#i8$\x13\\$:\xc5\xdb\xc3\xa5\xc0\xd7W\r\t\xbfRc2\x1d\xa7\x89{g\x1f\xc2\xbf\xf7\xc8\xf4\xaf\x7f\x8a\xde=[\xe3\x07\xc3\xbb\x8b\xa8\xd2\xea\xe2\xfa\xda\xea;\x99e]\xefp\xab\xbbj\xb9<\xb0\x1d\x81\xce+[ivG]\x0eOF\xd3-t\xaf\x19J\x8b\x12\xdf3i\xdffX^\xe4\xb5\x89\xde\xcc\xf2M/\x98\x19X\x8c\x82\xa5B\xb3\x80@d\x00\x1ag\x83\xbc\x1du\xe0\x9bmUa\xd7t\x08~\xda\xa1-aAqj$BY\xa3\xfd\xd61\xbdX\x12\x1c\xeeS\x81\xc7Q\\\xc4\x93\xbc\x1ae\xc0Fd\x10\x98D{N6e\xa4\xce=3\xed^\xe9\xe1\x8b\x18[\xf6t\x8e\xf0\xc3\x11\xbb\xff\x00\x84\xa1\x17\xcf(<\xcco~7u\xa1$\xc3[\x1eK\xe0O\x89\xb7\x9e-\xbe\xba\xf0\x8d\xa5\xfe\xa1\xb6\xcd\xde\xeaR\xb7\xa9o\xf6\x97e>\xa1Kaw\x00\x0e\xc2\x00\x00+n\xe7\xb8\xf8{u\xa7\xdf\\\xf8:\xe3I\xbe\xb5\xdd\xe7\xc8\x90\xdc\x1b+\xab\x8f.b\x19|\xaf%Sr\xbf\\\xeffL\x90I\\.<\xf7\xc2Q*x\xf3T\x99UVX\xefm\xca8\x1f2\xe4\xa18=\xb2y\xae\xbe\xca\xe6KMC\xc2w\x11H\xf1\xdc4\xf1\xb1\x95\x1bk\x93\xf3\x9c\xe7\xad\x1c\xdd\x89\xb5\xde\xa6\xbf\x8a\xf4\xd7\x8b\xc3\xf3}\xa3X\x96K\xbbWh\xeem\xec\xae\x9e;\x89\x01(\xdec\xec\xdc\x8d\x94\xdc\xc03;\x00\xa4dg#\x08x\xef\xc3\xfe,\x96\xc7I\xd5~\xc9-\xd2\xde\xc6m\xed.s\x0co6\x18HY\xf6\x86\xe7h\x01\x80T\xda\xd9$"
# b'\x91\xf3W\xd0#]{\xc4~4{\xe5[\xc7\xfe\xd6\xb8]\xd3\x8f0\xe0\xb3\xe4e\xb3\xd6\xbc\xcb\xc2r2~\xd0z\xe5\xaa\xb3-\xad\xbe\x9f\x17\x95\x08?\xbb\x8b\xa7\xdd^\x83\xf0\xa6\xb6(\xf5\xdf\x88R\xe9\x10E\x1f\xf6>\x87k\x0e\xa0\xb1\x7fg8\xba\xb0\x89\xa7\x95\xa4\xc9S\x1c\x8b\xb0\xedU\n\x01*\xaa\xa3\'\x9c\x10/\xf8R\xd7B\xf0F\x97\x1e\xad\xabi\xb7\x10\x7ff\xc6\xb6\xfb-\xf5\xbf\xb2\xcfr_*\x0c\xc6E\xb8*\xcb\x95q\x86@r\xbd\xf6\xe6\x1d\r\xda\xd7\xe05\xf5\xdcd\xc7u"\xc3\x1bL\xbcH\xcb\xe7m\xc1n\xb8\xdb\xc6=8\xa8\xfc#g\r\x9f\x8a\xdb\xc9\x868\xbf\xd3\xa7o\x91B\xf3\x98\xf9\xe2\x8e[\xb2S\xd0\xd6\xd3\xf5\xef\x0ekz\xae\x94\xd0\xea:\xb5\xf6\xa5x\x8d\x1c\xf6\xf6\x10\xb5\xd3HT\xe5Y\xd8\x02<\xc2\xd9\x00\x84\x8f\x91\x90\x08 \xd4\x97ph\xba$W\x96"\x1f\x1bxn\xe2h\xe4I\x0b\xd9\x98\xee\'\x89"\x1b\xdbf\xd6|\x15,\xd9,\xc3oB\xab\xf2\x8e\xb3\xe3\xae\x93k\xa2|\x1d\xb5\x9e\xce\xd6\xde\xd2k\xe7\x8e\xea\xe6Hc\x11\xb5\xc4\xab\xe5\x15\x91\xc8\xe5\x9cd\xe1\x8eH\xc9\xaf\x97<m\xad\xde?\xed\x11\xa1@o.\x8c"\xce@#2\xb6\xd1\xfb\xb9\x97\xa6q\xf7x\xfaqH\xa4z\xac^#\xb8\xbf\xf0\xe5\x9e\x87oke\x0e\xa5\x18\x8d,\xaeuI\xed\xcc\x97Q\x04\x04\x1d\xcf\x87Dl\xed\xe7\x95\xc0\x038 \x17\xfe/\xbd\xf8w\xf0\xea\xe3V\xbc\xd0\xee\xbca\xad](x\xed,uH\xa3Y\xdaB<\xc6\x89\xa5b\xcd)\xdf\xbc\xa8.@.@U\x06\xbc\x07\xc7z\xb5\xd6\xad\xe3\xaf:\xea\xe6\xe2\xeah\xee\xe5\x8d\x1eY\x0b\xb2\xa8\xb58\x00\x9e\x80zW\xcf:\xc7\x87\xb4\xfbo\x87\xda\xd4\xd1\xd8\xd9\xc72\xdeZ\xa8u\x85C\x00\xcc\xd9\x19\xc7|s\xebX\xb9;\xd8\xd21M\xea}\x19\xe0\xff\x00\x1a\xf8\x8f\xe2&\xa5\xf6\xb8\xfc+\xf1\x03\xc0\xb67\x17,m\xae\xa4\xb0\xb7X'
# b"\xe3\x92%Q#I$\xb2\x99>\\\x8cm\n\x08$\x81\x82q\xe7\xff\x00\x1d?o\x1f\r|\x00\xb4\xbc\xd0t+\x88<u\xe2\x07\xfd\xdaK%\xbc&\x1bC\x9c\x8d\xd2\xaa\xeev\xcf$+\x10Oq\xc8\xab\xdf\xb7\xe5\xdc\xbe\x10\xfd\x8e\xf4\x98t\x99$\xd2\xe1\x98\xa4RGh\xc6\x05t\xd9\x9d\xa4.\x01\x1e\xc7\x8a\xf8\x1f\xe14Kw\xe2\x15iUdm\xf9\xcb\x8d\xd5\x15\xa5\xc8\x95\xb7gM\x1ajj\xefc\xad\xf1g\x8b\xfcU\xfb@\xf8\xbdu\x8f\x18^_j\x96\xf0\xca\xa0\xdaG'\x94\xb1\xa30\x1bP`\xacy\xecH\xc7\xeak\xea_\x0f\xfe\xcb~\x1b\xf0&\xa3uq\xe1\xf8m5->KT\x8e\xc7U:\xa4a\xb4]C\x86Ws\x95\xf9U\xb0\xa5\xa4E \x16 0\x00\x99\x7fc\xbf\x0fi\xf7\x03\xc7M%\x8d\x9c\x8d\x1b\xc6T\xb4*J\xfc\x91t\xe2\xbe\x9f\xd1\xfc!\xa4\xdbx\x16\xdeH\xf4\xbd:9.T$\xce\xb6\xc8\x1aU\xe3\x868\xe4{\x1a\xcdJ\xda\xbdY3\x93\x96\x9d\x0f5\xb8\xf0>\xb9\xe1\x8d*\xe2\x0bO\x88wV>$\xd4\x0cW\xfa\x93\xb6\xbdg\xfd\x91\xab\xc6AP\x8bx\xb2)e\n\x8a\x0c-\x1b\xa0\x03\xa89\xac\xcd2\xd3\xc4\x9f\x0en\xa6k\x96\xd2m\xe6S,\x88\x96~)\x8a(\xe4%Fp\xd1\xe0\x12p\x83\xe7\x00\x02\xcb\xc6I\xafO\xf8\xdd\xe0}\x17@\xf8_\xa2Mc\xa3\xe9vSMu\xb6G\x82\xd28\xd9\xc6\xd98%@\xcfA\xd7\xd0WE\xf0\xae\xe6K\xd9<6f\x92I\x8a\x81\x18.\xc5\xb0\xaa\x84\x01\xcf`\x00\x00v\xc0\xa27d]$q~\x1c\xf1\xe6\xaf{c6\xa2\xba\xad\xe6\x9b\xabC<\x7f\xbb\x8f\xc4\xe95\xb5\xc4{\x02\x06B\xf8\x1b\x95\xb2J\x15\x07\x82rA9\xf4M\x0f\xc4\xdf\x10\x99D\xd6\xfe,\xd4\xaf\xa3\x85\x96\x15\xb3\xb0\x9d\xee\x16U\xc9\xcf\xfa\xb0c=v\x9d\xc5@\x00\x1c\x900y=/\xc3\x1an\xafgo}w\xa7\xd8\xdd^\xff\x00iD~\xd14\n\xf2"
# b'\xe5\x9a=\xdf1\x19\xe7\xbf<\xd6^\x89\xa0X\xa6\xafj\xabeh\xaa\xd6rd\x08W\x9f\xdeI\xedW&\xe2%ft^3\xf1\'\xc5M\x03\\\xb1\x9a\xfbK\xf1~\xa9k\xb1\x14.\x9a\x168\xf2\xcc\xd1\x82\xfd76\x19A\x0eH\x01w|\xa7&\xa3\xd5f\xd5\x1d\x1a\xe3Z\xf0\xff\x00\x8c4\xfb\x81\x1e\xfd\xff\x00g\xfbK#n\x0b\xff\x00,\xf7\x8c\x05l\x81\x82r:c&\xb1|)\xe2MF\xea\xff\x00\xc5+-\xfd\xec\x8bo2$A\xe7f\x11\xaf\x90\x0e\x17\x9e\x06y\xc0\xaeG\xe2\x07\x8fu\xcbM\n\xc5\xa2\xd6\xb5h\xd9\x9d\x81)w"\x93\x87lw\xedF\xb7\xb0\x8fX\xf0\xcf\x80?\xe13\xd4\xe6[\x9f\x11kV\xb1\xc3\x1a\xca\xb0Mm\xcb\xf4\x0cvy\x19_\x9b\x8c\x8d\xc5y\xe6\xba\x8d\x03\xc1\x16\xfe\x19\xb5K\xe9>$i\xac\x96\xe8\xc9\x1cz\xb5\xbcp\xc7,\xdd0\x82e\x8c3\x0eX\xa8\xc9*\t\xca\x81\x91\xf2\xbd\x87\xc5O\x14O5\xf2\xc9\xe2My\xd68\x83(mBS\xb4\xef<\x8f\x9a\xbdw\xe1\x7f\x88u\roJ\x87\xed\x97\xd7\x97\x9b\xa2\\\xf9\xd34\x99\xfd\xe0\xf55\xac6Bq=\xc7\xc6_\x19,\xfc\x0b\x0e\x93k\xe2\x1d[LHX\xee\x95\xae\x1a;U@\xe0\xe1\x91w\xb0l\xe4\x9c\x06\xce\x1b \x1e\x95\xe7?\x18~\'G\xf1\x03C\xd3\xf4\xbf\x0c\xa40\xdf\xdf\xdc;\xde\xdd\xaa\xa7\x91\x15\xba\x10\xa4\x08\xfe\xfb3\xb6\xc6.\xac\x08\x00\x02\xa41j\xea\xad\xec \x92\xd6\xcav\x86\x16\x99\xa0x\xcc\x85\x06\xe2\xbb\xfag\xae=\xab\x8c\x16p\xa1\xd4.\x041\x8b\x81<\xa4J\x14o\xc9PO=y\xaa\x87\xbd.Q=\x11\xf1\xb7\xed\x9d\xf1\x86\x0f\x17\xea\xf0\xfc\x1c\xd0uU\x8aK8\xd1\xb5o$H\xd2j\x12\xe7?e\x8b\x86\x1b\xb3\x96*\xc4\x02H\\\x8cW\xa2|$\xf8\x1b\xe2\xc3\xe1=\x0e\x1b\xc9\xbc\x17t\xbal\x1ff\x88\xbe\x98\xf0_y\x7f3\xec\x98ad2\x0c\xba\x82\xc1\x94\x10\xa4\x13\x83\x8f\x81'
# b'\xb5\x8dV\xe94\xff\x00\x1a]\xad\xcd\xc2\xdd}\xa9$\xf3\x84\x87\xcc\xdd\xf6\x86\xf9\xb7u\xcf\xbd}\xad\xfb!\xdfM\xac\xfc/\xf0|\xd7\x93Ku5\xd9\x81\xa7y\x98\xc8\xd3\x1f:Q\x96\'\x96\xfb\xab\xd7\xfb\xa3\xd2\xaeR\xd6\xe4\xb8\xddX\xf7\xb1\xa6j\xd6\x9e!\x92\xd2\xde5\x1ao\x9f \x92\xec]\xac\x8a\xaa\xb9\x07v\xef\x99p\xc0\x8c\xb0\x03\xa7\xca3\x80kZ\x14\xb1\xd8\xe9\xed\r\xd4\xedmk"\xc1\x1a\xccbxl\xa3\r\xb4\x05\x0e\xeb\xb65\xe4\x10\x83\x1d\xf1\x90+\xaf\xb5\xb7\x8e\x0f\x0f\xccR4B\xb7NF\xd5\xc6\x0e\xee\xb5\xe2Z\xae\xb9z>3_[\xfd\xb2\xeb\xec\xe6"\x86/5\xb6\x15\xf2\x18\xe3\x19\xc6=\xaaA\x0b\xaciz\xa5\xd4z\x9d\xfd\xbe\x90<Ioc8u\xb8r\xb0\xdb\xda\x07\xf9\x86\xd3\x14N\x1f\x19\xe8\xc0\x920q\x91\x91\xfb7\xfb\x19\xe8\x93|\x04\xfd\x96\xfc#\xa5\xdc\xdb\xebZn\xb5}f\xba\x8e\xa0\x86\xc9fS<\xc0;\r\xdcn\xda\x08\\\x82\t\xda8\x04`~F\xfcm\xf1N\xa9\xa1|J\xf8]cc\xa9_\xd9\xd9j\x9a\xad\x92\xde\xdb\xc1p\xf1\xc5v\x19\xe3\x04H\xa0\x80\xf9\xcf;\x81\xcd~\xf2|@\x89WC\xb7\xc2\xa8\xc2\x0c`t\xa9\x8f\xf3\x137\xaaG\x81\xfcs\xf1\xf5\xd7\x88\xec~\xcd\x1f\x88/\xe6\x8aB\x04\x96\x13\xda\x1br\xdd=\xb1\x8c\x8e>l\xfbW\x93\xc4\x86\xd4\x9f\xf4}\xac\xbc\xb8?1\xf5\xf5\xef\xf5\xe4\xd7\xa1~\xd3\x0e\xc6\xd7M\xe4\xfd\xe0\x7f\x95yE\xac\xce\xb7\x96\xb8f\x1b\xba\xe0\xf5\xace&\xcd"\xac\x8e\x81u6h72\xc9\x81\xc9"#\xb9O\x03\xf5\xf5\x1csV\xe3\xd5\x92\x18\xb74M\xeeLg\x9fO\xce\xaaGq"[\xdb\xed\x91\xc6[\x9c\x1e\xbc\x1a[\xe7o\xb3\xaf\'\xbf\xf2\xa8\xb1E\x87\xf1\xa5\x9c\x01\x83\x86\x8f\x18\xca\xe3\xa7\xf2\xa2/\x1d\xda1*\x8d\x8fO\x9b\x83\x8a\xe3\xb5v)\x9d\xbc}?\n\xac\x1bn\xa0\xca8]\x9d\x050;\xe1\xe3\xa8Y'
# b'x\x1f\x8a\x8a\xb5\x07\x89\x12\xe8\xb2\xe3,\x06}\xeb\xcfmF\xebt\xcf<\x1f\xe7V\xac\x1d\x96\xfdpH\xe1z~\x14\x01\xdbM|\xd0\x8d\xfbU{\xf3U\xe6\xd7D\xc1w\x0c\x95\x19\xe9\xfe\x7f*ls3Zr\xccz\xf55\x0c*\x08\xe8:\xfaU%rv$\x93^\xc21T\xcf\xa1#\x82*\xbc7o1\x91\x968\xf0\xc7;}j=Dy1|\x9f/\'\xee\xf1\xde\xb4 \x1f/\xfc\x04Rj\xc5"/\xb3C\xaa\xd8\xb6\xf1\xb7\x8c0\xc608\xe3\xa8\xfc\xfe\xbcV\x1d\xf7\x86\xed\x03\xf9muy\x08|\x91\xb6R\xd8\xc7=?Lg\x07\xd0\xd6\xfc\\\\7\xd0\xff\x00Z\xc0\xd7$d\xd4\xe1\xda\xcc9=\r.\xa0A\x1f\x86\xcc\x96\xe1\xa0\xbfs\xc6\x182ry\xfa{\xe0\x8cw\xab\x16~\x1a\xba\xbb\x89\xc4w\x8b\x18\xe0\x82c\xceH\xc1\xe3\xa7\xe9\x8f\xadW\xb6\x95\x97W\xe1\x98d\xaepz\xd7\\\xaa\x1a\xde\x1c\x8c\xf2\xbf\xca\xab\xc8\x0c\x06\xf0u\xf4\xf1mk\xa8d\xde\xb8,\x14\xee<\xfb\x92?\x0e}9\xab:w\x85\xa5\xd1\xa7b\xb1\xc6\xd1c\xf8@\x18\xf6\xe9\xfa\x0fJ\xd4\xbfP\xa7\x81\x8f\x9b\xb5S\x12\xb1\xb7u\xdc\xdbw\x0e3\xf5\xa0\x99\x0f\x1e\x17\xb1\x96O1\x99\x95[\x05T}\xd5\xc7\xf9\xef\xd8S/<\x16\x8ft.\xac\xae\xa4\xb6|\x0c\x86r\xd1\xb7\xe1\xfd\x07\x04~\x18\x8c\xbb\x18\x9b\x93\xd4\xd4vS0\xb9\xfb\xcd\xd0w\xa2\xf7W\x1f\x99rm\x12H\xd62%\x8d\xe4\x03\x0c\x0f\xddo\xa7\x7f\xcc\x9c\x13\xf9\xf1\xbf\x18\xbc\x0f\x1f\x8e<\x1d}d\xdad7\x9et-\x1c\x96\xa6`\xaa\xe5\x86\x06\x18\xfd\xd2\t\xdc\x0e{c\x90k\xbb\x80\xee^y\xe2\x8b\xb5\x01I\xc74\xae3\xf3\xc3\xc5\x9f\xf0I?\r\xf8\xb7W\xbc\xbb\xbc\xf0N\xa0\xd7\xf7X-tu+y<\xd1\xee\xb8\x18\xc7@W\x1d\x00\xae\x03U\xff\x00\x82\x17hO\xe2?\xedk[?\x13i\xf7h\xc1\xd0\xc7w\x1bmn\x00\xfb\xae\x08\xf48>\xbc\xf3_'
# b'\xaa3(\x12t\x1d\x0fj\xaf4J\x8ep\xaa>^\xc2\x9f4\xb6\xb96[\x9f9~\xcf\x1f\x07\xf5\x0f\x87:\x1c~\x17\xd4,\xb5\t,,\x86\xfbK\xb3\x13\xc6\xd1\x06%\x99\x1b\xe7l\xfc\xc7 \xe0p\xd8\xe4\x01]\xb7\x8d>\x11\xc3\x14\x01\xb4\xdb\xeb\xb9$bZH\xa7\xe1A\xeb\xc1\xc1\xeb\xef\x8f\xadz\xfa\x1d\xc8s\xe9U\xdc\xef\xb5\x9bw?\xbc^\xbf\x85\x0b]\xc1F\xc7\xca\xfa\xff\x00\xc3\xadb\xdavi\x82\xdd\xa2\xaevI\x86\xdaz\xf0x>\xd8\x03<\xf45\x8b\xa9\xf8\xa7\xfb\x14\xab^iPy+\x1e\xc9b!\xb6\xb8<\x1e\x0f\xe0z\x11\xcex\xc0\xaf\xa9\xbcYc\x04\x9aj\xc8\xd0\xc4\xd2m\xfb\xc5\x06z\x9e\xf5\xe0\x7f\x19O\xd9\xe2\xdd\x1f\xee\xdb\xcdnW\x8a9n\xac\xca\xf3>E\xfd\xbf\xbc;\xa6\xa7\xc1)\xf5\r%\xe6\xb6\x8eK\x88Y\xac\x98\xefE\x04\x92\x1dO^\xe4`\x8c\x8c\xf5#\x15O\xf6P\x9e;\x9f\x80z\x0c\x97\x13O\x1a\xc3\x0c\x90*n\xc3\x1f\xde\xb1\xf9}s\xd8\x0e\x87\x02\xae\xfe\xddc?\xb3\x96\xa8\xdf\xc5\x1d\xfc*\xa7\xba\x82\xc3 }kk\xe0-\xacO\xff\x00\x04\xe8\xf0M\xd3G\x1b\\\xad\xfd\xdcbR\xa3\xcc\x0b\xe7Hv\xee\xeb\x8fj\xf1q\xb8X(5\x1d\x16\xe6\x98Z\xadc\x14\x9fUcV\rj\xdb\xc4\x16\xf7\x16j\xb7H\xb0\xae\xf7-.&\x1c\xe7\x1dq\xc7\xa5,\x97\x16\xf6\x82(e\xb7\xfe\xd0\xdfnYD\x8a\xbecd|\xa0w\x1d\xf1\xc8$\x8e\xf9\xacm\x16%\xb7\xf1\xcbyj\xb1\xf9\x8d\xf3\xed\x18\xdd\xf5\xf5\xae\xfb\xc51+k\xfa~UN\xebq\x9e:\xe3v+\xe7d\x9a\x97*g\xd1\xf3_C\xff\xd9'

# %% [markdown]
# La salida comienza con las cabecera que el servidor web envía para describir el documento. Por ejemplo Content-Type indica que es imagen en formato jpeg (image/jpeg). A continuación de la cabecera, añade una línea en blanco para indicar el final de la misma, y envía los datos reales del fichero.
#
#
# Se puede mejorar el programa guardando los datos en una cadena, recortando las cabeceras y luego guardando los datos de la imagen en un archivo.

# %%
import socket
import time

misock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
misock.connect(('4.bp.blogspot.com', 80))
cmd = 'GET http://4.bp.blogspot.com/-aqPvTTwBDJQ/W4FInd5fTtI/AAAAAAAACkY/6536BHcuVlEh4YTRqIVi6DUFGb1FZWEWQCK4BGAYYCw/s1600/DSC_0166-1.jpg HTTP/1.0\r\n\r\n'.encode()
misock.send(cmd)
contador=0
imagen="".encode()
while True:
    datos = misock.recv(5120)
    if (len(datos) < 1):
        break
    imagen=imagen+datos
misock.close()

#Búsqueda del final de la cabecera
pos=imagen.find("\r\n\r\n".encode())
print (imagen[:pos])

#Saltar la cabecera y guardar los datos de la imagen
imagen=imagen[pos+4:]
manf=open("tren.jpg","wb")
manf.write(imagen)
manf.close()
# Out:
# b'HTTP/1.0 200 OK\r\nAccess-Control-Expose-Headers: Content-Length\r\nETag: "va47"\r\nExpires: Wed, 16 Oct 2019 01:47:09 GMT\r\nContent-Disposition: inline;filename="DSC_0166-1.jpg"\r\nContent-Type: image/jpeg\r\nVary: Origin\r\nAccess-Control-Allow-Origin: *\r\nTiming-Allow-Origin: *\r\nX-Content-Type-Options: nosniff\r\nDate: Tue, 15 Oct 2019 09:10:55 GMT\r\nServer: fife\r\nContent-Length: 341437\r\nX-XSS-Protection: 0\r\nCache-Control: public, max-age=86400, no-transform\r\nAge: 0'

# %% [markdown]
# Una vez que el programa termina, se pueden ver los datos de la imagen abriendo el archivo tren.jpg con un editor de imágenes.

# %%
from IPython.display import Image
Image(filename='tren.jpg')

# %% [markdown]
# __Recuperación con el módulo urllib__
#
# urllib es una librería que permite tratar una página web de forma parecida a la apertura de un fichero, de forma que la librería gestiona de manera transparente todo lo referente al protocolo HTTP y los detalles de la cabecera.
#
# Una vez que la página web ha sido abierta con urllib.request.urlopen, se puede tratar como un archivo y leer a través de ella usando un bucle for.
#
# Cuando se recupera la página web, sólo se accede al contenido puesto las cabeceras aunque se envián,  el código de urllib se queda con ellas y sólo devuelve los datos.
#
# En el siguiente ejemplo se recupera la información de una página web

# %%
import urllib.request

manf = urllib.request.urlopen('http://informatica.ucm.es')
for line in manf:
    print(line.decode().strip())
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
# <meta charset="UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <title>Facultad de Informática</title>
#
# <meta name="description" content="La Universidad Complutense de Madrid es una institución de larga trayectoria y amplio reconocimiento social que aspira a situarse entre las primeras universidades de Europa y a consolidarse como centro de referencia para el continente latinoamericano" />
# <meta name="keywords" content="Universidad Complutense de Madrid, Complutense, UCM, Educación, Innovación, Universidad de excelencia, Formación, Grado, Máster, Doctorado, Postgrado" />
# <link rel="apple-touch-icon" href="/themes/ucm16/media/img/logoucm.ico" />
# <link rel="shortcut icon" href="/themes/ucm16/media/img/logoucm.ico" />
# <link rel="icon" href="/themes/ucm16/media/img/logoucm.ico" />
# <link type="text/css" media="screen" rel="stylesheet" href="/themes/ucm16/css/bootstrap.css" />
# <link type="text/css" media="all" rel="stylesheet" href="/themes/ucm16/css/font-awesome.min.css" />
# <link type="text/css" media="screen" rel="stylesheet" href="/themes/ucm16/css/ucm-theme.css" />
# <link type="text/css" media="screen" rel="stylesheet" href="/themes/ucm16/css/ucm.css" />
# <link type="text/css" media="screen" rel="stylesheet" href="/themes/ucm16/css/ucm-wg.css" />
# <link type="text/css" media="print" rel="stylesheet" href="/themes/ucm16/css/print.css" />
# </head>
# <body>
# <header>
# <div id="barra">
# <div class="container">
#
# <ul class="ul-menu">
# <li>
# <div id="buscador">
# <form action="https://informatica.ucm.es/buscador" method="get" class="posicion_buscar form-inline" id="formbuscador">
# <label for="search" class="hidden">Buscar en la web</label>
# <input type="search" id="search" name="search" placeholder="Buscar en la web" required />
# <button type="submit" class="botonbusca" id="btsearch" title="Buscar en la web" aria-label="Buscar en la web"><span class="fa fa-search" aria-hidden="true" title="Buscar en la web"></span></button>
# </form>
# <button class="botoncerrar" id="cerrar_buscador" aria-label="Cerrar buscador"><span class="fa fa-times" aria-hidden="true" title="Cerrar buscador"></span></button>
# </div>
# </li>
# <li>
# <nav class="navbar" role="navigation" id="menusuperior">
# <div class="navbar-header">
# <button type="button" class="navbar-toggle" data-toggle="collapse" data-target=".navbar-sup-collapse" id="collapse-personal">
# <span class="sr-only">Desplegar navegación</span>
# <span class="fa fa-user fa-2x"></span>
# </button>
# </div>
# <div id="contenido-menusuperior" class="collapse navbar-collapse navbar-sup-collapse">
# <ul class="nav navbar-nav" >
# <li class="iniciasesion"><a href="https://www.ucm.es/login_sso/" title="Navegar identificado">Navegar identificado</a></li>
# </ul>
# </div>
# </nav>
# </li>
# <li>
# <ul id="lg_items">
#
# </ul>
# </li>
# </ul>
# </div>
# </div>
#
# <div class="container" id="cabecera">
# <div class="row">
# <div class="col-lg-5 col-sm-5 col-xs-12" id="logo">
# <a href="https://www.ucm.es/" title="Universidad Complutense de Madrid">
# <img src="/themes/ucm16/media/img/logo.png" alt="ucm" title="Universidad Complutense de Madrid" />
# </a>
# </div>
# <div class="col-lg-7 col-sm-7 col-xs-12" id="titulo_website">
# <h1 class="web_title" style="font-size: 2.1em;"><a href="https://informatica.ucm.es/" title="Portada - Facultad de Informática">Facultad de Informática</a></h1>
# </div>
# </div>
# </div>
# </header>
#
# <nav class="container navbar navbar-default" role="navigation" id="menu">
# <div class="navbar-header">
# <button type="button" class="navbar-toggle" data-toggle="collapse" data-target=".navbar-ex1-collapse" id="botonmenu">
# <span class="sr-only">Desplegar navegación</span>
# <span class="fa fa-bars"></span>
# </button>
# </div>
#
# <div class="collapse navbar-collapse navbar-ex1-collapse">
#
# <ul class="nav nav-justified" id="contenidomenu">
# <li class="dropdown resalte lead">
# <a title="Facultad" href="/facultad" class="dropdown-toggle" data-toggle="dropdown">Facultad</a>
# <ul class="dropdown-menu" role="menu">
# <li><a title="Historia de la Informática" href="/seminario-de-historia">Historia de la Informática</a></li>
# <li><a title="Presentación" href="/presentacion">Presentación</a></li>
# <li><a title="Gobierno" href="/gobierno">Gobierno</a></li>
# <li><a title="Organización" href="/departamentos_1">Organización</a></li>
# <li><a href="/facultad" title="Facultad" aria-label="Facultad"><span class="fa fa-plus-circle" aria-hidden="true"  title="Facultad"></span></a></li>
# </ul>
# </li>
# <li class="dropdown resalte lead">
# <a title="Titulaciones" href="/estudiar" class="dropdown-toggle" data-toggle="dropdown">Titulaciones</a>
# <ul class="dropdown-menu" role="menu">
# <li><a title="Grado" href="/grado">Grado</a></li>
# <li><a title="Máster" href="/master">Máster</a></li>
# <li><a title="Doctorado" href="/doctorado">Doctorado</a></li>
# <li><a title="Títulos propios" href="/titulos-propios">Títulos propios</a></li>
# <li><a href="/estudiar" title="Titulaciones" aria-label="Titulaciones"><span class="fa fa-plus-circle" aria-hidden="true"  title="Titulaciones"></span></a></li>
# </ul>
# </li>
# <li class="dropdown resalte lead">
# <a title="Estudiantes" href="/estudiantes" class="dropdown-toggle" data-toggle="dropdown">Estudiantes</a>
# <ul class="dropdown-menu" role="menu">
# <li><a title="Programacion docente" href="/programacion-docente">Programacion docente</a></li>
# <li><a title="Prácticas Externas" href="/practicas-de-formacion">Prácticas Externas</a></li>
# <li><a title="Ofertas de Empleo" href="/ofertas-de-empleo">Ofertas de Empleo</a></li>
# <li><a title="Mentorías académicas" href="/mentorias-academicas">Mentorías académicas</a></li>
# <li><a title="Secretaría de Alumnos" href="/secretaria">Secretaría de Alumnos</a></li>
# <li><a title="Movilidad" href="/programas-de-movilidad">Movilidad</a></li>
# <li><a href="/estudiantes" title="Estudiantes" aria-label="Estudiantes"><span class="fa fa-plus-circle" aria-hidden="true"  title="Estudiantes"></span></a></li>
# </ul>
# </li>
# <li class="dropdown resalte lead">
# <a title="Servicios" href="/asistencia" class="dropdown-toggle" data-toggle="dropdown">Servicios</a>
# <ul class="dropdown-menu" role="menu">
# <li><a title="Infraestructuras" href="/infraestructuras">Infraestructuras</a></li>
# <li><a title="Biblioteca" href="http://biblioteca.ucm.es/fdi">Biblioteca</a></li>
# <li><a title="Campus Virtual" href="https://cv.ucm.es/CampusVirtual/jsp/index.jsp">Campus Virtual</a></li>
# <li><a title="Sede Electrónica" href="https://e-administracion.ucm.es/">Sede Electrónica</a></li>
# <li><a href="/asistencia" title="Servicios" aria-label="Servicios"><span class="fa fa-plus-circle" aria-hidden="true"  title="Servicios"></span></a></li>
# </ul>
# </li>
# <li class="dropdown resalte lead">
# <a title="Investigación" href="/investigacion" class="dropdown-toggle">Investigación</a>
# </li>
# <li class="dropdown resalte lead">
# <a title="Sugerencias" href="/buzon-de-sugerencias-y-quejas" class="dropdown-toggle">Sugerencias</a>
# </li>
# </ul>
# </div>
# </nav>
#
# <main id="portada">
#
# <div class="container">
# <div class="row">
# <div class="col-sm-8 col-xs-12" id="marco_01">
# <div class="column" id="lista_1">
#
# <div class="wg_txt">
# <div>
# <div id="not_principal" class="remove_wg_text" style="width: 100%; font-weight: bold; background-color: #000000; background: rgba(0, 0, 0, 0.8); border: 1px solid #808080; color: #ffffff; font-size: 1.1em; padding: 12px;">
# <ul class="menu_pag" style="padding-left: 0px;">
# <ul style="list-style: none;">
# <li style="list-style: none; background-image: none; padding-left: 0px;"><a style="color: #f8cd1e; padding-right: 10px;" title="Eventos y conferencias en la Facultad de Inform&aacute;tica" href="https://informatica.ucm.es/eventos-y-conferencias">Eventos y conferencias</a></li>
# <li style="list-style: none; background-image: none; padding-left: 0px;"><a style="color: #f8cd1e; padding-right: 10px;" title="Delegaci&oacute;n de alumnos y asociaciones en la Facultad de Inform&aacute;tica" href="https://informatica.ucm.es/delegacion-y-asociaciones">Delegaci&oacute;n y asociaciones</a></li>
# <li style="list-style: none; background-image: none; padding-left: 0px;"><a style="color: #f8cd1e; padding-right: 10px;" title="Museo de inform&aacute;tica Garc&iacute;a Santesmases" href="http://www.fdi.ucm.es/migs/" target="_blank">Museo </a></li>
# <li style="list-style: none; background-image: none; padding-left: 0px;"><a style="color: #f8cd1e; padding-right: 10px;" title="Revista de Ciencia Ficci&oacute;n de la Facultad de Inform&aacute;tica" href="http://www.ucm.es/BUCM/revcul/sci-fdi/" target="_blank">Sci_Fdi</a></li>
# <li style="list-style: none; background-image: none; padding-left: 0px;"><a style="color: #f8cd1e; padding-right: 10px;" title="Seminario de Historia de la Inform&aacute;tica" href="https://informatica.ucm.es/seminario-de-historia" target="_blank">Seminario de Historia</a></li>
# </ul>
# </ul>
# </div>
# <p>
# <script type="text/javascript">// <![CDATA[
# (function () {
#
# //Carga dinámica de un script
# //Recibe como parámetro la URL del script y una función para llamar una vez cargado
# function loadScript(url, callback) {
#
# var script = document.createElement("script")
# script.type = "text/javascript";
#
# if (script.readyState) { //IE
# script.onreadystatechange = function () {
# if (script.readyState == "loaded" || script.readyState == "complete") {
# script.onreadystatechange = null;
# callback();
# }
# };
# } else { //Others
# script.onload = function () {
# callback();
# };
# }
#
# script.src = url;
# document.getElementsByTagName("head")[0].appendChild(script);
# }
#
# //Función para ejecutar el código jQuery deseado en la instancia señalada
# function payload(jq) {
# jq(&#039;.remove_wg_txt&#039;).each(function(idx){
# jq(this).parent().parent().css("background-color", "transparent");
# jq(this).parent().parent().attr("style", "background-color: transparent !important");
# });
#
# jq(&#039;.wg_txt&#039;).attr("style", "background-color: transparent !important");
# }
#
#
# //Inyección segura de jQuery sin conflictos
# if (! window.jQuery) { //Si no hay jQuery, lo cargamos y ejecutamos el payload.
# loadScript("//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js", function () {
# var jq = jQuery.noConflict();
# jq(document).ready(function() {
# payload(jq);
# });
# });
# } else { //Si ya hay jQuery, ejecutamos el payload
# jQuery(document).ready(function() {
# payload(jQuery);
# });
# }
#
# })();
# // ]]></script>
# </p>
# </div>
# <div class="spacer"><br/></div>
# </div>
# <div class="wg_txt">
# <div>
# <div id="not_principal" class="remove_wg_text" style="width: 100%; background-color: #000000; background: rgba(0, 0, 0, 0.8); border: 1px solid #808080; color: #ffffff; font-size: 1.1em; padding: 12px;">
# <div style="padding-left: 18px;">
# <h1 style="text-align: center; color: #f8cd1e; font-size: 1.2em;">Grados Oficiales de la Facultad de Inform&aacute;tica</h1>
# <p style="text-align: left; font-weight: bold; width: 80%;">Grados</p>
# </div>
# <div style="clear: both; padding-left: 18px;">
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px; margin-right: 2%;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/grado-ingenieriainformatica">Ingenier&iacute;a Inform&aacute;tica (con grupo biling&uuml;e)</a></div>
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/grado-ingenieriadelsoftware">Ingenier&iacute;a del Software</a></div>
# </div>
# <div style="clear: both; padding-left: 18px;">
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px; margin-right: 2%;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/grado-ingenieriadecomputadores">Ingenier&iacute;a de Computadores</a></div>
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/grado-videojuegos">Desarrollo de Videojuegos</a></div>
# </div>
# <div style="padding-left: 18px;">
# <p style="text-align: left; font-weight: bold; width: 80%;">Dobles grados</p>
# </div>
# <div style="clear: both; padding-left: 18px;">
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px; margin-right: 2%;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/grado-informaticaymatematicas">Ingenier&iacute;a Inform&aacute;tica y Matem&aacute;ticas</a></div>
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/grado-adeinginformatica">Inform&aacute;tica y Administraci&oacute;n y Direcci&oacute;n de empresas</a></div>
# </div>
# <div style="clear: both;">
# <h1 style="text-align: center; font-size: 0.8em; font-weight: bold;"><a style="color: #ffffff;" href="https://informatica.ucm.es/futuros-estudiantes-1">Informaci&oacute;n de inter&eacute;s para futuros estudiantes</a></h1>
# <h1 style="text-align: center; font-size: 0.8em; font-weight: bold;"><a style="color: #ffffff;" href="https://www.ucm.es/proceso-general-de-preinscripcion-y-admision">Tutoriales sobre el proceso de admisi&oacute;n y matr&iacute;cula</a></h1>
# </div>
# </div>
# </div>
# <div class="spacer"><br/></div>
# </div>
# <div class="wg_txt">
# <div>
# <div id="not_principal" class="remove_wg_text" style="width: 100%; background-color: #000000; background: rgba(0, 0, 0, 0.8); border: 1px solid #808080; color: #ffffff; font-size: 1.1em; padding: 12px;">
# <div style="padding-left: 18px;">
# <h1 style="text-align: center; color: #f8cd1e; font-size: 1.2em;">Conoce nuestros estudios de M&aacute;ster</h1>
# <p style="text-align: left; font-weight: bold; width: 80%;">T&iacute;tulos oficiales</p>
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px; margin-right: 2%;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/master-ingenieriainformatica">Ingenier&iacute;a Inform&aacute;tica</a></div>
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/master-internetcosas">Internet de las Cosas</a></div>
# </div>
# <div style="clear: both; padding-left: 18px;">
# <p style="text-align: left; font-weight: bold; width: 80%;">T&iacute;tulos oficiales interuniversitarios</p>
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px; margin-right: 2%;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/master-ingenieriadesistemas">Ingenier&iacute;a de Sistemas y de Control<br />(UCM/UNED)</a></div>
# <div style="width: 48%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px;"><a style="color: #ffffff;" href="https://informatica.ucm.es/estudios/master-mfingenieriainf">M&eacute;todos Formales en Ingenier&iacute;a Inform&aacute;tica<br />(UCM/UAM/UPM)</a></div>
# </div>
# <div style="clear: both; padding-left: 18px;">
# <p style="position: static; text-align: left; font-weight: bold;">T&iacute;tulos propios</p>
# <div style="width: 32%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-right: 1%; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px;"><a style="color: #ffffff;" href="https://informatica.ucm.es/titulos-propios#desarrolloJuegos">Desarrollo de <br />Videojuegos</a></div>
# <div style="width: 32%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-right: 1%; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px;"><a style="color: #ffffff;" href="https://informatica.ucm.es/titulos-propios#dise&ntilde;oJuegos">Dise&ntilde;o y Desarrollo<br />de Videojuegos</a></div>
# <div style="width: 32%; text-align: center; float: left; font-size: 0.7em; background-color: #800000; border: 1px solid #e9b3b3; margin-bottom: 25px; overflow: hidden; padding-top: 15px; padding-bottom: 15px;"><a style="color: #ffffff;" href="https://informatica.ucm.es/titulos-propios#arteDigital">Arte digital<br />para Videojuegos</a></div>
# <div style="clear: both;">
# <h1 style="text-align: center; font-size: 0.8em; font-weight: bold;"><a style="color: #ffffff;" href="https://informatica.ucm.es/master">Ver todas las titulaciones de M&aacute;ster</a></h1>
# </div>
# </div>
# </div>
# </div>
# <div class="spacer"><br/></div>
# </div>			</div>
# </div>
# <div class="col-sm-4 col-xs-12" id="marco_02">
# <div class="column" id="lista_2">
#
# <div class="wg_txt">
# <div>
# <p style="text-align: center;"><a href="https://www.youtube.com/watch?v=jQhEj_AhuNA&amp;feature=youtu.be&amp;t=1470" target="_blank"><img src="/data/cont/media/www/pag-804/2019-2020/LeccionAperturaCurso.png" alt="Lecci&oacute;n inaugural de apertura de curso, Septiembre 2019" width="100%" />Video de la lecci&oacute;n inaugural en la apertura del curso 2019-2020 por Ricardo Pe&ntilde;a</a></p>
# </div>
# <div class="spacer"><br/></div>
# </div>
# <div class="wg_txt">
# <div>
# <p><img src="https://informatica.ucm.es/data/cont/media/portada/fijas/26-portada-1.jpg" alt="Facultad de Inform&aacute;tica" /></p>
# </div>
# <div class="spacer"><br/></div>
# </div>
# <div class="wg_txt">
# <div>
# <!-- Twitter y cursos -->
# <div style="width: 80%;">
# <p class="remove_wg_txt" style="text-align: center;"><a class="twitter-follow-button" style="margin-left: auto; margin-right: auto;" href="https://twitter.com/informaticaucm">Follow @informaticaucm</a></p>
# <p>
# <script type="text/javascript">// <![CDATA[
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?&#039;http&#039;:&#039;https&#039;;if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+&#039;://platform.twitter.com/widgets.js&#039;;fjs.parentNode.insertBefore(js,fjs);}}(document, &#039;script&#039;, &#039;twitter-wjs&#039;);
# // ]]></script>
# </p>
# <p style="text-align: center;"><a href="http://www.ucm.es/csim" target="_blank"><img src="/data/cont/media/www/pag-804/logo%20CSIM.jpg" alt="Logo Centro Superior de Idiomas Modernos" width="80" height="75" /></a>&nbsp;<a style="text-align: center;" href="http://www.fdi.ucm.es/cfi/" target="_blank"><img src="/data/cont/media/www/pag-804/logoCFI1.png" alt="Logo Cursos de Formaci&oacute;n en Inform&aacute;tica" width="80" height="79" /></a></p>
# </div>
# </div>
# <div class="spacer"><br/></div>
# </div>
# <div class="wg_include"><object width='100%' height='800px' data='https://web.fdi.ucm.es/Avisos_Der.aspx?tipo=8' ><param name='allowfullscreen' value='true' /><param name='allowscriptaccess' value='always' /><param name='movie' value='https://web.fdi.ucm.es/Avisos_Der.aspx?tipo=8' /><embed src='https://web.fdi.ucm.es/Avisos_Der.aspx?tipo=8' type='text/html' allowscriptaccess='always' allowfullscreen='true' width='100%' height='100%'></embed></object>
# </div>			</div>
# </div>
# </div>
# </div>	</main>
#
# <nav class="container text-center">
# <ul class="redes">
# <li><a id="link_yb" href="https://www.youtube.com/user/finformaticaucm" class="redsocial" target="_blank"><img alt="youtube" src="/themes/ucm16/media/img/youtube.png" /></a></li>
# <li><a id="link_tw" href="https://twitter.com/informaticaucm" class="redsocial" target="_blank"><img alt="twitter" src="/themes/ucm16/media/img/twitter.png" /></a></li>
# </ul>
# </nav>
# <footer id="pie">
# <div class="container">
# <div class="row">
# <div class="col-sm-4 col-xs-12">
# <nav id="pie_1">
# <ul>
# <li><a href="https://e-administracion.ucm.es/" title="Sede Electrónica">Sede Electrónica</a></li>
# <li><a href="http://www.ucm.es/fundacion" title="Fundación General">Fundación General</a></li>
# <li><a href="http://www.ucm.es/ucm-en-linea" title="Servicios UCM en línea">Servicios UCM en línea</a></li>
# <li id="1421"><a href="https://informatica.ucm.es/profesores" title="Información a Profesores">Información a Profesores</a></li>
# </ul>
# </nav>
# </div>
# <div class="col-sm-4 col-xs-12">
# <nav id="pie_2">
# <ul>
# <li id="242"><a href="http://informatica.ucm.es/laboratorios-fdi" title="Laboratorios FdI">Laboratorios FdI</a></li>
# <li id="1393"><a href="https://www.fdi.ucm.es/Account/" title="Portal FDI">Portal FDI</a></li>
# <li id="1303"><a href="http://Informatica.ucm.es/buzon-de-sugerencias-y-quejas" title="Sugerencias y Quejas">Sugerencias y Quejas</a></li>
# </ul>
# </nav>
# </div>
# <div class="col-sm-4 col-xs-12 cei">
# <a href="https://www.ucm.es/hrs4r" target="_blank" title="UCM - HR Excellence in Research"><img src="/themes/ucm16/media/img/hr.jpg" alt="HR Excellence in Research" /></a>
# <a href="http://www.campusmoncloa.es/" target="_blank" title="CAMPUS DE EXCELENCIA INTERNACIONAL"><img src="/themes/ucm16/media/img/cei.jpg" alt="CAMPUS DE EXCELENCIA INTERNACIONAL" /></a>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row" id="pie_contacto">
# <div class="col-sm-3 col-xs-12">&copy; Universidad Complutense Madrid</div>
# <div class="col-sm-3 col-xs-12"><a href="/contacto" title="Localización y contacto">Localización y contacto</a></div>
# <div class="col-sm-2 col-xs-12"><a href="/aviso-legal" title="Aviso Legal">Aviso Legal</a></div>
# <div class="col-sm-3 col-xs-12"><a href="https://www.ucm.es/datos-personales" title="Protección de datos">Protección de datos</a></div>
# <div class="col-sm-1 col-xs-12"><a href="https://informatica.ucm.es/rss/rss.php?weid=26" title="RSS">RSS</a></div>
# </div>
# </div>
# </footer>
# <script type="text/javascript" src="/themes/ucm16/js/jquery.min.js"></script>
# <script type="text/javascript" src="/themes/ucm16/js/bootstrap.js"></script>
# <script type="text/javascript" src="/themes/ucm16/js/ucm.js"></script>
# <script type="text/javascript">
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-299350-23', 'ucm.es');
# ga('create', 'UA-299350-1', 'ucm.es', 'ucmHistorico');
# ga('send', 'pageview');
# ga('ucmHistorico.send', 'pageview');
# setTimeout("ga('send','event','NoBounce','page visit over 5 seconds')",5000);
# </script>
#
# </body>
# </html>

# %% [markdown]
# En el siguiente programa se procesa la información de un página web y se calcula la frecuencia de cada palabra:

# %%
import urllib.request
contadores=dict()
manf = urllib.request.urlopen('http://informatica.ucm.es')
for linea in manf:
    palabras=linea.split()
    for palabra in palabras:
        contadores[palabra]=contadores.get(palabra,0)+1
print (contadores)
# Out:
# {b'<!DOCTYPE': 1, b'html>': 1, b'<html': 1, b'lang="es">': 1, b'<head>': 1, b'<meta': 5, b'charset="UTF-8"': 1, b'/>': 14, b'http-equiv="X-UA-Compatible"': 1, b'content="IE=edge">': 1, b'name="viewport"': 1, b'content="width=device-width,': 1, b'initial-scale=1">': 1, b'<title>Facultad': 1, b'de': 50, b'Inform\xc3\xa1tica</title>': 1, b'name="description"': 1, b'content="La': 1, b'Universidad': 3, b'Complutense': 5, b'Madrid': 1, b'es': 1, b'una': 3, b'instituci\xc3\xb3n': 1, b'larga': 1, b'trayectoria': 1, b'y': 19, b'amplio': 1, b'reconocimiento': 1, b'social': 1, b'que': 1, b'aspira': 1, b'a': 4, b'situarse': 1, b'entre': 1, b'las': 3, b'primeras': 1, b'universidades': 1, b'Europa': 1, b'consolidarse': 1, b'como': 2, b'centro': 1, b'referencia': 1, b'para': 4, b'el': 5, b'continente': 1, b'latinoamericano"': 1, b'name="keywords"': 1, b'content="Universidad': 1, b'Madrid,': 1, b'Complutense,': 1, b'UCM,': 1, b'Educaci\xc3\xb3n,': 1, b'Innovaci\xc3\xb3n,': 1, b'excelencia,': 1, b'Formaci\xc3\xb3n,': 1, b'Grado,': 1, b'M\xc3\xa1ster,': 1, b'Doctorado,': 1, b'Postgrado"': 1, b'<link': 9, b'rel="apple-touch-icon"': 1, b'href="/themes/ucm16/media/img/logoucm.ico"': 3, b'rel="shortcut': 1, b'icon"': 1, b'rel="icon"': 1, b'type="text/css"': 6, b'media="screen"': 4, b'rel="stylesheet"': 6, b'href="/themes/ucm16/css/bootstrap.css"': 1, b'media="all"': 1, b'href="/themes/ucm16/css/font-awesome.min.css"': 1, b'href="/themes/ucm16/css/ucm-theme.css"': 1, b'href="/themes/ucm16/css/ucm.css"': 1, b'href="/themes/ucm16/css/ucm-wg.css"': 1, b'media="print"': 1, b'href="/themes/ucm16/css/print.css"': 1, b'</head>': 1, b'<body>': 1, b'<header>': 1, b'<div': 69, b'id="barra">': 1, b'class="container">': 4, b'<ul': 11, b'class="ul-menu">': 1, b'<li>': 3, b'id="buscador">': 1, b'<form': 1, b'action="https://informatica.ucm.es/buscador"': 1, b'method="get"': 1, b'class="posicion_buscar': 1, b'form-inline"': 1, b'id="formbuscador">': 1, b'<label': 1, b'for="search"': 1, b'class="hidden">Buscar': 1, b'en': 13, b'la': 16, b'web</label>': 1, b'<input': 1, b'type="search"': 1, b'id="search"': 1, b'name="search"': 1, b'placeholder="Buscar': 1, b'web"': 2, b'required': 1, b'<button': 4, b'type="submit"': 1, b'class="botonbusca"': 1, b'id="btsearch"': 1, b'title="Buscar': 2, b'aria-label="Buscar': 1, b'web"><span': 1, b'class="fa': 8, b'fa-search"': 1, b'aria-hidden="true"': 6, b'web"></span></button>': 1, b'</form>': 1, b'class="botoncerrar"': 1, b'id="cerrar_buscador"': 1, b'aria-label="Cerrar': 1, b'buscador"><span': 1, b'fa-times"': 1, b'title="Cerrar': 1, b'buscador"></span></button>': 1, b'</div>': 51, b'</li>': 9, b'<nav': 5, b'class="navbar"': 1, b'role="navigation"': 2, b'id="menusuperior">': 1, b'class="navbar-header">': 2, b'type="button"': 2, b'class="navbar-toggle"': 2, b'data-toggle="collapse"': 2, b'data-target=".navbar-sup-collapse"': 1, b'id="collapse-personal">': 1, b'<span': 4, b'class="sr-only">Desplegar': 2, b'navegaci\xc3\xb3n</span>': 2, b'fa-user': 1, b'fa-2x"></span>': 1, b'</button>': 2, b'id="contenido-menusuperior"': 1, b'class="collapse': 2, b'navbar-collapse': 2, b'navbar-sup-collapse">': 1, b'class="nav': 2, b'navbar-nav"': 1, b'>': 1, b'<li': 16, b'class="iniciasesion"><a': 1, b'href="https://www.ucm.es/login_sso/"': 1, b'title="Navegar': 1, b'identificado">Navegar': 1, b'identificado</a></li>': 1, b'</ul>': 13, b'</nav>': 5, b'id="lg_items">': 1, b'class="container"': 1, b'id="cabecera">': 1, b'class="row">': 3, b'class="col-lg-5': 1, b'col-sm-5': 1, b'col-xs-12"': 4, b'id="logo">': 1, b'<a': 9, b'href="https://www.ucm.es/"': 1, b'title="Universidad': 2, b'Madrid">': 1, b'<img': 1, b'src="/themes/ucm16/media/img/logo.png"': 1, b'alt="ucm"': 1, b'Madrid"': 1, b'</a>': 1, b'class="col-lg-7': 1, b'col-sm-7': 1, b'id="titulo_website">': 1, b'<h1': 6, b'class="web_title"': 1, b'style="font-size:': 1, b'2.1em;"><a': 1, b'href="https://informatica.ucm.es/"': 1, b'title="Portada': 1, b'-': 2, b'Facultad': 5, b'Inform\xc3\xa1tica"> ...

# %% [markdown]
# La librería urllib también se puede utilizar para recuperar ficheros que no son de texto  como un archivo de imagen o de video, y para los que se requiere hacer una copia de la URL en un archivo local.
#
# En estos casos se usa el método read para descargar el contenido completo del documento en una variable de tipo cadena y luego escribir la información a un archivo local.

# %%
import urllib.request
img = urllib.request.urlopen('https://www.vialibre-ffe.com/multimedia/galerias/trenesdeantes/03.jpg').read()
manf=open("portada.jpg","wb")
manf.write(img)
manf.close()

# %% [markdown]
# El programa lee todos los datos de una sola vez a través de la red y los almacena en la variable img en la memoria principal  y luego abre el fichero portada.jpg y escribe los datos en el disco. Esto funciona sólo si el tamaño del fichero es menor que el tamaño de la memoria del PC.

# %%
from IPython.display import Image
Image(filename='portada.jpg')

# %% [markdown]
# Pero si se trata de un fichero demasiado grande el programa puede fallar cuando el equipo se quede sin memoria. Para evitar agotar la memoria, se puede recuperar los datos en bloques, y luego escribir cada bloque en el disco antes de recuperar el siguiente. De este modo el programa puede leer archivos de cualquier tamaño sin usar toda la memoria del equipo.
#
# En este ejemplo, se leen 100.000 caracteres cada vez y luego se escriben esos caracteres en el archivo portada.jpg, antes de recuperar los 100.000 caracteres siguientes.

# %%
import urllib.request
img = urllib.request.urlopen('https://www.vialibre-ffe.com/multimedia/galerias/trenesdeantes/03.jpg')
manf=open("portada.jpg","wb")
tamano=0
while True:
    info=img.read(100000)
    if len(info)<1:
        break
    tamano=tamano+len(info)
    manf.write(info)
print(tamano," caracteres copiados")
manf.close()
# Out:
# 68100  caracteres copiados

# %% [markdown]
# Una versión más sofisticada sería:

# %%
import os
import urllib.request
print ("Entrar una url")
urlstr=input().strip()
img = urllib.request.urlopen(urlstr)
words=urlstr.split('/')
fname=words[-1]

if os.path.exists(fname):
    if input("¿Reemplazar archivo "+" S/n?")!="S":
        print ("Datos no copiados")
        exit()
    print ("Reemplazando datos",fname)


manf=open(fname,"wb")
tamano=0
while True:
    info=img.read(100000)
    if len(info)<1:
        break
    tamano=tamano+len(info)
    manf.write(info)
print(tamano," caracteres copiados ", fname)
manf.close()
# Out:
# Entrar una url
# https://www.vialibre-ffe.com/multimedia/galerias/trenesdeantes/17.jpg
# ¿Reemplazar archivo  S/n?S
# Reemplazando datos 17.jpg
# 90044  caracteres copiados  17.jpg

# %% [markdown]
# __Recuperación con el módulo request__
#
# El módulo requests permite bajarse archivos de la red de una forma transparente. No se encuentra instalado por defecto con Python.
#
# La función get() del módulo requests toma una cadena que representa la url que se quiere descargar. El resultado de la llamada es un objeto de tipo Response que contiene la respuesta que el servidor web devuelve como respuesta a la petición.

# %% [raw]
# import request
# res=requests.get("http://informatica.ucm.es")
# if res.status.code==request.codes.ok:
#     print("len(res.text)")
#     print(res.text[:250])

# %% [markdown]
# En el ejemplo además de recuperar la pagina descrita, se ha comprobado que la descarga se ha realizado con éxito chequeando el valor del atributo status_code del objeto Response. Si el valor que toma es requests.codes.ok significa que se ha realizado correctamente, y la descargada se ha almacenado como una cadena en la variable text del objeto Response.
#
# Otra forma de comprobar si una descarga se ha realizado con éxito consiste en utilizar el método raise_for_status() del objeto Response. Este método lanzará una excepción si se ha producido algún error en la descarga y no hará nada en caso de que la descarga se haya realizado con éxito. Es por ello que una buena práctica consiste en encerrar la llamada al método raise_for_status() entre un try/except con el objetivo de tratar los casos en que se produzca una descarga errónea.

# %% [raw]
# import request
# res=requests.get("http://informatica.ucm.es")
# try:
#     res.raise_for_status()
# except:
#     print ("Hubo un problema")

# %% [markdown]
# Observar que es la llamada al método __raise_for_status()__ hay que realizarlo siempre después de llamar al método __requests.get()__ dado que el objetivo es asegurarse que la descarga se realizó con éxito antes de que el programa continúe su ejecución.
#
# Una vez que ha realizado la descarga, lo que interesa es guardar el contenido en un archivo. Para ello se puede utilizar la función __open()__ y el método __write()__. En este sentido lo primero que hay que hacer es abrir un fichero en modo __“wb”__(escribir un modo binario), y a continuación escribir al fichero usando un bucle for que utilice el método __iter_content__ del objeto __Response__.

# %% [raw]
# import request
# res=requests.get("http://informatica.ucm.es")
# try:
#     res.raise_for_status()
#     archivo=open("Archivo.txt","wb")
#     for bloque in res.iter_content(10000):
#        archivo.write(bloque)
#     archivo.close()
# except:
#     print ("Hubo un problema")

# %% [markdown]
# Observar que el método iter_content recupera bloques de contenido en cada iteración a través del bucle. Cada bloque es un conjunto de bytes de datos en un tamaño igual al especificado. Así  mismo observar que el método __write()__ retorna el número de bytes escritos al fichero.

# %% [markdown]
# ### Web Scraping

# %% [markdown]
# El “web scraping” consiste en escribir un programa que finge ser un navegador web y recupera páginas, examinando luego los datos de esas páginas para encontrar ciertos patrones.
#
# Por ejemplo los buscadores:
#
# * Buscan en el código de una página web, extraen los enlaces a otras páginas y recuperan esas páginas, extrayendo los enlaces que haya en ellas y así sucesivamente.
#
# * Usan la frecuencia con que las páginas que encuentra enlazan hacia una página concreta para calcular la “importancia” de esa página, y la posición en la que debe aparecer dentro de sus resultados de búsqueda.
#
# Se van a estudiar dos formas de analizar páginas web:
#
# * Mediante expresiones regulares.
#
# * Mediante la librería BeautifulSoup.

# %% [markdown]
# __Expresiones regulares__
#
# Un forma fácil de analizar HTML consiste en utilizar expresiones regulares para hacer búsquedas repetidas que extraigan subcadenas coincidentes con un modelo concreto.
#
# Considerar por ejemplo una página web que contiene enlaces y se quieren detectar dicho enlaces. Para ello se podría construir una expresión regular  que busque y extraiga los valores de los enlaces:
#
#                                   href=("http://.+?")
#
# La expresión regular busca cadenas que comiencen por “href=”http://”, seguido de uno o más caracteres (“.+?”), seguidos por otra comilla doble. El signo de interrogación añadido a “.+?” indica que se busca la cadena coincidente más pequeña posible.  Por último se añaden paréntesis a la expresión regular para indicar qué parte de la cadena localizada se quiere extraer.

# %%
import urllib.request
import re
url=input("Introduzca url: ")
html=str(urllib.request.urlopen(url).read())
enlaces=re.findall('href="(http://.+?)"',html)
for enlace in enlaces:
    print(enlace)
# Out:
# Introduzca url: http://informatica.ucm.es
# http://biblioteca.ucm.es/fdi
# http://www.fdi.ucm.es/migs/
# http://www.ucm.es/BUCM/revcul/sci-fdi/
# http://www.ucm.es/csim
# http://www.fdi.ucm.es/cfi/
# http://www.ucm.es/fundacion
# http://www.ucm.es/ucm-en-linea
# http://informatica.ucm.es/laboratorios-fdi
# http://Informatica.ucm.es/buzon-de-sugerencias-y-quejas
# http://www.campusmoncloa.es/

# %% [markdown]
# El método findall de las expresiones regulares proporciona una lista de todas las cadenas que coinciden con la expresión regular, devolviendo sólo el texto del enlace situado dentro de las comillas dobles.
#
# Las expresiones regulares funcionan bien cuando el HTML está bien formado y es predecible. Sin embargo si el HTML no está bien construido, se pueden perder parte de los enlaces correctos, o terminar obteniendo datos erróneos.

# %% [markdown]
# __BeautifulSoup__
#
# BeautifulSoup es un módulo para extraer información de un página web.
#
# Se puede descargar e “instalar” desde http://www.crummy.com/software/ o simplemente colocar el archivo BeautifulSoup.py en la misma carpeta que nuestra aplicación.
#
# En este ejemplo se va analizar una página web y se van a extraer todos sus enlaces. Para ello el programa solicita una dirección web, luego abre la página web usando urllib, se leen los datos y se los pasa al analizador BeautifulSoup, que recupera todas las etiquetas de anclas(a) e imprime en pantalla el atributo href de cada una de ellas.

# %%
import urllib
from bs4 import BeautifulSoup
url=input("Introduzca url: ")
html=urllib.request.urlopen(url).read()
soup=BeautifulSoup(html, 'html.parser')
etiquetas=soup("a")
for etiqueta in etiquetas:
    print (etiqueta.get("href",None))
# Out:
# Introduzca url: http://informatica.ucm.es
# https://www.ucm.es/login_sso/
# https://www.ucm.es/
# https://informatica.ucm.es/
# /facultad
# /seminario-de-historia
# /presentacion
# /gobierno
# /departamentos_1
# /facultad
# /estudiar
# /grado
# /master
# /doctorado
# /titulos-propios
# /estudiar
# /estudiantes
# /programacion-docente
# /practicas-de-formacion
# /ofertas-de-empleo
# /mentorias-academicas
# /secretaria
# /programas-de-movilidad
# /estudiantes
# /asistencia
# /infraestructuras
# http://biblioteca.ucm.es/fdi
# https://cv.ucm.es/CampusVirtual/jsp/index.jsp
# https://e-administracion.ucm.es/
# /asistencia
# /investigacion
# /buzon-de-sugerencias-y-quejas
# https://informatica.ucm.es/eventos-y-conferencias
# https://informatica.ucm.es/delegacion-y-asociaciones
# http://www.fdi.ucm.es/migs/
# http://www.ucm.es/BUCM/revcul/sci-fdi/
# https://informatica.ucm.es/seminario-de-historia
# https://informatica.ucm.es/estudios/grado-ingenieriainformatica
# https://informatica.ucm.es/estudios/grado-ingenieriadelsoftware
# https://informatica.ucm.es/estudios/grado-ingenieriadecomputadores
# https://informatica.ucm.es/estudios/grado-videojuegos
# https://informatica.ucm.es/estudios/grado-informaticaymatematicas
# https://informatica.ucm.es/estudios/grado-adeinginformatica
# https://informatica.ucm.es/futuros-estudiantes-1
# https://www.ucm.es/proceso-general-de-preinscripcion-y-admision
# https://informatica.ucm.es/estudios/master-ingenieriainformatica
# https://informatica.ucm.es/estudios/master-internetcosas
# https://informatica.ucm.es/estudios/master-ingenieriadesistemas
# https://informatica.ucm.es/estudios/master-mfingenieriainf
# https://informatica.ucm.es/titulos-propios#desarrolloJuegos
# https://informatica.ucm.es/titulos-propios#diseñoJuegos
# https://informatica.ucm.es/titulos-propios#arteDigital
# https://informatica.ucm.es/master
# https://www.youtube.com/watch?v=jQhEj_AhuNA&feature=youtu.be&t=1470
# https://twitter.com/informaticaucm
# http://www.ucm.es/csim
# http://www.fdi.ucm.es/cfi/
# https://www.youtube.com/user/finformaticaucm
# https://twitter.com/informaticaucm
# https://e-administracion.ucm.es/
# http://www.ucm.es/fundacion
# http://www.ucm.es/ucm-en-linea
# https://informatica.ucm.es/profesores
# http://informatica.ucm.es/laboratorios-fdi
# https://www.fdi.ucm.es/Account/
# http://Informatica.ucm.es/buzon-de-sugerencias-y-quejas
# https://www.ucm.es/hrs4r
# http://www.campusmoncloa.es/
# /contacto
# /aviso-legal
# https://www.ucm.es/datos-personales
# https://informatica.ucm.es/rss/rss.php?weid=26

# %% [markdown]
# Observar que el método BeautifulSoup() también admite como entrada un archivo html que esté descargado en el disco duro local.

# %%
import urllib
from bs4 import BeautifulSoup
html=open("Facultad de Informática.html")
soup=BeautifulSoup(html, 'html.parser')
etiquetas=soup("a")
for etiqueta in etiquetas:
    print (etiqueta.get("href",None))
# Out:
# https://www.ucm.es/login_sso/
# https://www.ucm.es/
# http://informatica.ucm.es/
# http://informatica.ucm.es/facultad
# http://informatica.ucm.es/presentacion
# http://informatica.ucm.es/gobierno
# http://informatica.ucm.es/departamentos_1
# http://informatica.ucm.es/facultad
# http://informatica.ucm.es/estudiar
# http://informatica.ucm.es/grado
# http://informatica.ucm.es/master
# http://informatica.ucm.es/doctorado
# http://informatica.ucm.es/titulos-propios
# http://informatica.ucm.es/estudiar
# http://informatica.ucm.es/estudiantes
# http://informatica.ucm.es/programacion-docente
# http://informatica.ucm.es/practicas-de-formacion
# http://informatica.ucm.es/mentorias-academicas
# http://informatica.ucm.es/secretaria
# http://informatica.ucm.es/programas-de-movilidad
# http://informatica.ucm.es/estudiantes
# http://informatica.ucm.es/asistencia
# http://informatica.ucm.es/infraestructuras
# http://biblioteca.ucm.es/fdi
# https://cv.ucm.es/CampusVirtual/jsp/index.jsp
# https://e-administracion.ucm.es/
# http://informatica.ucm.es/asistencia
# http://informatica.ucm.es/asistencia
# http://informatica.ucm.es/investigacion
# http://informatica.ucm.es/grupos-y-lineas-de-investigacion
# http://informatica.ucm.es/oai
# http://informatica.ucm.es/investigacion
# http://informatica.ucm.es/investigacion
# http://informatica.ucm.es/buzon-de-sugerencias-y-quejas
# http://informatica.ucm.es/grupos-y-lineas-de-investigacion
# http://informatica.ucm.es/oai
# http://informatica.ucm.es/investigacion
# http://informatica.ucm.es/investigacion
# http://informatica.ucm.es/eventos-y-conferencias
# https://informatica.ucm.es/delegacion-y-asociaciones
# http://www.fdi.ucm.es/migs/
# http://www.ucm.es/BUCM/revcul/sci-fdi/
# https://informatica.ucm.es/estudios/grado-ingenieriainformatica
# https://informatica.ucm.es/estudios/grado-ingenieriadelsoftware
# https://informatica.ucm.es/estudios/grado-ingenieriadecomputadores
# https://informatica.ucm.es/estudios/grado-videojuegos
# https://informatica.ucm.es/estudios/grado-informaticaymatematicas
# https://informatica.ucm.es/estudios/grado-adeinginformatica
# https://informatica.ucm.es/futuros-estudiantes-1
# https://www.ucm.es/proceso-general-de-preinscripcion-y-admision
# https://informatica.ucm.es/estudios/master-ingenieriainformatica
# https://informatica.ucm.es/estudios/master-ingenieriadesistemas
# https://informatica.ucm.es/estudios/master-internetcosas
# https://informatica.ucm.es/titulos-propios#desarrolloJuegos
# https://informatica.ucm.es/titulos-propios#dise%C3%B1oJuegos
# https://informatica.ucm.es/titulos-propios#arteDigital
# https://informatica.ucm.es/titulos-propios#seguridad
# https://informatica.ucm.es/master
# https://informatica.ucm.es/xxv-aniversario-de-la-facultad
# http://www.ucm.es/csim
# http://www.fdi.ucm.es/cfi/
# https://www.youtube.com/user/finformaticaucm
# https://twitter.com/informaticaucm
# https://e-administracion.ucm.es/
# http://www.ucm.es/fundacion
# http://www.ucm.es/ucm-en-linea
# https://informatica.ucm.es/profesores
# http://informatica.ucm.es/laboratorios-fdi
# https://www.fdi.ucm.es/Account/
# http://informatica.ucm.es/buzon-de-sugerencias-y-quejas
# http://www.campusmoncloa.es/
# http://informatica.ucm.es/contacto
# http://informatica.ucm.es/aviso-legal
# http://informatica.ucm.es/rss/rss.php?weid=26

# %% [markdown]
# El método BeautifulSoup() genera un objeto de tipo BeautifulSoup que tiene un conjunto de métodos que se pueden utilizar para localizar partes específicas de un documento html.
#
# En el siguiente ejemplo se van a extraer varías partes de una etiqueta.

# %%
import urllib
from bs4 import BeautifulSoup
url=input("Introduzca url: ")
html=urllib.request.urlopen(url).read()
soup=BeautifulSoup(html, 'html.parser')
#Recupera todas las etiquetas de anclaje
etiquetas=soup("a")
#Busca las partes de una etiqueta
for etiqueta in etiquetas:
    print("ETIQUETA: ", etiqueta)
    print("URL:",etiqueta.get("href",None))
    print("Contenidos:",str(etiqueta.contents[0]))
    print("Atributos:",etiqueta.attrs)
# Out:
# Introduzca url: http://informatica.ucm.es
# ETIQUETA:  <a href="https://www.ucm.es/login_sso/" title="Navegar identificado">Navegar identificado</a>
# URL: https://www.ucm.es/login_sso/
# Contenidos: Navegar identificado
# Atributos: {'href': 'https://www.ucm.es/login_sso/', 'title': 'Navegar identificado'}
# ETIQUETA:  <a href="https://www.ucm.es/" title="Universidad Complutense de Madrid">
# <img alt="ucm" src="/themes/ucm16/media/img/logo.png" title="Universidad Complutense de Madrid"/>
# </a>
# URL: https://www.ucm.es/
# Contenidos:
#
# Atributos: {'href': 'https://www.ucm.es/', 'title': 'Universidad Complutense de Madrid'}
# ETIQUETA:  <a href="https://informatica.ucm.es/" title="Portada - Facultad de Informática">Facultad de Informática</a>
# URL: https://informatica.ucm.es/
# Contenidos: Facultad de Informática
# Atributos: {'href': 'https://informatica.ucm.es/', 'title': 'Portada - Facultad de Informática'}
# ETIQUETA:  <a class="dropdown-toggle" data-toggle="dropdown" href="/facultad" title="Facultad">Facultad</a>
# URL: /facultad
# Contenidos: Facultad
# Atributos: {'title': 'Facultad', 'href': '/facultad', 'class': ['dropdown-toggle'], 'data-toggle': 'dropdown'}
# ETIQUETA:  <a href="/seminario-de-historia" title="Historia de la Informática">Historia de la Informática</a>
# URL: /seminario-de-historia
# Contenidos: Historia de la Informática
# Atributos: {'title': 'Historia de la Informática', 'href': '/seminario-de-historia'}
# ETIQUETA:  <a href="/presentacion" title="Presentación">Presentación</a>
# URL: /presentacion
# Contenidos: Presentación
# Atributos: {'title': 'Presentación', 'href': '/presentacion'}
# ETIQUETA:  <a href="/gobierno" title="Gobierno">Gobierno</a>
# URL: /gobierno
# Contenidos: Gobierno
# Atributos: {'title': 'Gobierno', 'href': '/gobierno'}
# ETIQUETA:  <a href="/departamentos_1" title="Organización">Organización</a>
# URL: /departamentos_1
# Contenidos: Organización
# Atributos: {'title': 'Organización', 'href': '/departamentos_1'}
# ETIQUETA:  <a aria-label="Facultad" href="/facultad" title="Facultad"><span aria-hidden="true" class="fa fa-plus-circle" title="Facultad"></span></a>
# URL: /facultad
# Contenidos: <span aria-hidden="true" class="fa fa-plus-circle" title="Facultad"></span>
# Atributos: {'href': '/facultad', 'title': 'Facultad', 'aria-label': 'Facultad'}
# ETIQUETA:  <a class="dropdown-toggle" data-toggle="dropdown" href="/estudiar" title="Titulaciones">Titulaciones</a>
# URL: /estudiar
# Contenidos: Titulaciones
# Atributos: {'title': 'Titulaciones', 'href': '/estudiar', 'class': ['dropdown-toggle'], 'data-toggle': 'dropdown'}
# ETIQUETA:  <a href="/grado" title="Grado">Grado</a>
# URL: /grado
# Contenidos: Grado
# Atributos: {'title': 'Grado', 'href': '/grado'}
# ETIQUETA:  <a href="/master" title="Máster">Máster</a>
# URL: /master
# Contenidos: Máster
# Atributos: {'title': 'Máster', 'href': '/master'}
# ETIQUETA:  <a href="/doctorado" title="Doctorado">Doctorado</a>
# URL: /doctorado
# Contenidos: Doctorado
# Atributos: {'title': 'Doctorado', 'href': '/doctorado'}
# ETIQUETA:  <a href="/titulos-propios" title="Títulos propios">Títulos propios</a>
# URL: /titulos-propios
# Contenidos: Títulos propios
# Atributos: {'title': 'Títulos propios', 'href': '/titulos-propios'}
# ETIQUETA:  <a aria-label="Titulaciones" href="/estudiar" title="Titulaciones"><span aria-hidden="true" class="fa fa-plus-circle" title="Titulaciones"></span></a>
# URL: /estudiar
# Contenidos: <span aria-hidden="true" class="fa fa-plus-circle" title="Titulaciones"></span>
# Atributos: {'href': '/estudiar', 'title': 'Titulaciones', 'aria-label': 'Titulaciones'}
# ETIQUETA:  <a class="dropdown-toggle" data-toggle="dropdown" href="/estudiantes" title="Estudiantes">Estudiantes</a>
# URL: /estudiantes
# Contenidos: Estudiantes
# Atributos: {'title': 'Estudiantes', 'href': '/estudiantes', 'class': ['dropdown-toggle'], 'data-toggle': 'dropdown'}
# ETIQUETA:  <a href="/programacion-docente" title="Programacion docente">Programacion docente</a>
# URL: /programacion-docente
# Contenidos: Programacion docente
# Atributos: {'title': 'Programacion docente', 'href': '/programacion-docente'}
# ETIQUETA:  <a href="/practicas-de-formacion" title="Prácticas Externas">Prácticas Externas</a>
# URL: /practicas-de-formacion
# Contenidos: Prácticas Externas
# Atributos: {'title': 'Prácticas Externas', 'href': '/practicas-de-formacion'}
# ETIQUETA:  <a href="/ofertas-de-empleo" title="Ofertas de Empleo">Ofertas de Empleo</a>
# URL: /ofertas-de-empleo
# Contenidos: Ofertas de Empleo
# Atributos: {'title': 'Ofertas de Empleo', 'href': '/ofertas-de-empleo'}
# ETIQUETA:  <a href="/mentorias-academicas" title="Mentorías académicas">Mentorías académicas</a>
# URL: /mentorias-academicas
# Contenidos: Mentorías académicas
# Atributos: {'title': 'Mentorías académicas', 'href': '/mentorias-academicas'}
# ETIQUETA:  <a href="/secretaria" title="Secretaría de Alumnos">Secretaría de Alumnos</a>
# URL: /secretaria
# Contenidos: Secretaría de Alumnos
# Atributos: {'title': 'Secretaría de Alumnos', 'href': '/secretaria'}
# ETIQUETA:  <a href="/programas-de-movilidad" title="Movilidad">Movilidad</a>
# URL: /programas-de-movilidad
# Contenidos: Movilidad
# Atributos: {'title': 'Movilidad', 'href': '/programas-de-movilidad'}
# ETIQUETA:  <a aria-label="Estudiantes" href="/estudiantes" title="Estudiantes"><span aria-hidden="true" class="fa fa-plus-circle" title="Estudiantes"></span></a>
# URL: /estudiantes
# Contenidos: <span aria-hidden="true" class="fa fa-plus-circle" title="Estudiantes"></span>
# Atributos: {'href': '/estudiantes', 'title': 'Estudiantes', 'aria-label': 'Estudiantes'}
# ETIQUETA:  <a class="dropdown-toggle" data-toggle="dropdown" href="/asistencia" title="Servicios">Servicios</a>
# URL: /asistencia
# Contenidos: Servicios
# Atributos: {'title': 'Servicios', 'href': '/asistencia', 'class': ['dropdown-toggle'], 'data-toggle': 'dropdown'}
# ETIQUETA:  <a href="/infraestructuras" title="Infraestructuras">Infraestructuras</a>
# URL: /infraestructuras
# Contenidos: Infraestructuras
# Atributos: {'title': 'Infraestructuras', 'href': '/infraestructuras'}
# ETIQUETA:  <a href="http://biblioteca.ucm.es/fdi" title="Biblioteca">Biblioteca</a>
# URL: http://biblioteca.ucm.es/fdi
# Contenidos: Biblioteca
# Atributos: {'title': 'Biblioteca', 'href': 'http://biblioteca.ucm.es/fdi'}
# ETIQUETA:  <a href="https://cv.ucm.es/CampusVirtual/jsp/index.jsp" title="Campus Virtual">Campus Virtual</a>
# URL: https://cv.ucm.es/CampusVirtual/jsp/index.jsp
# Contenidos: Campus Virtual
# Atributos: {'title': 'Campus Virtual', 'href': 'https://cv.ucm.es/CampusVirtual/jsp/index.jsp'}
# ETIQUETA:  <a href="https://e-administracion.ucm.es/" title="Sede Electrónica">Sede Electrónica</a>
# URL: https://e-administracion.ucm.es/
# Contenidos: Sede Electrónica
# Atributos: {'title': 'Sede Electrónica', 'href': 'https://e-administracion.ucm.es/'}
# ETIQUETA:  <a aria-label="Servicios" href="/asistencia" title="Servicios"><span aria-hidden="true" class="fa fa-plus-circle" title="Servicios"></span></a>
# URL: /asistencia
# Contenidos: <span aria-hidden="true" class="fa fa-plus-circle" title="Servicios"></span>
# Atributos: {'href': '/asistencia', 'title': 'Servicios', 'aria-label': 'Servicios'}
# ETIQUETA:  <a class="dropdown-toggle" href="/investigacion" title="Investigación">Investigación</a>
# URL: /investigacion
# Contenidos: Investigación
# Atributos: {'title': 'Investigación', 'href': '/investigacion', 'class': ['dropdown-toggle']}
# ETIQUETA:  <a class="dropdown-toggle" href="/buzon-de-sugerencias-y-quejas" title="Sugerencias">Sugerencias</a>
# URL: /buzon-de-sugerencias-y-quejas
# Contenidos: Sugerencias
# Atributos: {'title': 'Sugerencias', 'href': '/buzon-de-sugerencias-y-quejas', 'class': ['dropdown-toggle']}
# ETIQUETA:  <a href="https://informatica.ucm.es/eventos-y-conferencias" style="color: #f8cd1e; padding-right: 10px;" title="Eventos y conferencias en la Facultad de Informática">Eventos y conferencias</a>
# URL: https://informatica.ucm.es/eventos-y-conferencias
# Contenidos: Eventos y conferencias
# Atributos: {'style': 'color: #f8cd1e; padding-right: 10px;', 'title': 'Eventos y conferencias en la Facultad de Informática', 'href': 'https://informatica.ucm.es/eventos-y-conferencias'}
# ETIQUETA:  <a href="https://informatica.ucm.es/delegacion-y-asociaciones" style="color: #f8cd1e; padding-right: 10px;" title="Delegación de alumnos y asociaciones en la Facultad de Informática">Delegación y asociaciones</a>
# URL: https://informatica.ucm.es/delegacion-y-asociaciones
# Contenidos: Delegación y asociaciones
# Atributos: {'style': 'color: #f8cd1e; padding-right: 10px;', 'title': 'Delegación de alumnos y asociaciones en la Facultad de Informática', 'href': 'https://informatica.ucm.es/delegacion-y-asociaciones'}
# ETIQUETA:  <a href="http://www.fdi.ucm.es/migs/" style="color: #f8cd1e; padding-right: 10px;" target="_blank" title="Museo de informática García Santesmases">Museo </a>
# URL: http://www.fdi.ucm.es/migs/
# Contenidos: Museo
# Atributos: {'style': 'color: #f8cd1e; padding-right: 10px;', 'title': 'Museo de informática García Santesmases', 'href': 'http://www.fdi.ucm.es/migs/', 'target': '_blank'}
# ETIQUETA:  <a href="http://www.ucm.es/BUCM/revcul/sci-fdi/" style="color: #f8cd1e; padding-right: 10px;" target="_blank" title="Revista de Ciencia Ficción de la Facultad de Informática">Sci_Fdi</a>
# URL: http://www.ucm.es/BUCM/revcul/sci-fdi/
# Contenidos: Sci_Fdi
# Atributos: {'style': 'color: #f8cd1e; padding-right: 10px;', 'title': 'Revista de Ciencia Ficción de la Facultad de Informática', 'href': 'http://www.ucm.es/BUCM/revcul/sci-fdi/', 'target': '_blank'}
# ETIQUETA:  <a href="https://informatica.ucm.es/seminario-de-historia" style="color: #f8cd1e; padding-right: 10px;" target="_blank" title="Seminario de Historia de la Informática">Seminario de Historia</a>
# URL: https://informatica.ucm.es/seminario-de-historia
# Contenidos: Seminario de Historia
# Atributos: {'style': 'color: #f8cd1e; padding-right: 10px;', 'title': 'Seminario de Historia de la Informática', 'href': 'https://informatica.ucm.es/seminario-de-historia', 'target': '_blank'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/grado-ingenieriainformatica" style="color: #ffffff;">Ingeniería Informática (con grupo bilingüe)</a>
# URL: https://informatica.ucm.es/estudios/grado-ingenieriainformatica
# Contenidos: Ingeniería Informática (con grupo bilingüe)
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/grado-ingenieriainformatica'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/grado-ingenieriadelsoftware" style="color: #ffffff;">Ingeniería del Software</a>
# URL: https://informatica.ucm.es/estudios/grado-ingenieriadelsoftware
# Contenidos: Ingeniería del Software
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/grado-ingenieriadelsoftware'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/grado-ingenieriadecomputadores" style="color: #ffffff;">Ingeniería de Computadores</a>
# URL: https://informatica.ucm.es/estudios/grado-ingenieriadecomputadores
# Contenidos: Ingeniería de Computadores
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/grado-ingenieriadecomputadores'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/grado-videojuegos" style="color: #ffffff;">Desarrollo de Videojuegos</a>
# URL: https://informatica.ucm.es/estudios/grado-videojuegos
# Contenidos: Desarrollo de Videojuegos
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/grado-videojuegos'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/grado-informaticaymatematicas" style="color: #ffffff;">Ingeniería Informática y Matemáticas</a>
# URL: https://informatica.ucm.es/estudios/grado-informaticaymatematicas
# Contenidos: Ingeniería Informática y Matemáticas
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/grado-informaticaymatematicas'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/grado-adeinginformatica" style="color: #ffffff;">Informática y Administración y Dirección de empresas</a>
# URL: https://informatica.ucm.es/estudios/grado-adeinginformatica
# Contenidos: Informática y Administración y Dirección de empresas
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/grado-adeinginformatica'}
# ETIQUETA:  <a href="https://informatica.ucm.es/futuros-estudiantes-1" style="color: #ffffff;">Información de interés para futuros estudiantes</a>
# URL: https://informatica.ucm.es/futuros-estudiantes-1
# Contenidos: Información de interés para futuros estudiantes
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/futuros-estudiantes-1'}
# ETIQUETA:  <a href="https://www.ucm.es/proceso-general-de-preinscripcion-y-admision" style="color: #ffffff;">Tutoriales sobre el proceso de admisión y matrícula</a>
# URL: https://www.ucm.es/proceso-general-de-preinscripcion-y-admision
# Contenidos: Tutoriales sobre el proceso de admisión y matrícula
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://www.ucm.es/proceso-general-de-preinscripcion-y-admision'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/master-ingenieriainformatica" style="color: #ffffff;">Ingeniería Informática</a>
# URL: https://informatica.ucm.es/estudios/master-ingenieriainformatica
# Contenidos: Ingeniería Informática
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/master-ingenieriainformatica'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/master-internetcosas" style="color: #ffffff;">Internet de las Cosas</a>
# URL: https://informatica.ucm.es/estudios/master-internetcosas
# Contenidos: Internet de las Cosas
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/master-internetcosas'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/master-ingenieriadesistemas" style="color: #ffffff;">Ingeniería de Sistemas y de Control<br/>(UCM/UNED)</a>
# URL: https://informatica.ucm.es/estudios/master-ingenieriadesistemas
# Contenidos: Ingeniería de Sistemas y de Control
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/master-ingenieriadesistemas'}
# ETIQUETA:  <a href="https://informatica.ucm.es/estudios/master-mfingenieriainf" style="color: #ffffff;">Métodos Formales en Ingeniería Informática<br/>(UCM/UAM/UPM)</a>
# URL: https://informatica.ucm.es/estudios/master-mfingenieriainf
# Contenidos: Métodos Formales en Ingeniería Informática
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/estudios/master-mfingenieriainf'}
# ETIQUETA:  <a href="https://informatica.ucm.es/titulos-propios#desarrolloJuegos" style="color: #ffffff;">Desarrollo de <br/>Videojuegos</a>
# URL: https://informatica.ucm.es/titulos-propios#desarrolloJuegos
# Contenidos: Desarrollo de
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/titulos-propios#desarrolloJuegos'}
# ETIQUETA:  <a href="https://informatica.ucm.es/titulos-propios#diseñoJuegos" style="color: #ffffff;">Diseño y Desarrollo<br/>de Videojuegos</a>
# URL: https://informatica.ucm.es/titulos-propios#diseñoJuegos
# Contenidos: Diseño y Desarrollo
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/titulos-propios#diseñoJuegos'}
# ETIQUETA:  <a href="https://informatica.ucm.es/titulos-propios#arteDigital" style="color: #ffffff;">Arte digital<br/>para Videojuegos</a>
# URL: https://informatica.ucm.es/titulos-propios#arteDigital
# Contenidos: Arte digital
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/titulos-propios#arteDigital'}
# ETIQUETA:  <a href="https://informatica.ucm.es/master" style="color: #ffffff;">Ver todas las titulaciones de Máster</a>
# URL: https://informatica.ucm.es/master
# Contenidos: Ver todas las titulaciones de Máster
# Atributos: {'style': 'color: #ffffff;', 'href': 'https://informatica.ucm.es/master'}
# ETIQUETA:  <a href="https://www.youtube.com/watch?v=jQhEj_AhuNA&amp;feature=youtu.be&amp;t=1470" target="_blank"><img alt="Lección inaugural de apertura de curso, Septiembre 2019" src="/data/cont/media/www/pag-804/2019-2020/LeccionAperturaCurso.png" width="100%"/>Video de la lección inaugural en la apertura del curso 2019-2020 por Ricardo Peña</a>
# URL: https://www.youtube.com/watch?v=jQhEj_AhuNA&feature=youtu.be&t=1470
# Contenidos: <img alt="Lección inaugural de apertura de curso, Septiembre 2019" src="/data/cont/media/www/pag-804/2019-2020/LeccionAperturaCurso.png" width="100%"/>
# Atributos: {'href': 'https://www.youtube.com/watch?v=jQhEj_AhuNA&feature=youtu.be&t=1470', 'target': '_blank'}
# ETIQUETA:  <a class="twitter-follow-button" href="https://twitter.com/informaticaucm" style="margin-left: auto; margin-right: auto;">Follow @informaticaucm</a>
# URL: https://twitter.com/informaticaucm
# Contenidos: Follow @informaticaucm
# Atributos: {'class': ['twitter-follow-button'], 'style': 'margin-left: auto; margin-right: auto;', 'href': 'https://twitter.com/informaticaucm'}
# ETIQUETA:  <a href="http://www.ucm.es/csim" target="_blank"><img alt="Logo Centro Superior de Idiomas Modernos" height="75" src="/data/cont/media/www/pag-804/logo%20CSIM.jpg" width="80"/></a>
# URL: http://www.ucm.es/csim
# Contenidos: <img alt="Logo Centro Superior de Idiomas Modernos" height="75" src="/data/cont/media/www/pag-804/logo%20CSIM.jpg" width="80"/>
# Atributos: {'href': 'http://www.ucm.es/csim', 'target': '_blank'}
# ETIQUETA:  <a href="http://www.fdi.ucm.es/cfi/" style="text-align: center;" target="_blank"><img alt="Logo Cursos de Formación en Informática" height="79" src="/data/cont/media/www/pag-804/logoCFI1.png" width="80"/></a>
# URL: http://www.fdi.ucm.es/cfi/
# Contenidos: <img alt="Logo Cursos de Formación en Informática" height="79" src="/data/cont/media/www/pag-804/logoCFI1.png" width="80"/>
# Atributos: {'style': 'text-align: center;', 'href': 'http://www.fdi.ucm.es/cfi/', 'target': '_blank'}
# ETIQUETA:  <a class="redsocial" href="https://www.youtube.com/user/finformaticaucm" id="link_yb" target="_blank"><img alt="youtube" src="/themes/ucm16/media/img/youtube.png"/></a>
# URL: https://www.youtube.com/user/finformaticaucm
# Contenidos: <img alt="youtube" src="/themes/ucm16/media/img/youtube.png"/>
# Atributos: {'id': 'link_yb', 'href': 'https://www.youtube.com/user/finformaticaucm', 'class': ['redsocial'], 'target': '_blank'}
# ETIQUETA:  <a class="redsocial" href="https://twitter.com/informaticaucm" id="link_tw" target="_blank"><img alt="twitter" src="/themes/ucm16/media/img/twitter.png"/></a>
# URL: https://twitter.com/informaticaucm
# Contenidos: <img alt="twitter" src="/themes/ucm16/media/img/twitter.png"/>
# Atributos: {'id': 'link_tw', 'href': 'https://twitter.com/informaticaucm', 'class': ['redsocial'], 'target': '_blank'}
# ETIQUETA:  <a href="https://e-administracion.ucm.es/" title="Sede Electrónica">Sede Electrónica</a>
# URL: https://e-administracion.ucm.es/
# Contenidos: Sede Electrónica
# Atributos: {'href': 'https://e-administracion.ucm.es/', 'title': 'Sede Electrónica'}
# ETIQUETA:  <a href="http://www.ucm.es/fundacion" title="Fundación General">Fundación General</a>
# URL: http://www.ucm.es/fundacion
# Contenidos: Fundación General
# Atributos: {'href': 'http://www.ucm.es/fundacion', 'title': 'Fundación General'}
# ETIQUETA:  <a href="http://www.ucm.es/ucm-en-linea" title="Servicios UCM en línea">Servicios UCM en línea</a>
# URL: http://www.ucm.es/ucm-en-linea
# Contenidos: Servicios UCM en línea
# Atributos: {'href': 'http://www.ucm.es/ucm-en-linea', 'title': 'Servicios UCM en línea'}
# ETIQUETA:  <a href="https://informatica.ucm.es/profesores" title="Información a Profesores">Información a Profesores</a>
# URL: https://informatica.ucm.es/profesores
# Contenidos: Información a Profesores
# Atributos: {'href': 'https://informatica.ucm.es/profesores', 'title': 'Información a Profesores'}
# ETIQUETA:  <a href="http://informatica.ucm.es/laboratorios-fdi" title="Laboratorios FdI">Laboratorios FdI</a>
# URL: http://informatica.ucm.es/laboratorios-fdi
# Contenidos: Laboratorios FdI
# Atributos: {'href': 'http://informatica.ucm.es/laboratorios-fdi', 'title': 'Laboratorios FdI'}
# ETIQUETA:  <a href="https://www.fdi.ucm.es/Account/" title="Portal FDI">Portal FDI</a>
# URL: https://www.fdi.ucm.es/Account/
# Contenidos: Portal FDI
# Atributos: {'href': 'https://www.fdi.ucm.es/Account/', 'title': 'Portal FDI'}
# ETIQUETA:  <a href="http://Informatica.ucm.es/buzon-de-sugerencias-y-quejas" title="Sugerencias y Quejas">Sugerencias y Quejas</a>
# URL: http://Informatica.ucm.es/buzon-de-sugerencias-y-quejas
# Contenidos: Sugerencias y Quejas
# Atributos: {'href': 'http://Informatica.ucm.es/buzon-de-sugerencias-y-quejas', 'title': 'Sugerencias y Quejas'}
# ETIQUETA:  <a href="https://www.ucm.es/hrs4r" target="_blank" title="UCM - HR Excellence in Research"><img alt="HR Excellence in Research" src="/themes/ucm16/media/img/hr.jpg"/></a>
# URL: https://www.ucm.es/hrs4r
# Contenidos: <img alt="HR Excellence in Research" src="/themes/ucm16/media/img/hr.jpg"/>
# Atributos: {'href': 'https://www.ucm.es/hrs4r', 'target': '_blank', 'title': 'UCM - HR Excellence in Research'}
# ETIQUETA:  <a href="http://www.campusmoncloa.es/" target="_blank" title="CAMPUS DE EXCELENCIA INTERNACIONAL"><img alt="CAMPUS DE EXCELENCIA INTERNACIONAL" src="/themes/ucm16/media/img/cei.jpg"/></a>
# URL: http://www.campusmoncloa.es/
# Contenidos: <img alt="CAMPUS DE EXCELENCIA INTERNACIONAL" src="/themes/ucm16/media/img/cei.jpg"/>
# Atributos: {'href': 'http://www.campusmoncloa.es/', 'target': '_blank', 'title': 'CAMPUS DE EXCELENCIA INTERNACIONAL'}
# ETIQUETA:  <a href="/contacto" title="Localización y contacto">Localización y contacto</a>
# URL: /contacto
# Contenidos: Localización y contacto
# Atributos: {'href': '/contacto', 'title': 'Localización y contacto'}
# ETIQUETA:  <a href="/aviso-legal" title="Aviso Legal">Aviso Legal</a>
# URL: /aviso-legal
# Contenidos: Aviso Legal
# Atributos: {'href': '/aviso-legal', 'title': 'Aviso Legal'}
# ETIQUETA:  <a href="https://www.ucm.es/datos-personales" title="Protección de datos">Protección de datos</a>
# URL: https://www.ucm.es/datos-personales
# Contenidos: Protección de datos
# Atributos: {'href': 'https://www.ucm.es/datos-personales', 'title': 'Protección de datos'}
# ETIQUETA:  <a href="https://informatica.ucm.es/rss/rss.php?weid=26" title="RSS">RSS</a>
# URL: https://informatica.ucm.es/rss/rss.php?weid=26
# Contenidos: RSS
# Atributos: {'href': 'https://informatica.ucm.es/rss/rss.php?weid=26', 'title': 'RSS'}

# %% [markdown]
# En general BeautifulSoup se puede usar para diferentes acciones:
#
# * Imprimir un documento
#
# * Parsear un documento html
#
# * Analizar un documento html

# %% [markdown]
# __Imprimir un documento html__
#
# Existen varios métodos para imprimir un documento:
#
# * La función __str()__ muestra el documento como una cadena, pero no elimina nodos que solo tengan un espacio en blanco ni añade espacios en blanco entre los nodos.
#
# * La función __prettify()__ añade nuevas líneas y espacios para mostrar la estructura del documento html, y elimina nodos que solo contengan espacios en blanco.
#
# * La función __encode_contents__ muestra el documento como una cadena en la codificación dada, y si no se indica se muestra como una cadena unicode.

# %%
from bs4 import BeautifulSoup
doc="<html><h1>Cabecera</h1><p>Text"
soup=BeautifulSoup(doc, 'html.parser')
print(str(soup))
print()
print(soup.encode_contents())
print()
print(soup.__str__())
print()
print(soup.prettify())
# Out:
# <html><h1>Cabecera</h1><p>Text</p></html>
#
# b'<html><h1>Cabecera</h1><p>Text</p></html>'
#
# <html><h1>Cabecera</h1><p>Text</p></html>
#
# <html>
#  <h1>
#   Cabecera
#  </h1>
#  <p>
#   Text
#  </p>
# </html>

# %% [markdown]
# Las funciones __str__ y __encode_contents__ no funcionan igual cuando se usa sobre una etiqueta dentro del documento. En el caso de __str__ se imprime la etiqueta y sus contenidos y en el caso de __encode_contents__ solo se imprimen los contenidos.

# %%
from bs4 import BeautifulSoup
doc="<html><h1>Cabecera</h1><p>Text"
soup=BeautifulSoup(doc, 'html.parser')
cabecera=soup.h1
print (str(cabecera))
print()
print(cabecera.encode_contents())
# Out:
# <h1>Cabecera</h1>
#
# b'Cabecera'

# %% [markdown]
# Cuando se llama a __str__, __prettify__ o __encode_contents__ se puede especifica la codificación de salida de la cadena. Por defecto es UTF-8

# %%
from bs4 import BeautifulSoup
doc="Sacr\xe9 bleu!"
soup=BeautifulSoup(doc, 'html.parser')
print(str(soup))
print(soup.prettify(encoding="ISO-8859-1"))
print(soup.prettify(encoding="UTF-16"))
print(soup.prettify(encoding="EUC-JP"))
# Out:
# Sacré bleu!
# b'Sacr\xe9 bleu!\n'
# b'\xff\xfeS\x00a\x00c\x00r\x00\xe9\x00 \x00b\x00l\x00e\x00u\x00!\x00\n\x00'
# b'Sacr\x8f\xab\xb1 bleu!\n'

# %% [markdown]
# Si el documento original contenía una especificación de codificación entonces se reescribe cuando se convierte a cadena a UTF-8

# %%
from bs4 import BeautifulSoup
doc="""<html>
<meta http-equiv="Content-type" content=test/html; charset=ISO-Latin-1">
Sacr\xe9 bleu!
</html>"""
print (BeautifulSoup(doc, 'html.parser').prettify())
# Out:
# <html>
#  <meta charset="utf-8" content="test/html;" http-equiv="Content-type"/>
#  Sacré bleu!
# </html>

# %% [markdown]
# __Parsear un documento html__
#
# BeautifulSoup toma un documento html y lo parsea a una estructura de datos en forma de árbol. Si el documento está bien formado el árbol se parece al documento original pero si no lo está entonces usa heurísticas para conseguir una estructura razonable.
#
# En este sentido se usa el siguiente conocimiento:
#
# * Hay etiquetas que pueden estar anidadas(&lt;BLOCKQUOTE/>) y otras no(&lt;P/>).
#
# * Las tablas y listas de etiquetas tienen un orden de anidamiento natural. Por ejemplo &lt;TD> está en el interior de &lt;TR>.
#
# * Los contenidos de una etiqueta &lt;SCRIPT> no deben ser parseados.
#
# * Una etiqueta &lt;META> puede especificar una codificación del documento.

# %%
from bs4 import BeautifulSoup
html="<html><p>Parra 1<p> Parra 2<blockquote>Quote 1<blockquote>Quote 2"
soup=BeautifulSoup(html, 'html.parser')
print (soup.prettify())
# Out:
# <html>
#  <p>
#   Parra 1
#   <p>
#    Parra 2
#    <blockquote>
#     Quote 1
#     <blockquote>
#      Quote 2
#     </blockquote>
#    </blockquote>
#   </p>
#  </p>
# </html>

# %%
from bs4 import BeautifulSoup
html="""
<html>
<form>
<table>
<td><input name="input1"> Row 1 cell 1
<tr> <td> Row 2 cell 1
</form>
<td> Row 2 cell 2 <br> This </br> sure is a long cell
</body>
</html>"""

print(BeautifulSoup(html, 'html.parser').prettify())
# Out:
# <html>
#  <form>
#   <table>
#    <td>
#     <input name="input1"/>
#     Row 1 cell 1
#     <tr>
#      <td>
#       Row 2 cell 1
#      </td>
#     </tr>
#    </td>
#   </table>
#  </form>
#  <td>
#   Row 2 cell 2
#   <br/>
#   This  sure is a long cell
#  </td>
# </html>

# %% [markdown]
# El objeto Beautifulsoup representa un árbol de procesamiento que contiene dos tipos de objetos:
#
# * Objetos de tipo tag que se corresponden con etiquetas o elementos del documento HTML
#
# * Objetos de tipo NavigableString que se corresponden con cadenas. Existen subclases de NavigableString que corresponden a construcciones especiales XML tales como CData, Comment, Declaration, and ProcessingInstruction.
#
# Los elementos representados por los objetos de tipo tag pueden tener asociados atributos y se puede acceder a ellos como si fuera un diccionario. Sin embargo los elementos representados por los objetos NavigableString no tienen asociados atributos.
#
# Considerar el siguiente ejemplo para las explicaciones siguientes:

# %% [raw]
# <html>
#  <head>
#   <title>
#   Título de la página
#   </title>
#   </head>
#   <body>
#   <p id="primerparrafo" align="center">
#   Esto es un parrafo
#   <b>
#   one
#   </b>
#   .
#   </p>
#   <p id="segundoparrafo" align="blah">
#   Esto es un parrafo
#   <b>
#   two
#   </b>
#   .
#   </p>
#   </body>
# </html>

# %% [markdown]
# En el siguiente ejemplo se recuperan las etiquetas “p” y se accede a sus atributos como si fuera un diccionario.

# %%
from bs4 import BeautifulSoup
html=open("prueba.html")
soup=BeautifulSoup(html.read(),'html.parser')
Primero, Segundo=soup.find_all("p")
print (Primero['id'])
print (Segundo['id'])
# Out:
# primerparrafo
# segundoparrafo

# %% [markdown]
# Los valores tag pueden ser pasados a la función str() para mostrar las etiquetas que representan. Además los valores tag tienen un atributo llamado attrs que muestra todos los atributos HTML que tiene el elemento en forma de un diccionario.
#
# Los objetos Tag y NavigableString disponen de un conjunto de atributos y métodos:
#
# * __parent__: Permite acceder al objeto que representa la etiqueta padre del objeto que representa a  una etiqueta. Permite navegar por el árbol de procesamiento.

# %%
soup.head.parent.name
# Out:
# 'html'

# %% [markdown]
# * __contents__: Representa una lista ordenada de los objetos Tags y NavigableString contenidos dentro de un elemento. Solo el objeto que representa al árbol y los objetos tags poseen este atributo. Los objetos NavigableString no tienen el atributo contents, pues sólo tienen cadenas.

# %%
etiquetasp=soup.p
etiquetasp.contents
# Out:
# ['Esto es un parrafo', <b>one</b>, '.']

# %%
etiquetasp.contents[1].contents
# Out:
# ['one']

# %%
etiquetasp.contents[0].contents
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-853c80af9032> in <module>()
# ----> 1 etiquetasp.contents[0].contents
#
# C:\Users\Antonio\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     728             raise AttributeError(
#     729                 "'%s' object has no attribute '%s'" % (
# --> 730                     self.__class__.__name__, attr))
#     731
#     732     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'contents'

# %% [markdown]
# * __string__: Si un tag solo tiene un nodo hijo y se trata de una cadena, entonces se puede acceder al mismo mediante tag.string o mediante tag.contents[0]. Cuando existen hijos, y se trata de acceder al atributo string, devuelve como resultado el valor None. Los objetos NavigableString no tienen este atributo.

# %%
soup.b.string
# Out:
# 'one'

# %%
soup.b.contents[0]
# Out:
# 'one'

# %%
soup.p.string==None
# Out:
# True

# %%
soup.head.string==None
# Out:
# False

# %% [markdown]
# * __next_sibling__ y __previous_sibling__: Permite recuperar el objeto anterior o posterior que se encuentra al mismo nivel del objeto considerado. En el ejemplo anterior la etiqueta &lt;Body> está al mismo nivel que la etiqueta &lt;Head> pero esta última aparece antes.

# %%
soup.head.next_sibling.name
# Out:
# 'body'

# %%
soup.head.previous_sibling==None
# Out:
# True

# %% [markdown]
# * __next__ y __previous__: Permiten navegar en el árbol de procesamiento sobre los objetos en el orden en que fueron procesados en vez del orden dado por el árbol. En el ejemplo el objeto next al objeto que representa a &lt;HEAD> es el objeto que representa a &lt;TITLE> y no el objeto que representa a &lt;BODY>.

# %%
soup.head.next
# Out:
# <title>TÃ­tulo de la pÃ¡gina</title>

# %%
soup.head.next_sibling.name
# Out:
# 'body'

# %%
soup.head.previous.name
# Out:
# 'html'

# %% [markdown]
# Observaciones:
#
# * Se puede iterar sobre el atributo contents de un objeto tag y tratarlo como una lista, y de forma similar se puede obtener el número de hijos mediante len(tag) o len(tag.contents).

# %%
for i in soup.body:
    print (i)
# Out:
# <p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>
# <p align="blah" id="segundoparrafo">Esto es un parrafo<b>two</b>.</p>

# %%
len(soup.body)
# Out:
# 2

# %%
len(soup.body.contents)
# Out:
# 2

# %% [markdown]
# * Se puede usar los nombres de un objeto tag como si fueran atributos del árbol de procesamiento o de un objeto tag. Siempre que se usa de esta forma, devuelve el primer nodo hijo cuyo nombre sea el considerado o bien retorna None si no existen hijos con ese nombre. En el ejemplo anterior para acceder a la etiqueta &lt;Title> se puede ir a partir de la etiqueta &lt;Head> o bien directamente.

# %%
soup.head.title
# Out:
# <title>TÃ­tulo de la pÃ¡gina</title>

# %%
soup.title
# Out:
# <title>TÃ­tulo de la pÃ¡gina</title>

# %% [markdown]
# * Ahora se van a considerar los métodos que permiten buscar en el árbol de procesamiento: find_all y find.
#
# * Solo se encuentran disponibles para el objeto que representa el árbol de procesamiento y en los objetos de tipo tag pero no en los objetos de tipo NavigableString
#
# El método find_all busca todos los objetos tag y NavigableString  que coinciden con un criterio dado desde un punto dado. Sus principales argumentos son:
#
#                find_all(name, attrs, recursive, text, limit)
#
# donde:
#
# * Un nombre que restringe el conjunto de búsqueda por el nombre de las etiquetas.
#
# * Pares atributo-valor que restringen el conjunto de búsqueda por los valores que toman los atributos de las etiquetas.
#
# * El argumento “text” permite buscar objetos NavigableString , y puede tomar como valores una cadena, una expresión regular, una lista o diccionario, True o None o bien una expresión booleana. Cuando se usa este argumento, las restricciones sobre nombre o atributo no se tienen en cuenta.
#
# * El argumento “recursive” que puede tomar los valores True o False que indica si busca por debajo del árbol o bien por los hijos inmediatos del árbol. Por defecto es True.
#
# * El argumento limit permite parar la búsqueda cuando se han conseguido un número de coincidencias dado. Por defecto no tienen límite.

# %% [markdown]
# Algunos ejemplos de restricción por nombre:
#
# * Argumento con el nombre de una etiqueta.

# %%
soup.find_all('b')
# Out:
# [<b>one</b>, <b>two</b>]

# %% [markdown]
# * Argumento con una expresión regular

# %%
import re
etiquetasconb=soup.find_all(re.compile('^b'))
for tag in etiquetasconb:
    print(tag.name)
# Out:
# body
# b
# b

# %% [markdown]
# * Argumento con una lista o diccionario.

# %%
soup.find_all(['title','p'])
# Out:
# [<title>TÃ­tulo de la pÃ¡gina</title>,
#  <p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>,
#  <p align="blah" id="segundoparrafo">Esto es un parrafo<b>two</b>.</p>]

# %%
soup.find_all({'title':True,'p':True})
# Out:
# [<title>TÃ­tulo de la pÃ¡gina</title>,
#  <p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>,
#  <p align="blah" id="segundoparrafo">Esto es un parrafo<b>two</b>.</p>]

# %% [markdown]
# * Argumento con el valor True que produce una coincidencia con cada objeto tag.

# %%
etiquetas=soup.find_all(True)
for tag in etiquetas:
    print(tag.name)
# Out:
# html
# head
# title
# body
# p
# b
# p
# b

# %% [markdown]
# * Argumento con una expresión que evalúa a cierto o falso.

# %%
soup.find_all(lambda tag: len(tag.attrs)==2)
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>,
#  <p align="blah" id="segundoparrafo">Esto es un parrafo<b>two</b>.</p>]

# %%
soup.find_all(lambda tag: len(tag.name)==1 and not tag.attrs)
# Out:
# [<b>one</b>, <b>two</b>]

# %% [markdown]
# Algunos ejemplos de restricción por atributo:
#
# * Argumento que impone una condición al valor que toma un atributo.

# %%
soup.find_all(align="center")
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>]

# %% [markdown]
# * Argumento que impone una condición en forma de expresión regular al valor que toma un atributo.

# %%
soup.find_all(id=re.compile("parra$"))
# Out:
# []

# %% [markdown]
# * Argumento que impone una condición en forma de lista al valor que toma un atributo.

# %%
soup.find_all(align=["center","blah"])
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>,
#  <p align="blah" id="segundoparrafo">Esto es un parrafo<b>two</b>.</p>]

# %% [markdown]
# * Argumento que impone una condición en forma de una expresión booleano al valor que toma un atributo.

# %%
soup.find_all(align=lambda value: value and len(value) <5)
# Out:
# [<p align="blah" id="segundoparrafo">Esto es un parrafo<b>two</b>.</p>]

# %% [markdown]
# * Argumento que iguala a True o None el valor de un atributo. True encaja con etiquetas que toman cualquier valor para el atributo y None encaja con etiquetas que no tienen valor para ese atributo.

# %%
soup.find_all(align=True)
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>,
#  <p align="blah" id="segundoparrafo">Esto es un parrafo<b>two</b>.</p>]

# %%
etiquetas=soup.find_all(align=None)
for eti in etiquetas:
    print(eti.name)
# Out:
# html
# head
# title
# body
# b
# b

# %% [markdown]
# Algunos ejemplos del argumento text:

# %%
soup.find_all(text="one")
# Out:
# ['one']

# %%
soup.find_all(text=["one","two"])
# Out:
# ['one', 'two']

# %%
soup.find_all(text=True)
# Out:
# ['ï»¿',
#  'TÃ\xadtulo de la pÃ¡gina',
#  'Esto es un parrafo',
#  'one',
#  '.',
#  'Esto es un parrafo',
#  'two',
#  '.']

# %%
soup.find_all(text=lambda x: len(x)<12)
# Out:
# ['ï»¿', 'one', '.', 'two', '.']

# %%
soup.find_all(text=re.compile("parrafo"))
# Out:
# ['Esto es un parrafo', 'Esto es un parrafo']

# %% [markdown]
# Algunos ejemplos del argumento recursive:

# %%
[tag.name for tag in soup.html.find_all()]
# Out:
# ['head', 'title', 'body', 'p', 'b', 'p', 'b']

# %%
[tag.name for tag in soup.html.find_all(recursive=False)]
# Out:
# ['head', 'body']

# %% [markdown]
# Algunos ejemplos del argumento limit:

# %%
soup.find_all('p',limit=1)
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>]

# %%
soup.find_all('p',limit=100)
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>,
#  <p align="blah" id="segundoparrafo">Esto es un parrafo<b>two</b>.</p>]

# %% [markdown]
# El método find tiene una estructura similar a find_all:
#
#            find(name, attrs, recursive, text)
#
# Es similar a find_all con la única diferencia de que en vez de recuperar todas las coincidencias, recupera sólo la primera. Tiene el mismo comportamiento que si el parámetro limit de find_all tomara el valor 1.

# %%
soup.find_all('p', limit=1)
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>]

# %%
soup.find('p')
# Out:
# <p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>

# %% [markdown]
# Observaciones:
#
# * Puede ocurrir que algún atributo de una etiqueta coincida con las palabras reservadas en BeautifulSoup. En estos casos no se puede hacer una referencia directa al atributo y es necesario usar un atributo que tienen las etiquetas denominado attrs que actúa como un diccionario que hace referencia a los atributos de una etiqueta.

# %%
soup.find_all(attrs={"id":"primerparrafo"})
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>]

# %% [markdown]
# * Se pueden combinar búsqueda por nombre y por atributo:

# %%
soup.find_all('p',{"align":"center"})
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>]

# %% [markdown]
# * Cuando el objeto que representa al árbol de procesamiento o un objeto tag se usa como una función y se le pasan los mismos argumentos que a find_all, actúa como find_all.

# %%
soup(text=lambda x: len(x)<12)
# Out:
# ['ï»¿', 'one', '.', 'two', '.']

# %%
soup.body('p',limit=1)
# Out:
# [<p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>]

# %% [markdown]
# * Los métodos find_all y find empiezan en un cierto punto del árbol y lo recorren hacia abajo, iterando recursivamente sobre los elementos del atributo contents de los objetos tags. Es por ello que no se pueden usar sobre objetos de tipo NavigableString pues no tienen atributo contents.

# %% [markdown]
# Existen otros métodos de navegación por el árbol de procesamiento:
#
# * find_next_siblings(name, attrs, text, limit) y find_next_sibling(name, attrs, text): Devuelve el nodo/s hermano/s más cercanos a la etiqueta dada que coincida con los criterios de búsqueda y que aparece después de la etiqueta considerada.

# %%
parrafo=soup.find(text="Esto es un parrafo")
parrafo.find_next_siblings('b')
# Out:
# [<b>one</b>]

# %%
parrafo.find_next_sibling(text=lambda text:len(text)==1)
# Out:
# '.'

# %% [markdown]
# * find_previous_siblings(name, attrs, text, limit) y find_previous_sibling(name, attrs, text): Devuelve el nodo/s hermano/s más cercanos a la etiqueta dada que coincida con los criterios de búsqueda y que aparece antes de la etiqueta considerada.

# %%
parrafo=soup.find(text=".")
parrafo.find_previous_siblings('b')
# Out:
# [<b>one</b>]

# %%
parrafo.find_previous_sibling(text=True)
# Out:
# 'Esto es un parrafo'

# %% [markdown]
# * find_all_next(name, attrs, text, limit) y findNext(name, attrs, text):                                                Devuelve todos los elementos(el elemento) que coincida con los criterios de búsqueda y que aparece después de la etiqueta considerada.

# %%
etiqueta=soup.find('p')
etiqueta.find_all_next(text=True)
# Out:
# ['Esto es un parrafo', 'one', '.', 'Esto es un parrafo', 'two', '.']

# %%
etiqueta.find_next('p')
# Out:
# <p align="blah" id="segundoparrafo">Esto es un parrafo<b>two</b>.</p>

# %%
etiqueta.find_next('b')
# Out:
# <b>one</b>

# %% [markdown]
# * find_all_previous(name, attrs, text, limit) y find_previous(name, attrs, text):                            Devuelve todos los elementos(el elemento) que coincida con los criterios de búsqueda y que aparece antes de la etiqueta considerada.

# %%
etiqueta=soup('p')[-1]
etiqueta.find_all_previous(text=True)
# Out:
# ['.', 'one', 'Esto es un parrafo', 'TÃ\xadtulo de la pÃ¡gina', 'ï»¿']

# %%
etiqueta.find_previous('p')
# Out:
# <p align="center" id="primerparrafo">Esto es un parrafo<b>one</b>.</p>

# %%
etiqueta.find_previous('b')
# Out:
# <b>one</b>

# %% [markdown]
# * find_parents(name, attrs, limit) y find_parent(name, attrs):                                                       Devuelve los padres de la etiqueta considerada que coinciden con los criterios de búsqueda.

# %%
etiqueta=soup.find('b')
[eti.name for eti in etiqueta.find_parents()]
# Out:
# ['p', 'body', 'html', '[document]']

# %%
etiqueta.find_parent('body').name
# Out:
# 'body'

# %% [markdown]
# Otra utilidad que ofrece BeautifulSoup es la modificación del árbol de procesamiento:
#
# * Cambio de valores de atributos.
#
# * Eliminación de elementos.
#
# * Reemplazamiento de un elemento por otro.
#
# * Añadir una rama con un nuevo elemento.

# %% [markdown]
# __Cambio de valores de atributos__
#
# * Se puede usar la asignación de diccionarios para modificar los valores de los atributos de un objeto tag.

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup("<b id='2'> Argh!</b>","html.parser")
print(soup)
b=soup.b
b['id']=10
print(soup)
b['id']="diez"
print(soup)
b['id']="un millón"
print(soup)
# Out:
# <b id="2"> Argh!</b>
# <b id="10"> Argh!</b>
# <b id="diez"> Argh!</b>
# <b id="un millón"> Argh!</b>

# %% [markdown]
# * Se pueden eliminar atributos y añadir otros nuevos.

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup("<b id='2'> Argh!</b>","html.parser")
b=soup.b
del(b['id'])
print(soup)
b["class"]="extra negro"
print(soup)
# Out:
# <b> Argh!</b>
# <b class="extra negro"> Argh!</b>

# %% [markdown]
# __Eliminación de elementos__
#
# Cuando se sitúa sobre un elemento concreto, se puede eliminar del árbol de procesamiento con el método extract.

# %%
#Se eliminan todos los comentarios del documento html
from bs4 import BeautifulSoup,Comment
soup=BeautifulSoup(""" 1<!--Comentario 1-->
                        <a>2<!--Comentario 2--><b>3""", "html.parser")
comentarios=soup.find_all(text=lambda text: isinstance(text,Comment))
[comentario.extract() for comentario in comentarios]
print ("Eliminación de todos los comentarios del documento html")
print (soup)
# Out:
# Eliminación de todos los comentarios del documento html
#  1
# <a>2<b>3</b></a>

# %%
#Eliminación de un subárbol entero que da lugar a dos árboles disjuntos
from bs4 import BeautifulSoup
soup=BeautifulSoup("<a1></a1><a><b>Contenido de prueba<c><d></a><a2></a2>", "html.parser")
print (soup.a1.next_sibling)
print (soup.a2.previous_sibling)
subarbol=soup.a
subarbol.extract()
print (soup)
print (soup.a1.next_sibling)
print (soup.a2.previous_sibling)
print (subarbol.previous_sibling==None)
print (subarbol.parent==None)
# Out:
# <a><b>Contenido de prueba<c><d></d></c></b></a>
# <a><b>Contenido de prueba<c><d></d></c></b></a>
# <a1></a1><a2></a2>
# <a2></a2>
# <a1></a1>
# True
# True

# %% [markdown]
# __Reemplazar un elemento por otro__
#
# El método replace_with extrae un elemento y lo reemplaza por otro que puede ser tanto un objeto de tipo tag o de tipo NavigableString. Si se pasa como argumento una cadena entonces lo considera un objeto de tipo NavigableString

# %%
#Ejemplo 1 de reemplazamiento del contenido de una etiqueta
from bs4 import BeautifulSoup
soup=BeautifulSoup("<b>Argh!</b>", "html.parser")
soup.find(text="Argh!").replace_with("Buff!")
print(soup)
nuevoText=soup.find(text="Buff!")
print (nuevoText.previous)
s=nuevoText.previous.next
print (str(s))
print (nuevoText.parent)
print (soup.b.contents)
# Out:
# <b>Buff!</b>
# <b>Buff!</b>
# Buff!
# <b>Buff!</b>
# ['Buff!']

# %%
#Ejemplo 2 de reemplazamiento de un elemento por otro nuevo
from bs4 import BeautifulSoup
soup=BeautifulSoup("<b>Argh!<a>Hola</a></b><i>Adios</i>", "html.parser")
tag=BeautifulSoup.new_tag(soup,"newTag",[('id','1')])
tag.insert(0,"Noche")
soup.a.replace_with(tag)
print (soup)
# Out:
# <b>Argh!<newTag>Noche</newTag></b><i>Adios</i>

# %%
#Ejemplo 3 de reemplazamiento donde se elimina un elemento y se sustituye por
#otro elemento del árbol de procesamiento
from bs4 import BeautifulSoup
soup=BeautifulSoup("<html>Esto es <b> un</b> ejemplo de <b> documento </b> html</html>", "html.parser")
uno,dos=soup.find_all('b')
dos.replace_with(uno)
print (soup)
# Out:
# <html>Esto es  ejemplo de <b> un</b> html</html>

# %% [markdown]
# __Añadir una rama con un nuevo elemento.__
#
# * El método insert toma un índice sobre el atributo contents del objeto tag e inserta un nuevo elemento en dicha posición.

# %%
#Ejemplo de creación de un árbol de procesamiento desde cero
from bs4 import BeautifulSoup, NavigableString
soup=BeautifulSoup()
tag1= BeautifulSoup.new_tag(soup, "etiqueta1")
tag2= BeautifulSoup.new_tag(soup, "etiqueta2")
tag3= BeautifulSoup.new_tag(soup, "etiqueta3")
soup.insert(0,tag1)
tag1.insert(0,tag2)
tag1.insert(1,tag3)
print (soup.prettify())
text=NavigableString("Hola")
tag3.insert(0,text)
print(soup)
# Out:
# <etiqueta1>
#  <etiqueta2>
#  </etiqueta2>
#  <etiqueta3>
#  </etiqueta3>
# </etiqueta1>
# <etiqueta1><etiqueta2></etiqueta2><etiqueta3>Hola</etiqueta3></etiqueta1>

# %% [markdown]
# * Un elemento sólo puede estar en un lugar del árbol de procesamiento. Si con el método insert se intenta insertar nuevamente un elemento, entonces es eliminado del lugar en el que estaba anteriormente.

# %%
#Ejemplo de intentar insertar un elemento dos veces
from bs4 import BeautifulSoup, NavigableString
soup=BeautifulSoup()
tag1= BeautifulSoup.new_tag(soup, "etiqueta1")
tag2= BeautifulSoup.new_tag(soup, "etiqueta2")
tag3= BeautifulSoup.new_tag(soup, "etiqueta3")
soup.insert(0,tag1)
tag1.insert(0,tag2)
tag1.insert(1,tag3)
print (soup.prettify())
text=NavigableString("Hola")
tag3.insert(0,text)
print(soup)
tag2.insert(0,text)
print(soup)
# Out:
# <etiqueta1>
#  <etiqueta2>
#  </etiqueta2>
#  <etiqueta3>
#  </etiqueta3>
# </etiqueta1>
# <etiqueta1><etiqueta2></etiqueta2><etiqueta3>Hola</etiqueta3></etiqueta1>
# <etiqueta1><etiqueta2>Hola</etiqueta2><etiqueta3></etiqueta3></etiqueta1>

# %% [markdown]
# Se va a considerar el siguiente problema. Se quiere automatizar la bajada de imágenes de tren procedentes de un blog especializado.
#
# En primer lugar recuperamos la página principal del blog mediante urllib

# %%
import urllib.request
from bs4 import *
html=urllib.request.urlopen("http://trenesytiempos.blogspot.com.es/").read()

# %% [markdown]
# Vemos la estructura que tiene la página para ver dónde se encuentran las imágenes, y se observa que aparecen en etiquetas de anclaje que tienen entre sus atributos imageanchor=“1”.
#
# <a href="https://4.bp.blogspot.com/-jFeRNNxXIIk/WRbUurWfyHI/AAAAAAAAPFE/X8RtsF1f6p8RnC4ZMeMKJCDdP5d06pggACLcB/s1600/030-2569-70.jpg
#
# Se crea un árbol de procesamiento con BeautifulSoup y se recuperan todas las etiquetas con las características anteriores:

# %%
import urllib.request
from bs4 import *
html=urllib.request.urlopen("http://trenesytiempos.blogspot.com.es/").read()
soup=BeautifulSoup(html,"html.parser")
etiquetas=soup('a',{"imageanchor":"1"})

# %% [markdown]
# Recuperadas las direcciones se quieren almacenar las imágenes en el disco local, entonces para ello se usa un bucle for que recorre cada dirección, la abre y la almacena en un archivo distinto.

# %%
j=0
for i in etiquetas:
    archivo=open("foto"+str(j)+".jpg","wb")
    imagen=urllib.request.urlopen(i.get("href",None))
    while True:
        info=imagen.read(100000)
        if len(info)<1: 
            break
        archivo.write(info)
    archivo.close()
    j=j+1

# %% [markdown]
# El código completo sería:

# %%
import urllib.request
from bs4 import *
html=urllib.request.urlopen("http://trenesytiempos.blogspot.com.es/").read()
soup=BeautifulSoup(html,"html.parser")
etiquetas=soup('a',{"imageanchor":"1"})
j=0
for i in etiquetas:
    archivo=open("foto"+str(j)+".jpg","wb")
    imagen=urllib.request.urlopen(i.get("href",None))
    while True:
        info=imagen.read(100000)
        if len(info)<1: 
            break
        archivo.write(info)
    archivo.close()
    j=j+1

# %% [markdown]
# __Otras herramientas__
#
# La función open del módulo webbrowser de Python permite lanzar un navegador sobre una URL específica. Por ejemplo el siguiente trozo de código abriría un navegador con la página de la Facultad de Informática

# %%
import webbrowser
webbrowser.open("http://informatica.ucm.es")
# Out:
# True

# %% [markdown]
# Se va a considerar un programa que recupera del teclado una dirección y que permite buscar dicha dirección en Google Maps.Para ello en primer lugar observar que la url que se usa cuando se busca una dirección en Google Maps tiene la siguiente estructura:
#     https://www.google.com/maps/place/dirección-buscada
#
# El programa debe recuperar de la línea de comandos la dirección . Para ello se usará el módulo sys que permite almacena en la variable sys.argv una lista con el nombre del programa y los argumentos pasados al programa en caso de tenerlos. Para saber si la lista incluye más elementos además del nombre del programa, se puede utilizar len(sys.argv) y comprobar que se evalúa a un número mayor que 1.
#
# Se tiene el siguiente código:

# %% [raw]
# import sys
# if len(sys.argv)>1:
#     direccion=' '.join(sys.argv[1:])

# %% [markdown]
# Observar que los argumentos en la línea de comandos en general se separan mediante espacios, sin embargo en este caso sería necesario interpretar todos los argumentos como una única cadena. Dado que sys.argv es una lista de cadenas, se puede utilizar el método join() que retorna una única cadena. Además como no interesa el nombre del programa, se puede eliminar el mismo si se selecciona la última parte de la lista con sys.argv[1:]
#
# Si en la línea de comandos no hay argumentos, se asumirá que la dirección se ha copiado. Para obtener el contenido de una copia se utiliza el método paste del módulo pyperclip

# %% [raw]
# import sys, pyperclip
# if len(sys.argv)>1:
#     direccion=' '.join(sys.argv[1:])
# else:
#     direccion=pyperclip.paste()

# %% [markdown]
# Por último para lanzar el navegador se utiliza el método open del módulo browser.

# %% [raw]
# import sys, pyperclip, webbrowser
# if len(sys.argv)>1:
#     direccion=' '.join(sys.argv[1:])
# else:
#     direccion=pyperclip.paste()
# webbrowser.open("http://www.google.com/maps/place/"+direccion)
